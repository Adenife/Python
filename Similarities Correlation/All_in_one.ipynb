# %% [markdown]
# # Module 1

# %%
# import the libraries to be used in reading the data and performing operatons on it
import numpy as np
import pandas as pd
from io import StringIO
import csv

# %%
data = pd.read_csv('data.csv')
data.head()
# Out:
#    acousticness                                   artists  danceability  \
# 0         0.995                       ['Carl Woitschach']         0.708
# 1         0.994  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2         0.604                   ['Seweryn Goszczyński']         0.749
# 3         0.995                      ['Francisco Canaro']         0.781
# 4         0.990  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD             0.563
# 1       282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV             0.901
# 2       104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM             0.000
# 3       180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8             0.887
# 4       687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd             0.908
#
#    key  liveness  loudness  mode  \
# 0   10    0.1510   -12.428     1
# 1    8    0.0763   -28.454     1
# 2    5    0.1190   -19.924     0
# 3    1    0.1110   -14.734     0
# 4   11    0.0980   -16.829     1
#
#                                             name  popularity release_date  \
# 0                    Singende Bataillone 1. Teil           0         1928
# 1       Fantasiestücke, Op. 111: Più tosto lento           0         1928
# 2                 Chapter 1.18 - Zamek kaniowski           0         1928
# 3  Bebamos Juntos - Instrumental (Remasterizado)           0   1928-09-25
# 4    Polonaise-Fantaisie in A-Flat Major, Op. 61           1         1928
#
#    speechiness    tempo  valence  year
# 0       0.0506  118.469   0.7790  1928
# 1       0.0462   83.972   0.0767  1928
# 2       0.9290  107.177   0.8800  1928
# 3       0.0926  108.003   0.7200  1928
# 4       0.0424   62.149   0.0693  1928

# %%
data['popularity'].value_counts()
# Out:
# 0      27357
# 42      3280
# 43      3120
# 40      3061
# 44      3054
#        ...
# 93         3
# 97         1
# 96         1
# 99         1
# 100        1
# Name: popularity, Length: 100, dtype: int64

# %%
data.shape
# Out:
# (169909, 19)

# %%
data = []

with open('data.csv', encoding='utf-8') as f:
    data_reader = csv.reader(f, delimiter=',')
    for row in data_reader:
        data.append(row)

# %%
data
# Out:
# [['acousticness',
#   'artists',
#   'danceability',
#   'duration_ms',
#   'energy',
#   'explicit',
#   'id',
#   'instrumentalness',
#   'key',
#   'liveness',
#   'loudness',
#   'mode',
#   'name',
#   'popularity',
#   'release_date',
#   'speechiness',
#   'tempo',
#   'valence',
#   'year'],
#  ['0.995',
#   "['Carl Woitschach']",
#   '0.708',
#   '158648',
#   '0.195',
#   '0',
#   '6KbQ3uYMLKb5jDxLF7wYDD',
#   '0.563',
#   '10',
#   '0.151',
#   '-12.428',
#   '1',
#   'Singende Bataillone 1. Teil',
#   '0',
#   '1928',
#   '0.0506',
#   '118.469',
#   '0.779',
#   '1928'],
#  ['0.994',
#   "['Robert Schumann', 'Vladimir Horowitz']",
#   '0.379',
#   '282133',
#   '0.0135',
#   '0',
#   '6KuQTIu1KoTTkLXKrwlLPV',
#   '0.901',
#   '8',
#   '0.0763',
#   '-28.454',
#   '1',
#   'Fantasiestücke, Op. 111: Più tosto lento',
#   '0',
#   '1928',
#   '0.0462',
#   '83.97200000000002',
#   '0.0767',
#   '1928'],
#  ['0.604',
#   "['Seweryn Goszczyński']",
#   '0.7490000000000001',
#   '104300',
#   '0.22',
#   '0',
#   '6L63VW0PibdM1HDSBoqnoM',
#   '0.0',
#   '5',
#   '0.119',
#   '-19.924',
#   '0',
#   'Chapter 1.18 - Zamek kaniowski',
#   '0',
#   '1928',
#   '0.929',
#   '107.177',
#   '0.88',
#   '1928'],
#  ['0.995',
#   "['Francisco Canaro']",
#   '0.7809999999999999',
#   '180760',
#   '0.13',
#   '0',
#   '6M94FkXd15sOAOQYRnWPN8',
#   '0.887',
#   '1',
#   '0.111',
#   '-14.734000000000002',
#   '0',
#   'Bebamos Juntos - Instrumental (Remasterizado)',
#   '0',
#   '1928-09-25',
#   '0.0926',
#   '108.003',
#   '0.72',
#   '1928'],
#  ['0.99',
#   "['Frédéric Chopin', 'Vladimir Horowitz']",
#   '0.21',
#   '687733',
#   '0.204',
#   '0',
#   '6N6tiFZ9vLTSOIxkj8qKrd',
#   '0.908',
#   '11',
#   '0.098',
#   '-16.829',
#   '1',
#   'Polonaise-Fantaisie in A-Flat Major, Op. 61',
#   '1',
#   '1928',
#   '0.0424',
#   '62.149',
#   '0.0693',
#   '1928'],
#  ['0.995',
#   "['Felix Mendelssohn', 'Vladimir Horowitz']",
#   '0.424',
#   '352600',
#   '0.12',
#   '0',
#   '6NxAf7M8DNHOBTmEd3JSO5',
#   '0.911',
#   '6',
#   '0.0915',
#   '-19.242',
#   '0',
#   'Scherzo a capriccio: Presto',
#   '0',
#   '1928',
#   '0.0593',
#   '63.521',
#   '0.266',
#   '1928'],
#  ['0.956',
#   "['Franz Liszt', 'Vladimir Horowitz']",
#   '0.444',
#   '136627',
#   '0.197',
#   '0',
#   '6O0puPuyrxPjDTHDUgsWI7',
#   '0.435',
#   '11',
#   '0.0744',
#   '-17.226',
#   '1',
#   'Valse oubliée No. 1 in F-Sharp Major, S. 215/1',
#   '0',
#   '1928',
#   '0.04',
#   '80.495',
#   '0.305',
#   '1928'],
#  ['0.988',
#   "['Carl Woitschach']",
#   '0.555',
#   '153967',
#   '0.421',
#   '0',
#   '6OJjveoYwJdIt76y0Pxpxw',
#   '0.836',
#   '1',
#   '0.105',
#   '-9.878',
#   '1',
#   'Per aspera ad astra',
#   '0',
#   '1928',
#   '0.0474',
#   '123.31',
#   '0.857',
#   '1928'],
#  ['0.995',
#   "['Francisco Canaro', 'Charlo']",
#   '0.6829999999999999',
#   '162493',
#   '0.207',
#   '0',
#   '6OaJ8Bh7lsBeYoBmwmo2nh',
#   '0.206',
#   '9',
#   '0.337',
#   '-9.801',
#   '0',
#   'Moneda Corriente - Remasterizado',
#   '0',
#   '1928-10-03',
#   '0.127',
#   '119.833',
#   '0.493',
#   '1928'],
#  ['0.846',
#   "['Seweryn Goszczyński']",
#   '0.674',
#   '111600',
#   '0.205',
#   '0',
#   '6PrZexNb16cabXR8Q418Xc',
#   '0.0',
#   '9',
#   '0.17',
#   '-20.119',
#   '1',
#   'Chapter 1.3 - Zamek kaniowski',
#   '0',
#   '1928',
#   '0.954',
#   '81.249',
#   '0.759',
#   '1928'],
#  ['0.994',
#   "['Sergei Rachmaninoff', 'Vladimir Horowitz']",
#   '0.376',
#   '590293',
#   '0.0719',
#   '0',
#   '6QBInZBkQNIQYU9gGzT5l4',
#   '0.883',
#   '10',
#   '0.196',
#   '-21.849',
#   '0',
#   'Piano Sonata No. 2 in B-Flat Minor, Op. 36: I. Allegro agitato - Meno mosso',
#   '0',
#   '1928',
#   '0.0352',
#   '141.39',
#   '0.0393',
#   '1928'],
#  ['0.989',
#   "['Frédéric Chopin', 'Vladimir Horowitz']",
#   '0.17',
#   '85133',
#   '0.0823',
#   '0',
#   '6QIONtzbQCbnmWNwn0H1yT',
#   '0.911',
#   '10',
#   '0.0962',
#   '-30.107',
#   '0',
#   'Piano Sonata No. 2, Op. 35: IV. Finale. Presto',
#   '1',
#   '1928',
#   '0.0317',
#   '85.98899999999998',
#   '0.34600000000000003',
#   '1928'],
#  ['0.99',
#   "['Samuel Barber', 'Vladimir Horowitz']",
#   '0.359',
#   '338333',
#   '0.0435',
#   '0',
#   '6QgdUySTRGVkNo3KwbHpK3',
#   '0.899',
#   '7',
#   '0.109',
#   '-20.858',
#   '1',
#   'Piano Sonata in E-Flat Minor, Op. 26: III. Adagio mesto',
#   '0',
#   '1928',
#   '0.0424',
#   '96.645',
#   '0.042',
#   '1928'],
#  ['0.992',
#   "['Robert Schumann', 'Vladimir Horowitz']",
#   '0.311',
#   '167333',
#   '0.0107',
#   '0',
#   '6RvSNoCPBZeTR2LyGvdJOw',
#   '0.883',
#   '5',
#   '0.0954',
#   '-35.648',
#   '1',
#   'Nachtstücke, Op. 23: No. 4 in F',
#   '0',
#   '1928',
#   '0.0556',
#   '78.98',
#   '0.21600000000000005',
#   '1928'],
#  ['0.977',
#   "['Ludwig van Beethoven', 'Staatskapelle Berlin', 'Richard Strauss']",
#   '0.335',
#   '276563',
#   '0.105',
#   '0',
#   '6Rwn56jcC0TdGQzbRl7NGw',
#   '0.84',
#   '5',
#   '0.231',
#   '-16.049',
#   '0',
#   'Symphony No. 5 in C Minor, Op. 67: 3. Allegro',
#   '0',
#   '1928-01-01',
#   '0.0716',
#   '80.204',
#   '0.406',
#   '1928'],
#  ['0.991',
#   "['George Butterworth', 'John Cameron']",
#   '0.319',
#   '184840',
#   '0.00593',
#   '0',
#   '6Sdpmree8xpGWaedACPMlP',
#   '6.35e-05',
#   '7',
#   '0.0691',
#   '-25.789',
#   '0',
#   'A Shropshire Lad: Is My Team Ploughing?',
#   '0',
#   '1928',
#   '0.051',
#   '79.831',
#   '0.16899999999999998',
#   '1928'],
#  ['0.996',
#   "['Alexander Scriabin', 'Vladimir Horowitz']",
#   '0.319',
#   '326067',
#   '0.155',
#   '0',
#   '6T0mZB7p3qzOifdXZ3Su9P',
#   '0.917',
#   '4',
#   '0.126',
#   '-18.728',
#   '1',
#   'Sonata No. 3, Op. 23 in F-Sharp Minor: IV. Presto con fuoco; Meno mosso',
#   '0',
#   '1928',
#   '0.036000000000000004',
#   '66.947',
#   '0.0488',
#   '1928'],
#  ['0.994',
#   "['Francisco Canaro', 'Luis Scalon']",
#   '0.787',
#   '167107',
#   '0.156',
#   '0',
#   '6TFuAErGpJ9FpxQQ1HC8nM',
#   '0.659',
#   '4',
#   '0.11',
#   '-14.056',
#   '0',
#   'Invocación al Tango - Remasterizado',
#   '0',
#   '1928-09-16',
#   '0.157',
#   '117.167',
#   '0.8490000000000001',
#   '1928'],
#  ['0.993',
#   "['Thomas Arne', 'John Heddle Nash']",
#   '0.569',
#   '122533',
#   '0.15',
#   '0',
#   '6UUfiNT82MWBNnmsE2ZNWf',
#   '0.0015',
#   '5',
#   '0.106',
#   '-15.238',
#   '1',
#   'Where the Bee Sucks',
#   '0',
#   '1928',
#   '0.0474',
#   '76.93',
#   '0.596',
#   '1928'],
#  ['0.992',
#   "['Francisco Canaro']",
#   '0.763',
#   '173707',
#   '0.132',
#   '0',
#   '6Ukl7n0q3Cjd0Og8uBmVeP',
#   '0.0693',
#   '4',
#   '0.112',
#   '-13.002',
#   '1',
#   'Tendrás Que Llorar Conmigo - Instrumental (Remasterizado)',
#   '0',
#   '1928-09-17',
#   '0.0886',
#   '111.679',
#   '0.8320000000000001',
#   '1928'],
#  ['0.993',
#   "['Moritz Moszkowski', 'Vladimir Horowitz']",
#   '0.35200000000000004',
#   '80800',
#   '0.132',
#   '0',
#   '6UxGTlqovmrBV4SKAsoz0A',
#   '0.966',
#   '8',
#   '0.425',
#   '-23.202',
#   '1',
#   'Etude in A-Flat, Op. 72, No. 11',
#   '0',
#   '1928',
#   '0.0381',
#   '74.737',
#   '0.6609999999999999',
#   '1928'],
#  ['0.99',
#   "['Francisco Canaro']",
#   '0.833',
#   '176000',
#   '0.132',
#   '0',
#   '6VGWQU6XIXshFT288CoLrk',
#   '0.0005679999999999999',
#   '1',
#   '0.0957',
#   '-11.130999999999998',
#   '1',
#   'Quisiste Cachar un Gil - Instrumental (Remasterizado)',
#   '0',
#   '1928-09-20',
#   '0.295',
#   '121.779',
#   '0.568',
#   '1928'],
#  ['0.975',
#   "['Frédéric Chopin', 'Vladimir Horowitz']",
#   '0.277',
#   '245440',
#   '0.09',
#   '0',
#   '6VUm7Dg5sufmG01IYcoJE3',
#   '0.949',
#   '7',
#   '0.125',
#   '-26.188',
#   '1',
#   'Andante spianato in E-Flat Major, Op. 22',
#   '0',
#   '1928',
#   '0.0316',
#   '105.031',
#   '0.168',
#   '1928'],
#  ['0.99',
#   "['Francisco Canaro']",
#   '0.8109999999999999',
#   '169720',
#   '0.175',
#   '0',
#   '6VqUdRHLlFMXmN4plGWSMA',
#   '0.841',
#   '9',
#   '0.13',
#   '-13.639',
#   '1',
#   'La Recova - Instrumental (Remasterizado)',
#   '0',
#   '1928-09-16',
#   '0.0712',
#   '115.212',
#   '0.933',
#   '1928'],
#  ['0.988',
#   "['Francisco Canaro', 'Charlo']",
#   '0.6990000000000001',
#   '166000',
#   '0.221',
#   '0',
#   '6W7iUeL4W0WVIF1BEOCswF',
#   '0.0725',
#   '11',
#   '0.142',
#   '-12.228',
#   '1',
#   'El Espejito - Remasterizado',
#   '0',
#   '1928-09-20',
#   '0.115',
#   '117.899',
#   '0.782',
#   '1928'],
#  ['0.988',
#   "['Roger Quilter', 'John Heddle Nash']",
#   '0.54',
#   '152600',
#   '0.102',
#   '0',
#   '6WBXyRc3ynwvRHiBWudVLo',
#   '2.13e-06',
#   '4',
#   '0.0819',
#   '-18.555',
#   '1',
#   'It Was a Lover and His Lass',
#   '0',
#   '1928',
#   '0.0792',
#   '73.516',
#   '0.433',
#   '1928'],
#  ['0.99',
#   "['Hafız Yaşar']",
#   '0.569',
#   '162197',
#   '0.327',
#   '0',
#   '6WFYaPHg3P8jQuh7x9YKYZ',
#   '0.947',
#   '7',
#   '0.134',
#   '-13.622',
#   '1',
#   'Kız Saçların',
#   '0',
#   '1928-05-07',
#   '0.0499',
#   '82.742',
#   '0.562',
#   '1928'],
#  ['0.991',
#   "['Frédéric Chopin', 'Vladimir Horowitz']",
#   '0.38',
#   '505920',
#   '0.119',
#   '0',
#   '6WRmg6x1bYjHxzeMCfKguB',
#   '0.89',
#   '11',
#   '0.0601',
#   '-21.255',
#   '1',
#   'Scherzo No. 1 in B Minor, Op. 20',
#   '0',
#   '1928',
#   '0.0389',
#   '132.005',
#   '0.18',
#   '1928'],
#  ['0.993',
#   "['Muzio Clementi', 'Vladimir Horowitz']",
#   '0.28',
#   '251960',
#   '0.0436',
#   '0',
#   '6WSYfri77xoUvXLg3WTdLF',
#   '0.885',
#   '8',
#   '0.0865',
#   '-25.958',
#   '1',
#   'Sonata, Op. 14, No. 3 in F Minor: I. Allegro agitato',
#   '0',
#   '1928',
#   '0.0393',
#   '81.07600000000002',
#   '0.182',
#   '1928'],
#  ['0.6859999999999999',
#   "['Seweryn Goszczyński']",
#   '0.715',
#   '102200',
#   '0.22',
#   '0',
#   '6XD6qJykJ91uC9AYb84ZeY',
#   '0.0',
#   '2',
#   '0.206',
#   '-19.788',
#   '1',
#   'Chapter 4.12 - Zamek kaniowski',
#   '0',
#   '1928',
#   '0.948',
#   '113.214',
#   '0.545',
#   '1928'],
#  ['0.995',
#   "['Francisco Canaro', 'Charlo']",
#   '0.767',
#   '177507',
#   '0.23',
#   '0',
#   '6XbXjlJZxRZslzXDh115DL',
#   '0.605',
#   '2',
#   '0.133',
#   '-10.728',
#   '1',
#   'Venite Conmigo - Remasterizado',
#   '0',
#   '1928-09-25',
#   '0.199',
#   '119.985',
#   '0.868',
#   '1928'],
#  ['0.995',
#   "['Ignacio Corsini']",
#   '0.531',
#   '159107',
#   '0.124',
#   '0',
#   '6XoyWGdCJwFaJV1Pnmphwr',
#   '0.0168',
#   '2',
#   '0.118',
#   '-23.243',
#   '1',
#   'Por una Mujer - Remasterizado',
#   '0',
#   '1928-05-14',
#   '0.0711',
#   '101.902',
#   '0.555',
#   '1928'],
#  ['0.422',
#   "['Shungi Music Crew']",
#   '0.662',
#   '372962',
#   '0.606',
#   '0',
#   '6XxKNIhZQsW1A5Sg6O32Is',
#   '0.915',
#   '7',
#   '0.0594',
#   '-7.026',
#   '0',
#   'Loving You',
#   '0',
#   '1928-08-20',
#   '0.0376',
#   '111.999',
#   '0.645',
#   '1928'],
#  ['0.987',
#   "['George Butterworth', 'John Cameron']",
#   '0.238',
#   '173293',
#   '0.0324',
#   '0',
#   '6Z6DJ8L7WMy2WHbXe3jR9I',
#   '0.000986',
#   '7',
#   '0.112',
#   '-24.361',
#   '0',
#   'A Shropshire Lad: Oh Fair Enough are Sky and Plain',
#   '0',
#   '1928',
#   '0.0541',
#   '172.321',
#   '0.0379',
#   '1928'],
#  ['0.983',
#   "['Ignacio Corsini']",
#   '0.6679999999999999',
#   '151840',
#   '0.261',
#   '0',
#   '6ZSXaYQBOPDDmKeqaOfBa2',
#   '0.0232',
#   '7',
#   '0.122',
#   '-16.91',
#   '0',
#   'Abuelita - Remasterizado',
#   '0',
#   '1928-05-14',
#   '0.101',
#   '120.553',
#   '0.7020000000000001',
#   '1928'],
#  ['0.989',
#   "['Perchicot']",
#   '0.769',
#   '140267',
#   '0.442',
#   '0',
#   '6ZWi1fuonJCUlt4p6o9Uzs',
#   '1.27e-06',
#   '2',
#   '0.16699999999999998',
#   '-12.697',
#   '0',
#   'La Noce À Rebecca',
#   '0',
#   '1928',
#   '0.273',
#   '132.125',
#   '0.934',
#   '1928'],
#  ['0.994',
#   "['Francisco Canaro', 'Charlo']",
#   '0.8009999999999999',
#   '166493',
#   '0.113',
#   '0',
#   '6aBzlB3FTioN5vCTfdswr8',
#   '0.206',
#   '4',
#   '0.129',
#   '-12.147',
#   '1',
#   'Por Esta Cruz - Remasterizado',
#   '0',
#   '1928-09-20',
#   '0.0837',
#   '117.063',
#   '0.672',
#   '1928'],
#  ['0.994',
#   "['Francisco Canaro']",
#   '0.8540000000000001',
#   '200213',
#   '0.151',
#   '0',
#   '6aNewFey3lEHDerGgy3rYN',
#   '0.371',
#   '4',
#   '0.159',
#   '-11.163',
#   '0',
#   'Che Bouhier - Instrumental (Remasterizado)',
#   '0',
#   '1928-09-16',
#   '0.13699999999999998',
#   '110.331',
#   '0.7809999999999999',
#   '1928'],
#  ['0.708',
#   "['Seweryn Goszczyński']",
#   '0.677',
#   '95900',
#   '0.204',
#   '0',
#   '6aXTusFB0Ycjmt9TXr2cfK',
#   '0.0',
#   '1',
#   '0.104',
#   '-20.024',
#   '0',
#   'Chapter 4.10 - Zamek kaniowski',
#   '0',
#   '1928',
#   '0.957',
#   '84.82600000000002',
#   '0.667',
#   '1928'],
#  ['0.777',
#   "['Seweryn Goszczyński']",
#   '0.738',
#   '139100',
#   '0.282',
#   '0',
#   '6bKJYhoaWIohnhspidbdW7',
#   '0.0',
#   '1',
#   '0.29',
#   '-16.555999999999994',
#   '1',
#   'Chapter 2.11 - Zamek kaniowski',
#   '0',
#   '1928',
#   '0.952',
#   '140.612',
#   '0.703',
#   '1928'],
#  ['0.977',
#   "['Frédéric Chopin', 'Vladimir Horowitz']",
#   '0.305',
#   '215267',
#   '0.083',
#   '0',
#   '6duqhjENDYbR2Q4Hpogh9M',
#   '0.6970000000000001',
#   '6',
#   '0.231',
#   '-20.895',
#   '1',
#   'Nocturne in F-Sharp Major, Op. 15, No. 2',
#   '1',
#   '1928',
#   '0.0331',
#   '80.622',
#   '0.0479',
#   '1928'],
#  ['0.993',
#   "['Dmitry Kabalevsky', 'Vladimir Horowitz']",
#   '0.3720000000000001',
#   '285133',
#   '0.0945',
#   '0',
#   '6h6ShFPagQGy48KSFd8BU9',
#   '0.941',
#   '10',
#   '0.189',
#   '-22.709',
#   '0',
#   'Sonata No. 3, Op. 46: II. Andante cantabile',
#   '0',
#   '1928',
#   '0.0317',
#   '59.217',
#   '0.0791',
#   '1928'],
#  ['0.99',
#   "['Frédéric Chopin', 'Vladimir Horowitz']",
#   '0.337',
#   '333907',
#   '0.0699',
#   '0',
#   '6hUMURfCaJ6JB8EWL1ZLr7',
#   '0.903',
#   '5',
#   '0.106',
#   '-23.806',
#   '0',
#   'Nocturne F Minor, Op. 55, No. 1',
#   '2',
#   '1928',
#   '0.0322',
#   '72.133',
#   '0.135',
#   '1928'],
#  ['0.995',
#   "['Francisco Canaro']",
#   '0.7290000000000001',
#   '174720',
#   '0.191',
#   '0',
#   '6hcPbniXegOud4FNv8Efxz',
#   '0.455',
#   '4',
#   '0.103',
#   '-15.313',
#   '0',
#   'Timbero - Instrumental (Remasterizado)',
#   '0',
#   '1928-09-17',
#   '0.108',
#   '112.565',
#   '0.902',
#   '1928'],
#  ['0.826',
#   "['Seweryn Goszczyński']",
#   '0.726',
#   '108800',
#   '0.249',
#   '0',
#   '6i3IWozMMPQXtD5W1klS0n',
#   '0.0',
#   '9',
#   '0.173',
#   '-16.82',
#   '0',
#   'Chapter 3.4 - Zamek kaniowski',
#   '0',
#   '1928',
#   '0.952',
#   '112.379',
#   '0.5589999999999999',
#   '1928'],
#  ['0.662',
#   "['Seweryn Goszczyński']",
#   '0.631',
#   '109900',
#   '0.23',
#   '0',
#   '6i7kom9nwTggWaYQAW9puH',
#   '0.0',
#   '1',
#   '0.145',
#   '-19.213',
#   '0',
#   'Chapter 1.13 - Zamek kaniowski',
#   '0',
#   '1928',
#   '0.959',
#   '83.40100000000002',
#   '0.595',
#   '1928'],
#  ['0.985',
#   "['Francisco Canaro']",
#   '0.81',
#   '169160',
#   '0.3',
#   '0',
#   '6iInEwECoC9ZX8uPDRjyft',
#   '0.0008849999999999998',
#   '4',
#   '0.13',
#   '-9.702',
#   '1',
#   'Mariposa de Cabaret - Instrumental (Remasterizado)',
#   '0',
#   '1928-09-25',
#   '0.289',
#   '115.648',
#   '0.8059999999999999',
#   '1928'],
#  ['0.985',
#   "['Frédéric Chopin', 'Vladimir Horowitz']",
#   '0.355',
#   '138013',
#   '0.0452',
#   '0',
#   '6j8nMxm9yFxN3Mdodm9tEl',
#   '0.825',
#   '1',
#   '0.153',
#   '-24.125',
#   '1',
#   'Mazurka in F Minor, Op. 7, No. 3',
#   '2',
#   '1928',
#   '0.0329',
#   '84.551',
#   '0.276',
#   '1928'],
#  ['0.461',
#   "['Shungi Music Crew']",
#   '0.733',
#   '369721',
#   '0.613',
#   '0',
#   '6jIUK38SalSc8jYFLW4FYv',
#   '0.951',
#   '7',
#   '0.122',
#   '-8.749',
#   '1',
#   'Rumours',
#   '0',
#   '1928-08-20',
#   '0.0383',
#   '123.019',
#   '0.26',
#   '1928'],
#  ['0.993',
#   "['Franz Liszt', 'Vladimir Horowitz']",
#   '0.303',
#   '491333',
#   '0.226',
#   '0',
#   '6jm4s7lONpJRXumjV6WH23',
#   '0.826',
#   '3',
#   '0.119',
#   '-21.483',
#   '1',
#   'Danse macabre, S. 555 (after Camille Saint-Saens)',
#   '0',
#   '1928',
#   '0.0444',
#   '67.013',
#   '0.146',
#   '1928'],
#  ['0.995',
#   "['Robert Schumann', 'Vladimir Horowitz']",
#   '0.319',
#   '118093',
#   '0.00217',
#   '0',
#   '6jpxi5YTFfquMKm7HLS0fW',
#   '0.937',
#   '10',
#   '0.0791',
#   '-36.905',
#   '1',
#   'Humoreske, Op. 20: Einfach',
#   '0',
#   '1928',
#   '0.0412',
#   '78.505',
#   '0.229',
#   '1928'],
#  ['0.992',
#   "['Robert Schumann', 'Vladimir Horowitz']",
#   '0.468',
#   '158973',
#   '0.0184',
#   '0',
#   '6k3zky8VRvpPo9T5dqWbKS',
#   '0.912',
#   '10',
#   '0.103',
#   '-27.785',
#   '1',
#   'Humoreske, Op. 20: Innig',
#   '0',
#   '1928',
#   '0.0447',
#   '59.38',
#   '0.235',
#   '1928'],
#  ['0.992',
#   "['Ignacio Corsini']",
#   '0.698',
#   '168400',
#   '0.192',
#   '0',
#   '6k6oWqs8cZnnjY38LdP08T',
#   '0.00577',
#   '2',
#   '0.243',
#   '-17.343',
#   '1',
#   'La Carreta - Remasterizado',
#   '0',
#   '1928-05-14',
#   '0.128',
#   '78.218',
#   '0.6809999999999999',
#   '1928'],
#  ['0.993',
#   "['Francisco Canaro', 'Charlo']",
#   '0.836',
#   '194000',
#   '0.207',
#   '0',
#   '6kfj3G8mZQH4n530vJen6L',
#   '0.522',
#   '7',
#   '0.321',
#   '-9.54',
#   '1',
#   'Dentra, No Llores - Remasterizado',
#   '0',
#   '1928-10-03',
#   '0.152',
#   '112.369',
#   '0.595',
#   '1928'],
#  ['0.992',
#   "['Frédéric Chopin', 'Vladimir Horowitz']",
#   '0.233',
#   '519933',
#   '0.113',
#   '0',
#   '6l4zbFqen97rgCxmq9LWgK',
#   '0.879',
#   '1',
#   '0.161',
#   '-18.276',
#   '1',
#   'Barcarolle, Op. 60',
#   '0',
#   '1928',
#   '0.0397',
#   '64.082',
#   '0.0642',
#   '1928'],
#  ['0.993',
#   "['Paul Whiteman']",
#   '0.6409999999999999',
#   '161587',
#   '0.192',
#   '0',
#   '6m2U5lsHxlDvCUl6aZzCLO',
#   '0.5',
#   '3',
#   '0.593',
#   '-15.905',
#   '1',
#   "I'd Rather Cry Over You",
#   '0',
#   '1928',
#   '0.04',
#   '106.052',
#   '0.7040000000000001',
#   '1928'],
#  ['0.995',
#   "['Francisco Canaro', 'Charlo']",
#   '0.461',
#   '204867',
#   '0.195',
#   '0',
#   '6mUmlFMnIKz3m8rIDnzwd0',
#   '0.8859999999999999',
#   '10',
#   '0.0969',
#   '-15.059',
#   '1',
#   'En un Pueblito de España - Remasterizado',
#   '0',
#   '1928-09-21',
#   '0.0609',
#   '76.419',
#   '0.8440000000000001',
#   '1928'],
#  ['0.989',
#   "['Muzio Clementi', 'Vladimir Horowitz']",
#   '0.222',
#   '351000',
#   '0.0113',
#   '0',
#   '6mUr9qArNrSpsXeWIL2Go0',
#   '0.954',
#   '5',
#   '0.0873',
#   '-33.218',
#   '1',
#   'Sonata quasi Concerto, Op. 33, No. 3 in C: II. Adagio e cantabile, con espressione',
#   '0',
#   '1928',
#   '0.043',
#   '74.04',
#   '0.0917',
#   '1928'],
#  ['0.991',
#   "['Ignacio Corsini']",
#   '0.431',
#   '108573',
#   '0.315',
#   '0',
#   '6mlX2fWNqtclyBUAyBHNQ5',
#   '0.883',
#   '11',
#   '0.108',
#   '-21.753',
#   '0',
#   'Caido del Cielo - Remasterizado',
#   '0',
#   '1928-05-14',
#   '0.0464',
#   '65.735',
#   '0.711',
#   '1928'],
#  ['0.991',
#   "['Ted Weems & His Orchestra']",
#   '0.8390000000000001',
#   '162147',
#   '0.37',
#   '0',
#   '6myKdOFzdAkk3npbTVrzFg',
#   '0.0419',
#   '2',
#   '0.104',
#   '-11.602',
#   '1',
#   'Chick, Chick, Chick, Chick, Chicken - Lay A Little Egg For Me',
#   '1',
#   '1928-07-01',
#   '0.08',
#   '115.063',
#   '0.976',
#   '1928'],
#  ['0.991',
#   "['Francisco Canaro', 'Charlo']",
#   '0.8290000000000001',
#   '175493',
#   '0.199',
#   '0',
#   '6nRuUkty1Wsn3rPZgfpZ9F',
#   '6.54e-06',
#   '10',
#   '0.119',
#   '-9.2',
#   '0',
#   'Triste Paica - Remasterizado',
#   '0',
#   '1928-09-20',
#   '0.0619',
#   '116.214',
#   '0.6809999999999999',
#   '1928'],
#  ['0.99',
#   "['Ignacio Corsini']",
#   '0.7090000000000001',
#   '130813',
#   '0.14800000000000002',
#   '0',
#   '6nxEIdbSzOtdi93IskacDT',
#   '0.0262',
#   '3',
#   '0.131',
#   '-18.933',
#   '0',
#   'Piedad - Remasterizado',
#   '0',
#   '1928-05-14',
#   '0.0775',
#   '122.415',
#   '0.516',
#   '1928'],
#  ['0.872',
#   "['Taj Mahal']",
#   '0.5710000000000001',
#   '155893',
#   '0.204',
#   '0',
#   '6oZyWbbisoG8jOunmpPH40',
#   '0.779',
#   '6',
#   '0.197',
#   '-18.61',
#   '1',
#   'Country Blues #1',
#   '0',
#   '1928',
#   '0.0328',
#   '129.289',
#   '0.0932',
#   '1928'],
#  ['0.991',
#   "['Francisco Canaro']",
#   '0.8079999999999999',
#   '194413',
#   '0.215',
#   '0',
#   '6p5vkrnb0SdBxqHXNPn8Zs',
#   '0.524',
#   '9',
#   '0.0906',
#   '-12.205',
#   '1',
#   'La Cabeza del Italiano - Instrumental (Remasterizado)',
#   '0',
#   '1928-09-17',
#   '0.0851',
#   '110.894',
#   '0.866',
#   '1928'],
#  ['0.989',
#   "['Robert Schumann', 'Vladimir Horowitz']",
#   '0.368',
#   '163800',
#   '0.124',
#   '0',
#   '6p8Q6LG6m1kxAzTbUyIWN3',
#   '0.892',
#   '0',
#   '0.105',
#   '-21.742',
#   '0',
#   'Humoreske, Op. 20: Intermezzo',
#   '0',
#   '1928',
#   '0.0371',
#   '128.418',
#   '0.266',
#   '1928'],
#  ['0.732',
#   "['Seweryn Goszczyński']",
#   '0.72',
#   '100700',
#   '0.28600000000000003',
#   '0',
#   '6qxoAGlWUrVYbvq3x6S08C',
#   '0.0',
#   '5',
#   '0.292',
#   '-15.861',
#   '1',
#   'Chapter 2.23 - Zamek kaniowski',
#   '0',
#   '1928',
#   '0.939',
#   '114.059',
#   '0.695',
#   '1928'],
#  ['0.991',
#   "['Muzio Clementi', 'Vladimir Horowitz']",
#   '0.317',
#   '214667',
#   '0.0916',
#   '0',
#   '6rIuHOee0surqjlxUWHruQ',
#   '0.918',
#   '10',
#   '0.104',
#   '-30.682',
#   '1',
#   'Rondo, No. 2',
#   '0',
#   '1928',
#   '0.0411',
#   '80.74',
#   '0.511',
#   '1928'],
#  ['0.947',
#   "['John Raitt']",
#   '0.333',
#   '122733',
#   '0.146',
#   '0',
#   '6rd3MB90B6JcMzSsxTVX5P',
#   '0.000426',
#   '2',
#   '0.265',
#   '-16.99',
#   '1',
#   "Where's the Mate for Me?",
#   '2',
#   '1928',
#   '0.0353',
#   '75.372',
#   '0.234',
#   '1928'],
#  ['0.986',
#   "['Francisco Canaro']",
#   '0.613',
#   '303493',
#   '0.187',
#   '0',
#   '6sHTmkp6k8genhaEHK5NxF',
#   '0.804',
#   '1',
#   '0.111',
#   '-13.959',
#   '1',
#   'Pájaro Azul - Instrumental (Remasterizado)',
#   '0',
#   '1928-09-21',
#   '0.255',
#   '116.325',
#   '0.3',
#   '1928'],
#  ['0.977',
#   "['Ted Weems & His Orchestra']",
#   '0.757',
#   '180147',
#   '0.49',
#   '0',
#   '6t2heLDAa5eqqLZM6yyDKw',
#   '0.043',
#   '10',
#   '0.0885',
#   '-9.198',
#   '1',
#   'It Was Only A Sun Shower',
#   '0',
#   '1928-07-01',
#   '0.035',
#   '105.734',
#   '0.836',
#   '1928'],
#  ['0.974',
#   "['Frédéric Chopin', 'Vladimir Horowitz']",
#   '0.188',
#   '236493',
#   '0.0891',
#   '0',
#   '6tD8hbtg9YvauF84fl15sd',
#   '0.8959999999999999',
#   '0',
#   '0.124',
#   '-25.936',
#   '1',
#   'Andante spianato in E-Flat Major, Op. 22',
#   '3',
#   '1928',
#   '0.0326',
#   '59.94600000000001',
#   '0.16399999999999998',
#   '1928'],
#  ['0.989',
#   "['Francisco Canaro']",
#   '0.858',
#   '168413',
#   '0.249',
#   '0',
#   '6tmVNRSYKtvrfhuuPnn7JK',
#   '8.79e-05',
#   '2',
#   '0.181',
#   '-8.897',
#   '1',
#   'Che Italiano - Instrumental (Remasterizado)',
#   '0',
#   '1928-09-16',
#   '0.224',
#   '115.858',
#   '0.611',
#   '1928'],
#  ['0.989',
#   "['Paul Whiteman']",
#   '0.441',
#   '201053',
#   '0.0454',
#   '0',
#   '6u4X5c1kV7hZrlMOD3FAco',
#   '0.0752',
#   '7',
#   '0.0801',
#   '-21.884',
#   '1',
#   'Chiquita',
#   '0',
#   '1928',
#   '0.0463',
#   '133.475',
#   '0.194',
#   '1928'],
#  ['0.996',
#   "['Ignacio Corsini']",
#   '0.675',
#   '145973',
#   '0.127',
#   '0',
#   '6uORAJwv0yYp917APJP8Be',
#   '0.0311',
#   '3',
#   '0.102',
#   '-21.612',
#   '1',
#   'Destellos - Remasterizado',
#   '0',
#   '1928-05-14',
#   '0.226',
#   '129.58700000000002',
#   '0.516',
#   '1928'],
#  ['0.987',
#   "['Samuel Barber', 'Vladimir Horowitz']",
#   '0.242',
#   '115627',
#   '0.149',
#   '0',
#   '6v13FCz4z385EbNyPaXYCU',
#   '0.877',
#   '0',
#   '0.134',
#   '-26.742',
#   '1',
#   'Piano Sonata in E-Flat Minor, Op. 26: II. Allegro vivace e leggero',
#   '0',
#   '1928',
#   '0.0369',
#   '88.18799999999996',
#   '0.279',
#   '1928'],
#  ['0.99',
#   "['Frédéric Chopin', 'Vladimir Horowitz']",
#   '0.444',
#   '104013',
#   '0.0431',
#   '0',
#   '6vK4MMy5CNIUNvFXlG9NuF',
#   '0.889',
#   '1',
#   '0.124',
#   '-26.77',
#   '1',
#   'Étude in G-Flat Major, Op. 10, No. 5 "Black Keys"',
#   '1',
#   '1928',
#   '0.041',
#   '106.062',
#   '0.404',
#   '1928'],
#  ['0.725',
#   "['Seweryn Goszczyński']",
#   '0.7909999999999999',
#   '107800',
#   '0.234',
#   '0',
#   '6vniIHqoSV74xRTMdomqij',
#   '0.0',
#   '8',
#   '0.152',
#   '-17.951',
#   '1',
#   'Chapter 2.16 - Zamek kaniowski',
#   '0',
#   '1928',
#   '0.947',
#   '37.596',
#   '0.705',
#   '1928'],
#  ['0.99',
#   "['Frédéric Chopin', 'Vladimir Horowitz']",
#   '0.272',
#   '473227',
#   '0.281',
#   '0',
#   '6wt8PKNBSqNFqdOxgexvKu',
#   '0.867',
#   '10',
#   '0.087',
#   '-16.227999999999998',
#   '0',
#   'Piano Sonata No. 2, Op. 35: I. Grave - Doppio movimento',
#   '0',
#   '1928',
#   '0.0365',
#   '99.27',
#   '0.0775',
#   '1928'],
#  ['0.993',
#   "['Francisco Canaro', 'Charlo']",
#   '0.466',
#   '204000',
#   '0.161',
#   '0',
#   '6x09M8ELRKDbwPH1y1uTje',
#   '0.764',
#   '6',
#   '0.118',
#   '-13.007',
#   '0',
#   'Always - Remasterizado',
#   '0',
#   '1928-09-25',
#   '0.0576',
#   '75.24',
#   '0.447',
#   '1928'],
#  ['0.989',
#   "['Frédéric Chopin', 'Vladimir Horowitz']",
#   '0.28',
#   '254107',
#   '0.0463',
#   '0',
#   '6xpA90VSHtmaUhNltHIcVM',
#   '0.873',
#   '11',
#   '0.0743',
#   '-19.78',
#   '1',
#   'Nocturne in E Minor, Op. 72, No. 1',
#   '1',
#   '1928',
#   '0.0347',
#   '100.131',
#   '0.0722',
#   '1928'],
#  ['0.995',
#   "['Robert Schumann', 'Vladimir Horowitz']",
#   '0.389',
#   '94307',
#   '0.263',
#   '0',
#   '6yOkXNFTUxZpnXXu1yJT3l',
#   '0.914',
#   '5',
#   '0.128',
#   '-15.034',
#   '0',
#   'Sonata No. 3, Op. 14: III: Variation II',
#   '0',
#   '1928',
#   '0.0354',
#   '73.98100000000002',
#   '0.188',
#   '1928'],
#  ['0.993',
#   "['Paul Whiteman']",
#   '0.523',
#   '202173',
#   '0.0867',
#   '0',
#   '6yanEXQBzoNKlWJzKGBpsb',
#   '0.124',
#   '10',
#   '0.14',
#   '-17.528',
#   '1',
#   'Reaching for Someone (And Not Finding Anyone There)',
#   '1',
#   '1928',
#   '0.0707',
#   '161.687',
#   '0.6970000000000001',
#   '1928'],
#  ['0.918',
#   "['Leroy Carr']",
#   '0.754',
#   '184840',
#   '0.194',
#   '0',
#   '6yx49288aRqkexZC1BoldM',
#   '4.34e-05',
#   '3',
#   '0.188',
#   '-11.634',
#   '1',
#   'Midnight Hour Blues',
#   '1',
#   '1928',
#   '0.053',
#   '84.042',
#   '0.454',
#   '1928'],
#  ['0.992',
#   "['Frédéric Chopin', 'Vladimir Horowitz']",
#   '0.301',
#   '785427',
#   '0.0823',
#   '0',
#   '71FaVeFy9ZOiQRY4yOijey',
#   '0.852',
#   '1',
#   '0.087',
#   '-23.282',
#   '1',
#   'Polonaise-Fantaisie in A-Flat Major, Op. 61',
#   '0',
#   '1928',
#   '0.0382',
#   '137.296',
#   '0.0548',
#   '1928'],
#  ['0.993',
#   "['Frédéric Chopin', 'Vladimir Horowitz']",
#   '0.409',
#   '318267',
#   '0.0224',
#   '0',
#   '722u6arjn98Ygql8TyqKZz',
#   '0.908',
#   '1',
#   '0.13',
#   '-18.234',
#   '1',
#   'Nocturne in C-Sharp Minor, Op. 27, No. 1 - 2001 Remastered',
#   '1',
#   '1928',
#   '0.0441',
#   '126.458',
#   '0.0655',
#   '1928'],
#  ['0.995',
#   "['Alexander Scriabin', 'Vladimir Horowitz']",
#   '0.411',
#   '97627',
#   '0.211',
#   '0',
#   '72f1VDD6VELfZybK1Wkggy',
#   '0.8759999999999999',
#   '2',
#   '0.106',
#   '-16.423',
#   '0',
#   'Preludes: Op. 59, No. 2',
#   '0',
#   '1928',
#   '0.0489',
#   '79.812',
#   '0.119',
#   '1928'],
#  ['0.992',
#   "['Dmitry Kabalevsky', 'Vladimir Horowitz']",
#   '0.266',
#   '350373',
#   '0.242',
#   '0',
#   '72iGv3PppJRsZwfT5ntZps',
#   '0.915',
#   '10',
#   '0.154',
#   '-19.283',
#   '0',
#   'Sonata No. 3, Op. 46: I. Allegro con moto',
#   '0',
#   '1928',
#   '0.0314',
#   '86.43700000000004',
#   '0.114',
#   '1928'],
#  ['0.777',
#   "['Seweryn Goszczyński']",
#   '0.748',
#   '110200',
#   '0.295',
#   '0',
#   '72vD6lhG8KohMxjGqkKzBX',
#   '0.0',
#   '9',
#   '0.122',
#   '-16.945',
#   '1',
#   'Chapter 3.14 - Zamek kaniowski',
#   '0',
#   '1928',
#   '0.94',
#   '114.431',
#   '0.7170000000000001',
#   '1928'],
#  ['0.994',
#   "['Francisco Canaro']",
#   '0.79',
#   '160000',
#   '0.171',
#   '0',
#   '73LY41HCJzlQwoNBmWM7Md',
#   '0.0562',
#   '5',
#   '0.116',
#   '-13.993',
#   '1',
#   '¿Te Acuerdas Mamita? - Instrumental (Remasterizado)',
#   '0',
#   '1928-09-20',
#   '0.221',
#   '121.646',
#   '0.856',
#   '1928'],
#  ['0.995',
#   "['Ignacio Corsini']",
#   '0.579',
#   '136160',
#   '0.33',
#   '0',
#   '747Dowy6MecKApVkFH1asI',
#   '0.94',
#   '1',
#   '0.108',
#   '-20.558000000000003',
#   '1',
#   'Quema Esas Cartas - Remasterizado',
#   '0',
#   '1928-05-14',
#   '0.055',
#   '134.545',
#   '0.89',
#   '1928'],
#  ['0.995',
#   "['Robert Schumann', 'Vladimir Horowitz']",
#   '0.316',
#   '76960',
#   '0.191',
#   '0',
#   '74qEIULd05bBGGtWiCglvC',
#   '0.914',
#   '10',
#   '0.101',
#   '-16.249000000000002',
#   '0',
#   'Sonata No. 3, Op. 14: III: Variation III',
#   '0',
#   '1928',
#   '0.0389',
#   '109.331',
#   '0.18',
#   '1928'],
#  ['0.991',
#   "['Frédéric Chopin', 'Vladimir Horowitz']",
#   '0.245',
#   '340973',
#   '0.0577',
#   '0',
#   '74rczPEWk2w3Fl8eENpzuf',
#   '0.882',
#   '5',
#   '0.0704',
#   '-24.98',
#   '0',
#   'Nocturne F Minor, Op. 55, No. 1',
#   '0',
#   '1928',
#   '0.0328',
#   '74.00399999999998',
#   '0.105',
#   '1928'],
#  ['0.992',
#   "['Francisco Canaro', 'Charlo']",
#   '0.78',
#   '161000',
#   '0.238',
#   '0',
#   '757cWe7lwe0BjpY1IRigot',
#   '0.0355',
#   '3',
#   '0.108',
#   '-13.552',
#   '0',
#   'Tu Disfraz - Remasterizado',
#   '0',
#   '1928-09-20',
#   '0.209',
#   '121.064',
#   '0.8440000000000001',
#   '1928'],
#  ['0.995',
#   "['Hikmet Rıza Hanım']",
#   '0.449',
#   '159496',
#   '0.16899999999999998',
#   '0',
#   '75AyIcNnQzdiYln6BQJeps',
#   '0.8320000000000001',
#   '7',
#   '0.0999',
#   '-12.993',
#   '0',
#   'Ayva Çiçek Açmış',
#   '0',
#   '1928-05-11',
#   '0.0497',
#   '66.372',
#   '0.413',
#   '1928'],
#  ['0.993',
#   "['Francisco Canaro']",
#   '0.7659999999999999',
#   '184000',
#   '0.203',
#   '0',
#   '75PDI4YUCg84Y0Nt0KAKa1',
#   '0.16899999999999998',
#   '2',
#   '0.147',
#   '-10.142',
#   '0',
#   'Emoción - Instrumental (Remasterizado)',
#   '0',
#   '1928-09-25',
#   '0.0728',
#   '116.415',
#   '0.6920000000000001',
#   '1928'],
#  ['0.995',
#   "['Ignacio Corsini']",
#   '0.599',
#   '135507',
#   '0.13699999999999998',
#   '0',
#   '75Tt3zPHlYnejhusIUy50f',
#   '0.305',
#   '5',
#   '0.132',
#   '-22.342',
#   '0',
#   'Cualquier Cosa - Remasterizado',
#   '0',
#   '1928-05-14',
#   '0.161',
#   '137.384',
#   '0.687',
#   '1928'],
#  ['0.994',
#   "['Francisco Canaro', 'Charlo']",
#   '0.615',
#   '170000',
#   '0.205',
#   '0',
#   '75vvVnUqj8PlyJBAZ494p3',
#   '0.913',
#   '2',
#   '0.113',
#   '-13.837',
#   '1',
#   'Pobre Gaucho - Remasterizado',
#   '0',
#   '1928-10-03',
#   '0.0618',
#   '58.299',
#   '0.752',
#   '1928'],
#  ['0.996',
#   "['Alexander Scriabin', 'Vladimir Horowitz']",
#   '0.278',
#   '288907',
#   '0.0049',
#   '0',
#   '75yPZGkLb31Q4dRFqzMF5z',
#   '0.932',
#   '11',
#   '0.0954',
#   '-31.442',
#   '1',
#   'Sonata No. 3, Op. 23 in F-Sharp Minor: III. Andante',
#   '0',
#   '1928',
#   '0.0407',
#   '81.033',
#   '0.0606',
#   '1928'],
#  ['0.996',
#   "['Alexander Scriabin', 'Vladimir Horowitz']",
#   '0.393',
#   '48627',
#   '0.0545',
#   '0',
#   '75zIt9muIwtL6o30PcqskO',
#   '0.8290000000000001',
#   '7',
#   '0.328',
#   '-27.582',
#   '1',
#   'Preludes: Op. 11, No. 3 in G',
#   '0',
#   '1928',
#   '0.0366',
#   '70.495',
#   '0.374',
#   '1928'],
#  ['0.105',
#   "['Shungi Music Crew']",
#   '0.6990000000000001',
#   '388115',
#   '0.838',
#   '0',
#   '764wHEOb2yPgsJHmU0J4ZS',
#   '0.909',
#   '7',
#   '0.128',
#   '-12.106',
#   '1',
#   'Trip to Limpopo',
#   '0',
#   '1928-08-20',
#   '0.0462',
#   '123.993',
#   '0.481',
#   '1928'],
#  ['0.981',
#   "['Elsie Houston']",
#   '0.78',
#   '117362',
#   '0.55',
#   '0',
#   '3yH0dcIQudG7VcC0kB4T8V',
#   '0.122',
#   '4',
#   '0.165',
#   '-11.095999999999998',
#   '0',
#   'Óia o Sapo',
#   '0',
#   '1930-12-31',
#   '0.396',
#   '83.383',
#   '0.847',
#   '1930'],
#  ['0.991',
#   "['Ignacio Corsini']",
#   '0.545',
#   '168653',
#   '0.133',
#   '0',
#   '3yZj8i9TwsWAVmBWKdMbaa',
#   '0.444',
#   '7',
#   '0.115',
#   '-20.53',
#   '0',
#   'Cobardia - Remasterizado',
#   '0',
#   '1930-06-21',
#   '0.127',
#   '185.062',
#   '0.691',
#   '1930'],
#  ['0.995',
#   "['Francisco Canaro']",
#   '0.746',
#   '186000',
#   '0.159',
#   '0',
#   '3yqMsVEs3Fq3jzsibskXeY',
#   '0.8190000000000001',
#   '8',
#   '0.109',
#   '-15.106',
#   '1',
#   'Asuero - Instrumental (Remasterizado)',
#   '0',
#   '1930-11-20',
#   '0.189',
#   '120.084',
#   '0.88',
#   '1930'],
#  ['0.981',
#   "['Αντώνης Νταλγκάς']",
#   '0.273',
#   '200693',
#   '0.0958',
#   '0',
#   '3ysZe4AZtpys3VbZabN0Nh',
#   '0.00109',
#   '1',
#   '0.637',
#   '-20.217',
#   '1',
#   'Μπεστενγκιάρ μανές',
#   '0',
#   '1930-01-01',
#   '0.0465',
#   '86.281',
#   '0.18',
#   '1930'],
#  ['0.982',
#   "['Stellakis Perpiniadis']",
#   '0.503',
#   '188120',
#   '0.46',
#   '0',
#   '3zFy6I5USXgmG18E3f1971',
#   '0.78',
#   '9',
#   '0.157',
#   '-9.289',
#   '0',
#   'O milonas',
#   '0',
#   '1930-01-01',
#   '0.0454',
#   '79.26899999999998',
#   '0.909',
#   '1930'],
#  ['0.989',
#   "['Αντώνης Διαμαντίδης']",
#   '0.414',
#   '165520',
#   '0.229',
#   '0',
#   '3zGslzrt12d41TKH7xBO5R',
#   '0.00067',
#   '7',
#   '0.121',
#   '-10.564',
#   '1',
#   'Θεοδωράκης Γρίβας',
#   '0',
#   '1930-01-01',
#   '0.0587',
#   '74.796',
#   '0.325',
#   '1930'],
#  ['0.992',
#   "['S. Loukopoulos', 'Klarino G. Anestopoulos', 'Klarino KOstas Giaouzos', 'Klarinos Nikos Karakostas']",
#   '0.368',
#   '204840',
#   '0.263',
#   '0',
#   '3zK60VaQyLm9Tbrji7v4eX',
#   '0.89',
#   '9',
#   '0.28800000000000003',
#   '-16.262999999999998',
#   '1',
#   'Xipna Pouli Mou To Proi',
#   '0',
#   '1930-01-01',
#   '0.0476',
#   '101.447',
#   '0.312',
#   '1930'],
#  ['0.996',
#   "['Paradosiako I. KIriakatis']",
#   '0.342',
#   '178154',
#   '0.308',
#   '0',
#   '3zYsOagWsmCQ0OwREYFxJ2',
#   '0.903',
#   '0',
#   '0.14',
#   '-13.483',
#   '1',
#   'Kenouria Logia',
#   '0',
#   '1930-01-01',
#   '0.0564',
#   '74.733',
#   '0.949',
#   '1930'],
#  ['0.951',
#   "['Moune De Rivel']",
#   '0.69',
#   '169509',
#   '0.7140000000000001',
#   '0',
#   '3zhptXjoaB6EF8WUtde9iA',
#   '0.000348',
#   '0',
#   '0.234',
#   '-15.857',
#   '0',
#   'Kiembeli',
#   '2',
#   '1930-01-01',
#   '0.0747',
#   '116.188',
#   '0.804',
#   '1930'],
#  ['0.994',
#   "['Dimitris Gkogkos']",
#   '0.552',
#   '194880',
#   '0.275',
#   '0',
#   '402nzcLa8CkqfeD3GzEy6j',
#   '0.8290000000000001',
#   '11',
#   '0.11',
#   '-12.746',
#   '0',
#   'Matia glika kai galana',
#   '0',
#   '1930-01-01',
#   '0.0599',
#   '117.057',
#   '0.544',
#   '1930'],
#  ['0.962',
#   "['Giorgos Papasideris']",
#   '0.32',
#   '185307',
#   '0.529',
#   '0',
#   '404Vsdauw3WGz3FG8Qwv9A',
#   '0.392',
#   '9',
#   '0.117',
#   '-7.449',
#   '1',
#   'Kalikie',
#   '0',
#   '1930-01-01',
#   '0.0474',
#   '79.649',
#   '0.858',
#   '1930'],
#  ['0.994',
#   "['Petros Epitropakis', 'Antonis Kalampousis']",
#   '0.14400000000000002',
#   '211399',
#   '0.331',
#   '0',
#   '40AkLtfyKR89OxRaf3X9zh',
#   '0.88',
#   '4',
#   '0.145',
#   '-13.406',
#   '0',
#   'San Oneiro',
#   '0',
#   '1930-01-01',
#   '0.0428',
#   '71.956',
#   '0.16399999999999998',
#   '1930'],
#  ['0.29',
#   "['Cellular Project']",
#   '0.344',
#   '192332',
#   '0.857',
#   '0',
#   '40P3zk2IX1Iannfbz89mO2',
#   '0.8740000000000001',
#   '3',
#   '0.125',
#   '-5.441',
#   '1',
#   'Purple Daze',
#   '0',
#   '1930',
#   '0.0507',
#   '140.66899999999998',
#   '0.158',
#   '1930'],
#  ['0.971',
#   "['Francisco Canaro', 'Luis Diaz']",
#   '0.807',
#   '207493',
#   '0.202',
#   '0',
#   '40c7MoKLp6KVavEdHLBINz',
#   '0.161',
#   '6',
#   '0.0561',
#   '-13.675',
#   '1',
#   'Cascabeles - Remasterizado',
#   '0',
#   '1930-12-03',
#   '0.184',
#   '115.364',
#   '0.8859999999999999',
#   '1930'],
#  ['0.989',
#   "['Francisco Canaro', 'Charlo']",
#   '0.445',
#   '185507',
#   '0.28800000000000003',
#   '0',
#   '40jiorcB4ujhNCJEM3NYRz',
#   '0.758',
#   '2',
#   '0.111',
#   '-8.925',
#   '1',
#   'Cantando Bajo la Lluvia - Remasterizado',
#   '0',
#   '1930-11-12',
#   '0.0699',
#   '205.423',
#   '0.6970000000000001',
#   '1930'],
#  ['0.996',
#   "['Sotiris Stasinopoulos']",
#   '0.269',
#   '271560',
#   '0.319',
#   '0',
#   '40lNmAqzsDxT1aV39oakv4',
#   '0.882',
#   '7',
#   '0.196',
#   '-16.218',
#   '1',
#   'Kovo Mia Klara',
#   '0',
#   '1930-01-01',
#   '0.0514',
#   '75.833',
#   '0.447',
#   '1930'],
#  ['0.971',
#   "['Nota Kaleli']",
#   '0.74',
#   '30000',
#   '0.508',
#   '0',
#   '40q1O23P19AcDSghky2Ct3',
#   '0.946',
#   '2',
#   '0.134',
#   '-11.353',
#   '1',
#   'Pagkratiotissa mou',
#   '0',
#   '1930-01-01',
#   '0.063',
#   '76.43',
#   '0.967',
#   '1930'],
#  ['0.87',
#   "['Robert Francis']",
#   '0.353',
#   '137090',
#   '0.0785',
#   '0',
#   '41FFRKj6ehfOer45QC85mm',
#   '2.21e-06',
#   '0',
#   '0.112',
#   '-18.434',
#   '0',
#   'My Funny Valentine',
#   '2',
#   '1930',
#   '0.0376',
#   '70.535',
#   '0.261',
#   '1930'],
#  ['0.99',
#   "['Francisco Canaro', 'Roberto Maida']",
#   '0.518',
#   '174493',
#   '0.462',
#   '0',
#   '41fXcqGebIUYOFQvDzqLJG',
#   '0.85',
#   '4',
#   '0.157',
#   '-9.632',
#   '0',
#   'A Lo Lejos - Remasterizado',
#   '0',
#   '1930-12-03',
#   '0.377',
#   '178.88',
#   '0.696',
#   '1930'],
#  ['0.991',
#   "['The Caresser']",
#   '0.574',
#   '189571',
#   '0.3720000000000001',
#   '0',
#   '41ot3rSkTwJ7tLBut2jmH5',
#   '0.000129',
#   '4',
#   '0.877',
#   '-9.888',
#   '0',
#   'Edward the VIII',
#   '1',
#   '1930-01-01',
#   '0.0592',
#   '88.836',
#   '0.8740000000000001',
#   '1930'],
#  ['0.991',
#   "['Soula Karagiorgi']",
#   '0.358',
#   '182733',
#   '0.35',
#   '0',
#   '41uoJrpHQhmOAkcXtKsAk3',
#   '0.0387',
#   '2',
#   '0.348',
#   '-13.585',
#   '1',
#   'Skliri Kardia',
#   '0',
#   '1930-01-01',
#   '0.0392',
#   '113.337',
#   '0.305',
#   '1930'],
#  ['0.779',
#   "['The Merlons']",
#   '0.4270000000000001',
#   '128707',
#   '0.531',
#   '0',
#   '41wmjlc9ChMBHZ8fB0btdM',
#   '0.978',
#   '0',
#   '0.145',
#   '-16.675',
#   '1',
#   'Loda',
#   '0',
#   '1930',
#   '0.0325',
#   '110.993',
#   '0.353',
#   '1930'],
#  ['0.994',
#   "['Francisco Canaro', 'Charlo', 'Angel Ramos']",
#   '0.6',
#   '202000',
#   '0.174',
#   '0',
#   '4285vY2v7Z1Kyh3Gi3sDrz',
#   '0.805',
#   '4',
#   '0.173',
#   '-9.047',
#   '1',
#   'Clavel del Aire - Remasterizado',
#   '0',
#   '1930-11-13',
#   '0.0449',
#   '118.107',
#   '0.594',
#   '1930'],
#  ['0.977',
#   "['Κώστας Δούσιας']",
#   '0.611',
#   '240160',
#   '0.38',
#   '0',
#   '428NvDHsWDUzEBUjvmfCFW',
#   '0.000192',
#   '10',
#   '0.117',
#   '-16.791',
#   '1',
#   'Το καλογεράκι',
#   '0',
#   '1930-01-01',
#   '0.0586',
#   '147.909',
#   '0.654',
#   '1930'],
#  ['0.996',
#   "['Miltiadis Kazis']",
#   '0.401',
#   '253121',
#   '0.354',
#   '0',
#   '42Ij0aAdwHtw9bOykDyGie',
#   '0.0123',
#   '2',
#   '0.248',
#   '-8.238',
#   '1',
#   'Kanella kanellitsa mou',
#   '0',
#   '1930-01-01',
#   '0.0387',
#   '113.026',
#   '0.797',
#   '1930'],
#  ['0.984',
#   "['Carlos Gardel']",
#   '0.711',
#   '165200',
#   '0.256',
#   '0',
#   '42N8vjI5pRxgsgkuKm9VfA',
#   '0.007559999999999998',
#   '11',
#   '0.084',
#   '-11.731',
#   '1',
#   'Que se vaya',
#   '2',
#   '1930-08-18',
#   '0.0789',
#   '114.151',
#   '0.603',
#   '1930'],
#  ['0.983',
#   "['Raquel Meller']",
#   '0.728',
#   '157246',
#   '0.159',
#   '0',
#   '42VPZtXihKkHwDx7AyvsFg',
#   '0.000423',
#   '2',
#   '0.115',
#   '-10.325',
#   '1',
#   'Ay! Cipriano',
#   '1',
#   '1930-01-01',
#   '0.475',
#   '122.18',
#   '0.65',
#   '1930'],
#  ['0.995',
#   '["Sam Manning\'s and His Cole Jazz Orchestra"]',
#   '0.664',
#   '173333',
#   '0.28300000000000003',
#   '0',
#   '42WDMm9hX0xCFkkKpt6NOY',
#   '0.8740000000000001',
#   '8',
#   '0.109',
#   '-18.301',
#   '0',
#   'Bungo',
#   '0',
#   '1930-01-01',
#   '0.0807',
#   '99.506',
#   '0.688',
#   '1930'],
#  ['0.821',
#   "['The Four Deuces']",
#   '0.627',
#   '132400',
#   '0.795',
#   '0',
#   '42r18phTFwegQjdbeDnFyN',
#   '0.0',
#   '7',
#   '0.105',
#   '-0.395',
#   '1',
#   'Fore Day in the Morning',
#   '0',
#   '1930-01-01',
#   '0.136',
#   '100.715',
#   '0.975',
#   '1930'],
#  ['0.941',
#   "['Banda del Regimiento Pérez 3 de Infantería', 'Adrián Patiño']",
#   '0.629',
#   '184086',
#   '0.7140000000000001',
#   '0',
#   '42wQ4jDtm0xxBUJDJnJpRr',
#   '0.97',
#   '7',
#   '0.284',
#   '-9.104',
#   '1',
#   'Como El Rocha',
#   '0',
#   '1930-01-01',
#   '0.0361',
#   '126.95',
#   '0.965',
#   '1930'],
#  ['0.0014199999999999998',
#   "['Shiny Gnomes']",
#   '0.45',
#   '224360',
#   '0.873',
#   '0',
#   '4306jl5QnfahO7GXeLUAq0',
#   '0.000147',
#   '7',
#   '0.32299999999999995',
#   '-6.885',
#   '1',
#   'The Nest',
#   '0',
#   '1930',
#   '0.0507',
#   '132.04',
#   '0.505',
#   '1930'],
#  ['0.944',
#   "['Petros Epitropakis', 'Elvira Nte Ntalgko']",
#   '0.433',
#   '187294',
#   '0.458',
#   '0',
#   '432t2QZQYpOJdEHmb60JAp',
#   '0.00186',
#   '5',
#   '0.0641',
#   '-10.689',
#   '1',
#   'Mparmpa Giannis Kanatas',
#   '0',
#   '1930-01-01',
#   '0.0585',
#   '65.672',
#   '0.716',
#   '1930'],
#  ['0.971',
#   "['Carlos Gardel']",
#   '0.72',
#   '140573',
#   '0.236',
#   '0',
#   '43NCVFtFp0pBCEGdmJI5GQ',
#   '0.00119',
#   '2',
#   '0.0376',
#   '-14.263',
#   '0',
#   'Esclavas blancas',
#   '1',
#   '1930-08-18',
#   '0.121',
#   '128.107',
#   '0.69',
#   '1930'],
#  ['0.993',
#   "['Paradosiako']",
#   '0.308',
#   '208704',
#   '0.317',
#   '0',
#   '43QD71OfHYeV0gc3jgvWYm',
#   '0.934',
#   '2',
#   '0.109',
#   '-12.646',
#   '0',
#   'Argitiko',
#   '0',
#   '1930-01-01',
#   '0.0451',
#   '87.10799999999998',
#   '0.915',
#   '1930'],
#  ['0.992',
#   "['Francisco Canaro', 'Charlo']",
#   '0.373',
#   '204000',
#   '0.239',
#   '0',
#   '43aHhXYKEQ6iitIbfFdUWI',
#   '0.848',
#   '4',
#   '0.179',
#   '-9.449',
#   '1',
#   'Nunca Jamás - Remasterizado',
#   '0',
#   '1930-11-13',
#   '0.079',
#   '83.85600000000002',
#   '0.589',
#   '1930'],
#  ['0.936',
#   "['Ioannis Panagiotopoulos']",
#   '0.594',
#   '192347',
#   '0.54',
#   '0',
#   '43tahNxwxcaWRBEFFtg6e1',
#   '0.879',
#   '8',
#   '0.242',
#   '-10.699000000000002',
#   '0',
#   'To Tragoudi Tou Kolokotroni',
#   '0',
#   '1930-01-01',
#   '0.0507',
#   '108.376',
#   '0.772',
#   '1930'],
#  ['0.982',
#   "['Los Peregrinos']",
#   '0.453',
#   '175882',
#   '0.446',
#   '0',
#   '448LaLI9LO7OdbOp9gz65L',
#   '0.0467',
#   '0',
#   '0.463',
#   '-9.89',
#   '0',
#   'Cholita Paceña (Cueca)',
#   '0',
#   '1930-01-01',
#   '0.036000000000000004',
#   '118.377',
#   '0.64',
#   '1930'],
#  ['0.994',
#   "['Giorgos Papasideris']",
#   '0.429',
#   '182733',
#   '0.214',
#   '0',
#   '448LdSPFzZA69X6kbW1ZBa',
#   '0.941',
#   '3',
#   '0.111',
#   '-14.994000000000002',
#   '0',
#   'Me Doxa Na Girisis',
#   '0',
#   '1930-01-01',
#   '0.0626',
#   '77.289',
#   '0.716',
#   '1930'],
#  ['0.994',
#   "['D.roitman']",
#   '0.327',
#   '257493',
#   '0.114',
#   '0',
#   '44FzNHdYMyEZ5Fpvz1Qv9U',
#   '0.556',
#   '7',
#   '0.13',
#   '-19.691',
#   '0',
#   'Oshamnu mikolom',
#   '0',
#   '1930',
#   '0.0534',
#   '66.043',
#   '0.184',
#   '1930'],
#  ['0.991',
#   "['Carlos Galhardo']",
#   '0.7120000000000001',
#   '197092',
#   '0.623',
#   '0',
#   '44NkmEmGvCudWCfqWklKIq',
#   '0.5660000000000001',
#   '4',
#   '0.303',
#   '-9.828',
#   '1',
#   'O Palhaço o Que É?',
#   '7',
#   '1930-06-14',
#   '0.04',
#   '134.58',
#   '0.926',
#   '1930'],
#  ['0.993',
#   "['Smt. Angurbala Devi']",
#   '0.433',
#   '193280',
#   '0.14800000000000002',
#   '0',
#   '44d2dTOy7Pz3q7n85JpaBx',
#   '0.898',
#   '3',
#   '0.0967',
#   '-16.861',
#   '0',
#   'Kapat Shyam E Ki Chhalona',
#   '0',
#   '1930-12-01',
#   '0.0588',
#   '127.361',
#   '0.313',
#   '1930'],
#  ['0.943',
#   "['Roza Eskenazi']",
#   '0.354',
#   '203600',
#   '0.387',
#   '0',
#   '44i8kWhXwKOcxXWNkW1IIc',
#   '0.00817',
#   '1',
#   '0.0674',
#   '-9.324',
#   '1',
#   'Alaniara',
#   '0',
#   '1930-01-01',
#   '0.0293',
#   '99.883',
#   '0.442',
#   '1930'],
#  ['0.996',
#   "['Marika Papaggika']",
#   '0.478',
#   '247360',
#   '0.404',
#   '0',
#   '44nod4F5OuloAdZrE627PF',
#   '0.76',
#   '2',
#   '0.114',
#   '-9.466',
#   '1',
#   'Mes tou Siggrou th filaki',
#   '0',
#   '1930-01-01',
#   '0.0401',
#   '117.94',
#   '0.696',
#   '1930'],
#  ['0.979',
#   "['Francisco Canaro']",
#   '0.696',
#   '170507',
#   '0.325',
#   '0',
#   '45gT0SuDZIPG99CysAoBNK',
#   '0.664',
#   '1',
#   '0.4320000000000001',
#   '-8.604',
#   '1',
#   'Ya Va Para Un Mes - Instrumental (Remasterizado)',
#   '0',
#   '1930-12-03',
#   '0.135',
#   '115.337',
#   '0.856',
#   '1930'],
#  ['0.993',
#   "['Pirros Xronidis']",
#   '0.423',
#   '192587',
#   '0.409',
#   '0',
#   '45i0kvbyPfVaST8OX5VyXb',
#   '3.07e-06',
#   '0',
#   '0.342',
#   '-11.573',
#   '0',
#   'Ki An Metaniosoume',
#   '0',
#   '1930-01-01',
#   '0.0364',
#   '100.719',
#   '0.617',
#   '1930'],
#  ['0.993',
#   "['Ignacio Corsini']",
#   '0.635',
#   '177787',
#   '0.14300000000000002',
#   '0',
#   '45qV959UBzPnWuRJQM2LEv',
#   '0.504',
#   '3',
#   '0.119',
#   '-20.475',
#   '0',
#   'El Regreso - Remasterizado',
#   '0',
#   '1930-06-21',
#   '0.097',
#   '103.767',
#   '0.54',
#   '1930'],
#  ['0.995',
#   "['Francisco Canaro', 'Charlo']",
#   '0.585',
#   '191000',
#   '0.199',
#   '0',
#   '4668mfHlOUN0MQc3gGMqbX',
#   '0.6',
#   '6',
#   '0.12',
#   '-11.035',
#   '1',
#   'Pantaleón - Remasterizado',
#   '0',
#   '1930-11-16',
#   '0.127',
#   '210.173',
#   '0.926',
#   '1930'],
#  ['0.995',
#   "['Dimitris Arapakis']",
#   '0.37',
#   '181693',
#   '0.287',
#   '0',
#   '467wQe7ACYneXJ882MfVXH',
#   '0.448',
#   '2',
#   '0.122',
#   '-12.17',
#   '1',
#   'Evga Gkolfo Sto Vouno',
#   '0',
#   '1930-01-01',
#   '0.0514',
#   '110.882',
#   '0.327',
#   '1930'],
#  ['0.994',
#   "['Giorgos Papasideris']",
#   '0.3670000000000001',
#   '175493',
#   '0.262',
#   '0',
#   '46WBp2UIhe9rOaUL5qy6xF',
#   '0.939',
#   '10',
#   '0.124',
#   '-13.883',
#   '0',
#   'Kato Ston Kampo Sto Plati',
#   '0',
#   '1930-01-01',
#   '0.054000000000000006',
#   '74.28399999999998',
#   '0.8420000000000001',
#   '1930'],
#  ['0.996',
#   "['Giorgos Papasideris']",
#   '0.389',
#   '175827',
#   '0.409',
#   '0',
#   '46kISPbFGH6uelVB2hNUaa',
#   '0.8079999999999999',
#   '8',
#   '0.173',
#   '-9.333',
#   '0',
#   'Pera Sto Pera Mahala',
#   '0',
#   '1930-01-01',
#   '0.0507',
#   '88.788',
#   '0.7959999999999999',
#   '1930'],
#  ['0.977',
#   "['Ignacio Corsini']",
#   '0.66',
#   '138347',
#   '0.215',
#   '0',
#   '47PSm96pHcTUuV1fLBtZ0q',
#   '5.69e-06',
#   '5',
#   '0.782',
#   '-17.500999999999998',
#   '1',
#   'Siete Lágrimas - Remasterizado',
#   '0',
#   '1930-06-21',
#   '0.0938',
#   '107.809',
#   '0.561',
#   '1930'],
#  ['0.983',
#   "['Gene Sedric', 'Al Casey']",
#   '0.564',
#   '166893',
#   '0.191',
#   '0',
#   '47Yn2O8dgxSzyWDrq4n7Nx',
#   '0.802',
#   '8',
#   '0.168',
#   '-11.108',
#   '1',
#   'Wail Of The Scromph',
#   '2',
#   '1930',
#   '0.0319',
#   '86.405',
#   '0.388',
#   '1930'],
#  ['0.962',
#   "['Francisco Canaro']",
#   '0.7659999999999999',
#   '171000',
#   '0.252',
#   '0',
#   '48EGcTrfJ9GORtz3KebYOm',
#   '0.0',
#   '10',
#   '0.337',
#   '-8.795',
#   '0',
#   'Bajo Cuerda - Instrumental (Remasterizado)',
#   '0',
#   '1930-12-03',
#   '0.0556',
#   '113.661',
#   '0.8809999999999999',
#   '1930'],
#  ['0.994',
#   "['Kostas Tsanakos']",
#   '0.475',
#   '30000',
#   '0.277',
#   '0',
#   '48gD3QaOgrZvyr3vhMuG1R',
#   '0.000742',
#   '11',
#   '0.299',
#   '-10.802',
#   '0',
#   'To koritsi sou kira mou',
#   '0',
#   '1930-01-01',
#   '0.0465',
#   '93.681',
#   '0.968',
#   '1930'],
#  ['0.988',
#   "['Francisco Canaro', 'Charlo']",
#   '0.631',
#   '179493',
#   '0.254',
#   '0',
#   '48scMLeZSqaJoTStmQIlHI',
#   '0.527',
#   '1',
#   '0.106',
#   '-8.206',
#   '1',
#   'Mejicana Ven - Remasterizado',
#   '0',
#   '1930-11-20',
#   '0.0604',
#   '99.762',
#   '0.713',
#   '1930'],
#  ['0.905',
#   "['Sy Oliver', 'Attila the Hun', 'Jimmie Lunceford & His Orchestra']",
#   '0.8',
#   '176120',
#   '0.166',
#   '0',
#   '493O6Uf84IQH4SH4Scumay',
#   '0.128',
#   '5',
#   '0.0883',
#   '-14.921',
#   '0',
#   "Hittin' the Bottle",
#   '1',
#   '1930-01-01',
#   '0.0779',
#   '104.06',
#   '0.617',
#   '1930'],
#  ['0.991',
#   "['Patrício Teixeira']",
#   '0.534',
#   '196043',
#   '0.199',
#   '0',
#   '49OPPHZzx3svtdYt4ffCQV',
#   '0.0902',
#   '3',
#   '0.11',
#   '-15.419',
#   '1',
#   'Gavião Calçudo',
#   '0',
#   '1930-06-20',
#   '0.0685',
#   '100.386',
#   '0.578',
#   '1930'],
#  ['0.8',
#   "['Robert Francis']",
#   '0.51',
#   '150777',
#   '0.27',
#   '0',
#   '49UWs2R4eF9Ww2TwecHE2K',
#   '0.000489',
#   '7',
#   '0.122',
#   '-12.788',
#   '1',
#   'Look for the Silver Lining',
#   '0',
#   '1930',
#   '0.0956',
#   '174.472',
#   '0.418',
#   '1930'],
#  ['0.904',
#   "['Giorgos Papasideris', 'Klarino Har. Margels']",
#   '0.502',
#   '192067',
#   '0.494',
#   '0',
#   '49gHX66DkP4yrMT6hng6UO',
#   '0.933',
#   '9',
#   '0.0844',
#   '-7.685',
#   '0',
#   'Gia Sou Kaimeni Leventia',
#   '0',
#   '1930-01-01',
#   '0.0388',
#   '112.033',
#   '0.931',
#   '1930'],
#  ['0.995',
#   "['ANTONIS NTALGKAS']",
#   '0.434',
#   '196693',
#   '0.306',
#   '0',
#   '4A807nqcpcHJVxVMNmxllY',
#   '0.901',
#   '10',
#   '0.12',
#   '-11.895',
#   '0',
#   'Salam Sala',
#   '0',
#   '1930-01-01',
#   '0.0555',
#   '124.672',
#   '0.314',
#   '1930'],
#  ['0.993',
#   "['Kostas Roukounas']",
#   '0.361',
#   '193653',
#   '0.365',
#   '0',
#   '4AVjTCJVohNzt2I4Tbx1m8',
#   '0.81',
#   '5',
#   '0.238',
#   '-12.329',
#   '1',
#   'Neva Rast Manes',
#   '0',
#   '1930-01-01',
#   '0.0506',
#   '101.89',
#   '0.546',
#   '1930'],
#  ['0.985',
#   "['Francisco Canaro', 'Ernesto Fama']",
#   '0.6759999999999999',
#   '197507',
#   '0.312',
#   '0',
#   '4BI6u0ALUUmIa3WHyMMpnl',
#   '0.133',
#   '4',
#   '0.113',
#   '-6.49',
#   '1',
#   'Las Obreritas Chilenas - Remasterizado',
#   '0',
#   '1930-12-05',
#   '0.109',
#   '177.429',
#   '0.8759999999999999',
#   '1930'],
#  ['0.992',
#   "['Francisco Canaro', 'Charlo']",
#   '0.701',
#   '179507',
#   '0.266',
#   '0',
#   '4BwqVJLcYAuTrepQyyLjml',
#   '0.415',
#   '3',
#   '0.24',
#   '-14.107',
#   '1',
#   'La Traicionera - Remasterizado',
#   '0',
#   '1930-11-12',
#   '0.152',
#   '114.907',
#   '0.937',
#   '1930'],
#  ['0.94',
#   "['Jack Payne']",
#   '0.569',
#   '170867',
#   '0.117',
#   '0',
#   '4C8Zw7r2LvN4SnBDtIu7qc',
#   '0.008740000000000001',
#   '0',
#   '0.151',
#   '-22.011',
#   '1',
#   'Fancy You Falling for Me!',
#   '0',
#   '1930',
#   '0.0383',
#   '114.602',
#   '0.637',
#   '1930'],
#  ['0.994',
#   "['Francisco Canaro', 'Charlo']",
#   '0.669',
#   '189493',
#   '0.458',
#   '0',
#   '4Ccl9Q8YI8h7JOvSzoH5Ca',
#   '0.682',
#   '11',
#   '0.136',
#   '-7.391',
#   '1',
#   'La Comadreja - Remasterizado',
#   '0',
#   '1930-12-05',
#   '0.321',
#   '154.61',
#   '0.984',
#   '1930'],
#  ['0.994',
#   "['Hrisoula Stini']",
#   '0.493',
#   '200760',
#   '0.264',
#   '0',
#   '4CizuT4ZZCClJisvxsVWf0',
#   '5.09e-06',
#   '7',
#   '0.17600000000000002',
#   '-12.082',
#   '1',
#   'Kathe Vradaki Stis Ohto',
#   '0',
#   '1930-01-01',
#   '0.0513',
#   '79.949',
#   '0.695',
#   '1930'],
#  ['0.966',
#   "['Lord Kitchener']",
#   '0.8170000000000001',
#   '179080',
#   '0.5589999999999999',
#   '0',
#   '4CjFhaey3Jr4z4uoIrms4H',
#   '0.0248',
#   '8',
#   '0.0974',
#   '-1.991',
#   '1',
#   'Muriel and the Bug',
#   '1',
#   '1930-01-01',
#   '0.141',
#   '140.984',
#   '0.908',
#   '1930'],
#  ['0.445',
#   "['Shorty Bralik', 'ParkPlace Swagg']",
#   '0.613',
#   '206785',
#   '0.55',
#   '1',
#   '4CnpHG2qWJJu5gwWbo1OCX',
#   '0.0',
#   '4',
#   '0.107',
#   '-12.05',
#   '0',
#   "No Lack'n",
#   '0',
#   '1930-05-29',
#   '0.404',
#   '116.576',
#   '0.35200000000000004',
#   '1930'],
#  ['0.982',
#   "['Manuel Ponce', 'Andrés Segovia']",
#   '0.385',
#   '165960',
#   '0.108',
#   '0',
#   '4DIRWsTjTb728nKD6oBRY4',
#   '0.845',
#   '9',
#   '0.141',
#   '-28.06',
#   '0',
#   'Suite in A major: Allemande',
#   '2',
#   '1930-01-01',
#   '0.0499',
#   '110.895',
#   '0.738',
#   '1930'],
#  ['0.993',
#   "['Fragiskos Dimitriou']",
#   '0.293',
#   '223787',
#   '0.211',
#   '0',
#   '4DSIEavoLru6Dn5OKrP1Uw',
#   '0.865',
#   '1',
#   '0.112',
#   '-11.083',
#   '0',
#   'Ntoulas',
#   '0',
#   '1930-01-01',
#   '0.0391',
#   '89.13',
#   '0.56',
#   '1930'],
#  ['0.968',
#   "['Francisco Canaro']",
#   '0.722',
#   '177000',
#   '0.297',
#   '0',
#   '4DcAyA58a9WBd1BWHk8jNB',
#   '0.343',
#   '10',
#   '0.224',
#   '-6.402',
#   '0',
#   'El Castigo - Instrumental (Remasterizado)',
#   '0',
#   '1930-11-16',
#   '0.0483',
#   '111.254',
#   '0.925',
#   '1930'],
#  ['0.986',
#   "['Giorgos Mpekas', 'Polixeni LItou']",
#   '0.5479999999999999',
#   '194880',
#   '0.289',
#   '0',
#   '4DlATZ1MIXLxb1WbA6utuO',
#   '0.3670000000000001',
#   '4',
#   '0.102',
#   '-8.432',
#   '0',
#   'Vasilikos Tha Gino',
#   '0',
#   '1930-01-01',
#   '0.0411',
#   '122.284',
#   '0.757',
#   '1930'],
#  ['0.989',
#   "['Dimitris Filipopoulos']",
#   '0.315',
#   '201613',
#   '0.55',
#   '0',
#   '4E5i6hk6cipCOFHBUN4AP3',
#   '0.027000000000000003',
#   '4',
#   '0.326',
#   '-6.997000000000001',
#   '0',
#   'Mesanuxta',
#   '0',
#   '1930-01-01',
#   '0.0386',
#   '103.721',
#   '0.339',
#   '1930'],
#  ['0.953',
#   "['Carlos Gardel']",
#   '0.705',
#   '160307',
#   '0.199',
#   '0',
#   '4EMYJgIiQJdxnKzc6ze1uJ',
#   '1.59e-05',
#   '8',
#   '0.128',
#   '-11.973',
#   '1',
#   'Por seguidora y por fiel',
#   '2',
#   '1930-08-18',
#   '0.14800000000000002',
#   '134.81',
#   '0.846',
#   '1930'],
#  ['0.979',
#   "['Ignacio Corsini']",
# ...
#   '0.182',
#   '25200',
#   '0.000884',
#   '0',
#   '4HYlFKmAWrhjC4PBXyJmHS',
#   '0.993',
#   '10',
#   '0.08199999999999999',
#   '-48.278',
#   '1',
#   'Le sacre du printemps: Part 1 "Adoration of the Earth", The Wise Elder',
#   '0',
#   '1948',
#   '0.0604',
#   '118.462',
#   '0.0',
#   '1948'],
#  ['0.961',
#   "['Giacomo Puccini', 'Giuseppe Antonicelli', 'Metropolitan Opera Orchestra']",
#   '0.35700000000000004',
#   '41760',
#   '0.53',
#   '0',
#   '4J7HeczOMetPbUGsL0IHL5',
#   '0.55',
#   '8',
#   '0.532',
#   '-10.582',
#   '1',
#   'La Bohème: Act IV - Quadriglia',
#   '0',
#   '1948',
#   '0.0496',
#   '78.12100000000002',
#   '0.7120000000000001',
#   '1948'],
#  ['0.992',
#   "['Safiye Ayla']",
#   '0.325',
#   '188369',
#   '0.248',
#   '0',
#   '4JRrjikrmk29kGoW8CBg5x',
#   '0.8009999999999999',
#   '0',
#   '0.217',
#   '-16.296',
#   '1',
#   'Ne Derin Kudreti Var',
#   '0',
#   '1948-04-30',
#   '0.08',
#   '73.233',
#   '0.507',
#   '1948'],
#  ['0.993',
#   "['Leela Mehta', 'A. R. Ojha']",
#   '0.611',
#   '190921',
#   '0.223',
#   '0',
#   '4JUhe5SG5bKGINfLnooUvv',
#   '0.043',
#   '2',
#   '0.142',
#   '-9.68',
#   '1',
#   'Hotel Ka Kinara Ho',
#   '0',
#   '1948-12-31',
#   '0.198',
#   '67.572',
#   '0.7509999999999999',
#   '1948'],
#  ['0.989',
#   "['Mohantara Talpade']",
#   '0.609',
#   '191169',
#   '0.142',
#   '0',
#   '4JlYwSNXTyCSIdFhw5LwVG',
#   '0.00504',
#   '6',
#   '0.105',
#   '-10.441',
#   '0',
#   'Ek Bhola Shikari Aaya',
#   '0',
#   '1948-12-31',
#   '0.478',
#   '174.63',
#   '0.733',
#   '1948'],
#  ['0.737',
#   "['Igor Stravinsky']",
#   '0.825',
#   '98760',
#   '0.237',
#   '0',
#   '4KEME1HJH6XY18zyluTFno',
#   '0.94',
#   '2',
#   '0.106',
#   '-16.93',
#   '1',
#   "The Soldier's Tale Suite: I. The Soldier's March",
#   '0',
#   '1948',
#   '0.0617',
#   '116.036',
#   '0.578',
#   '1948'],
#  ['0.961',
#   "['Igor Stravinsky', 'Concertgebouworkest', 'Eduard van Beinum']",
#   '0.375',
#   '66480',
#   '0.7959999999999999',
#   '0',
#   '4KIGFmuWCrbQPrRaVrF3wm',
#   '0.843',
#   '2',
#   '0.0704',
#   '-11.158',
#   '0',
#   "Le Sacre du Printemps / Part 1: L'Adoration de la Terre: 8. Danse de la terre",
#   '0',
#   '1948-01-01',
#   '0.0547',
#   '86.59100000000002',
#   '0.0375',
#   '1948'],
#  ['0.961',
#   "['Giacomo Puccini', 'Giuseppe Antonicelli', 'Metropolitan Opera Orchestra']",
#   '0.578',
#   '183733',
#   '0.247',
#   '0',
#   '4KRpaZqmT3t4IfKtJvee6M',
#   '2.6e-06',
#   '0',
#   '0.102',
#   '-17.017',
#   '0',
#   'La Bohème: Act II - Oh! Essa! Musetta!',
#   '0',
#   '1948',
#   '0.525',
#   '62.64',
#   '0.564',
#   '1948'],
#  ['0.8290000000000001',
#   "['Lucho Oliva']",
#   '0.635',
#   '176875',
#   '0.43',
#   '0',
#   '4LB8UN65DmHJsfgpIHR5o7',
#   '0.00636',
#   '3',
#   '0.152',
#   '-11.039',
#   '0',
#   'En Vano',
#   '3',
#   '1948-01-01',
#   '0.0401',
#   '159.09',
#   '0.948',
#   '1948'],
#  ['0.995',
#   "['Suraiya', 'G. M. Durrani']",
#   '0.523',
#   '194188',
#   '0.103',
#   '0',
#   '4LbVfJ8NyKBEPJMpcHa26Y',
#   '3.81e-05',
#   '5',
#   '0.233',
#   '-10.456',
#   '1',
#   'Mere Ansuon Meri Hasrato',
#   '0',
#   '1948-01-01',
#   '0.114',
#   '131.19799999999998',
#   '0.611',
#   '1948'],
#  ['0.995',
#   "['Suraiya']",
#   '0.501',
#   '181840',
#   '0.344',
#   '0',
#   '4Lk5Z0jzCobR6IY9vFhfrq',
#   '0.912',
#   '7',
#   '0.17800000000000002',
#   '-9.45',
#   '0',
#   'Din Pe Din Beet Jaye',
#   '0',
#   '1948-12-31',
#   '0.07400000000000001',
#   '73.31',
#   '0.598',
#   '1948'],
#  ['0.8640000000000001',
#   "['Camille Saint-Saëns', 'Charles Münch', 'New York Philharmonic']",
#   '0.229',
#   '532947',
#   '0.208',
#   '0',
#   '1fqRUY7Eyj8ff0v7Ssklbw',
#   '0.8490000000000001',
#   '8',
#   '0.102',
#   '-17.883',
#   '1',
#   'Symphony No. 3 in C Minor, Op. 78 "Organ": I. Adagio - Allegro moderato',
#   '4',
#   '1949',
#   '0.0416',
#   '132.885',
#   '0.158',
#   '1949'],
#  ['0.985',
#   "['Salvatore Cardillo', 'Mario Lanza', 'Constantine Callinicos']",
#   '0.179',
#   '155280',
#   '0.374',
#   '0',
#   '1ftOw055sL5qBIGp1ZuYln',
#   '0.000169',
#   '3',
#   '0.14',
#   '-8.546',
#   '1',
#   "Core 'ngrato",
#   '1',
#   '1949',
#   '0.033',
#   '76.223',
#   '0.275',
#   '1949'],
#  ['0.988',
#   "['André Gide', 'Jean Amrouche']",
#   '0.594',
#   '724927',
#   '0.293',
#   '0',
#   '1gF2Bk44PqRYOyWP1eHxvx',
#   '0.00472',
#   '8',
#   '0.232',
#   '-20.61',
#   '1',
#   '"Les Faux-monnayeurs": Composition...',
#   '0',
#   '1949',
#   '0.875',
#   '72.32600000000002',
#   '0.626',
#   '1949'],
#  ['0.984',
#   "['Pietro Mascagni', 'Richard Tucker']",
#   '0.18',
#   '211600',
#   '0.272',
#   '0',
#   '1ggMPSZkJ7o0riJMbFvXXr',
#   '0.00111',
#   '8',
#   '0.618',
#   '-12.752',
#   '0',
#   'Cavalleria Rusticana: "Mamma, mamma! Quel vino è generoso"',
#   '0',
#   '1949',
#   '0.0541',
#   '64.82',
#   '0.175',
#   '1949'],
#  ['0.8909999999999999',
#   "['Colette', 'André Parinaud', 'Robert Casadessus']",
#   '0.664',
#   '639960',
#   '0.184',
#   '0',
#   '1gojEzPzwDMhaLoxsOOPqv',
#   '0.0',
#   '7',
#   '0.285',
#   '-15.011',
#   '1',
#   'Dualité de Colette et Claudine',
#   '0',
#   '1949',
#   '0.953',
#   '85.639',
#   '0.463',
#   '1949'],
#  ['0.846',
#   "['Shamshad Begum']",
#   '0.564',
#   '211867',
#   '0.29',
#   '0',
#   '1gvON2x95M5nNuk9aSHcaF',
#   '5.37e-05',
#   '5',
#   '0.358',
#   '-10.134',
#   '1',
#   'Do Char Din Pyar Se',
#   '0',
#   '1949-12-31',
#   '0.47',
#   '85.546',
#   '0.569',
#   '1949'],
#  ['0.992',
#   "['Giacomo Rondinella']",
#   '0.261',
#   '167053',
#   '0.276',
#   '0',
#   '1hB2sfui5H9La7w98ZCxb8',
#   '0.00965',
#   '7',
#   '0.315',
#   '-16.570999999999998',
#   '1',
#   'Sulo',
#   '0',
#   '1949-01-01',
#   '0.0572',
#   '80.67699999999998',
#   '0.0909',
#   '1949'],
#  ['0.981',
#   "['Irving Berlin', 'Johnny V. R. Thompson', 'Allyn McLerie', 'Miss Liberty Ensemble', 'Jay Blackton']",
#   '0.243',
#   '173093',
#   '0.175',
#   '0',
#   '1hf7hC5MYb86001qzR5rBJ',
#   '0.000128',
#   '0',
#   '0.14',
#   '-14.149',
#   '1',
#   'Miss Liberty: Paris Wakes Up and Smiles',
#   '0',
#   '1949',
#   '0.0409',
#   '80.666',
#   '0.226',
#   '1949'],
#  ['0.787',
#   "['Giuseppe Verdi', 'Arturo Toscanini']",
#   '0.411',
#   '53013',
#   '0.408',
#   '0',
#   '1hrASLD1BLLXJkDGGgOtTA',
#   '0.469',
#   '2',
#   '0.3',
#   '-11.397',
#   '0',
#   'Aida: Traditor!',
#   '0',
#   '1949',
#   '0.0855',
#   '136.957',
#   '0.403',
#   '1949'],
#  ['0.8270000000000001',
#   "['Shanta Kunwar']",
#   '0.528',
#   '212287',
#   '0.471',
#   '0',
#   '1hu5Dh8Ke8h7ZzCRcqWaFx',
#   '0.00355',
#   '9',
#   '0.391',
#   '-9.84',
#   '1',
#   'Armaan Loot Gaye Hae',
#   '0',
#   '1949-12-31',
#   '0.0424',
#   '131.875',
#   '0.71',
#   '1949'],
#  ['0.802',
#   "['Lead Belly']",
#   '0.409',
#   '193123',
#   '0.672',
#   '0',
#   '1i8C8u3CVtM4NmaPGNXBNk',
#   '0.494',
#   '9',
#   '0.313',
#   '-8.601',
#   '1',
#   'John Henry',
#   '0',
#   '1949',
#   '0.0409',
#   '145.218',
#   '0.731',
#   '1949'],
#  ['0.91',
#   "['Jay Blackton', 'Laurence Guittard', 'Christine Andreas']",
#   '0.27',
#   '257107',
#   '0.16',
#   '0',
#   '1iYOEFvQbSmRrzIldiIWvP',
#   '0.000388',
#   '9',
#   '0.0963',
#   '-17.246',
#   '1',
#   'People Will Say We\'re in Love (From "Oklahoma!")',
#   '1',
#   '1949',
#   '0.0342',
#   '78.0',
#   '0.203',
#   '1949'],
#  ['0.965',
#   "['Fromental Halévy', 'Richard Tucker', 'Wilfrid Pelletier']",
#   '0.237',
#   '259867',
#   '0.18',
#   '0',
#   '1ivbgk5DS1fAppzMVqeVF1',
#   '5.1e-06',
#   '5',
#   '0.0963',
#   '-14.207',
#   '0',
#   'La Juive: "Rachel, quand du seigneur"',
#   '0',
#   '1949',
#   '0.0397',
#   '92.726',
#   '0.149',
#   '1949'],
#  ['0.995',
#   "['Robin Majumdar']",
#   '0.589',
#   '183347',
#   '0.185',
#   '0',
#   '1jF9tFdbK6wAxRN4NTYan2',
#   '0.93',
#   '11',
#   '0.106',
#   '-17.535',
#   '1',
#   'Moni Maniker Pasara',
#   '0',
#   '1949-12-31',
#   '0.0753',
#   '130.33',
#   '0.551',
#   '1949'],
#  ['0.993',
#   "['Dilip Dholakia']",
#   '0.459',
#   '194252',
#   '0.282',
#   '0',
#   '1jMQqsOw6QHC4Mq5WXVBSb',
#   '0.306',
#   '7',
#   '0.337',
#   '-8.994',
#   '1',
#   'Bhala Bhalae Bhool Kari',
#   '0',
#   '1949-03-02',
#   '0.14800000000000002',
#   '64.84899999999999',
#   '0.417',
#   '1949'],
#  ['0.778',
#   "['Bourvil']",
#   '0.637',
#   '194533',
#   '0.345',
#   '0',
#   '1jjZsdtrgJDPEDIOfLJtyo',
#   '0.0',
#   '3',
#   '0.0793',
#   '-10.125',
#   '1',
#   'Ma place',
#   '1',
#   '1949',
#   '0.153',
#   '80.075',
#   '0.648',
#   '1949'],
#  ['0.995',
#   "['Sulochana Kadam']",
#   '0.754',
#   '173964',
#   '0.35100000000000003',
#   '0',
#   '1jl449khYMkGlVb3RhPYi0',
#   '0.7559999999999999',
#   '0',
#   '0.126',
#   '-9.378',
#   '0',
#   'Jahan Koi Na Ho Wahan Chalenge Ham',
#   '0',
#   '1949-12-31',
#   '0.111',
#   '148.899',
#   '0.96',
#   '1949'],
#  ['0.993',
#   "['Wolfgang Amadeus Mozart', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#   '0.502',
#   '147333',
#   '0.252',
#   '0',
#   '1jsOMnrDvxZDHZqvoIu5C9',
#   '0.0138',
#   '7',
#   '0.155',
#   '-12.196',
#   '1',
#   'Die Entführung aus dem Serail, K. 384, Act II: "Welche Wonne.."',
#   '0',
#   '1949',
#   '0.114',
#   '75.835',
#   '0.565',
#   '1949'],
#  ['0.858',
#   "['Lalita Dewoolkar']",
#   '0.513',
#   '241653',
#   '0.364',
#   '0',
#   '1juCEmPAkt2OiC8UqB7I0A',
#   '0.000199',
#   '9',
#   '0.155',
#   '-11.102',
#   '1',
#   'Dil Leke Bhaga',
#   '0',
#   '1949-12-31',
#   '0.0924',
#   '180.836',
#   '0.755',
#   '1949'],
#  ['0.974',
#   "['Ernest Bloch', 'Isaac Stern', 'Alexander Zakin']",
#   '0.253',
#   '379267',
#   '0.206',
#   '0',
#   '1k80cWFHXq0lfIJg9Exj9y',
#   '0.7290000000000001',
#   '7',
#   '0.159',
#   '-16.584',
#   '0',
#   'Baal Shem - Three PIctures of Chassidic Life: II. Nigun',
#   '0',
#   '1949',
#   '0.0421',
#   '104.804',
#   '0.0924',
#   '1949'],
#  ['0.959',
#   "['Mitch Miller & The Sing-Along Gang']",
#   '0.109',
#   '260867',
#   '0.273',
#   '0',
#   '1k8Z5FY3QFBJtm4a63aF5p',
#   '0.000466',
#   '10',
#   '0.124',
#   '-14.77',
#   '1',
#   'Silent Night, Holy Night',
#   '1',
#   '1949',
#   '0.0356',
#   '71.313',
#   '0.103',
#   '1949'],
#  ['0.991',
#   "['Κούλα Νικολαϊδου']",
#   '0.41',
#   '95935',
#   '0.311',
#   '0',
#   '1kG5glfzBWVa0W3cL2sbGv',
#   '4.77e-05',
#   '10',
#   '0.21600000000000005',
#   '-9.951',
#   '1',
#   'Απόψε πάλι',
#   '0',
#   '1949-01-01',
#   '0.0394',
#   '96.012',
#   '0.505',
#   '1949'],
#  ['0.966',
#   "['Johannes Brahms', 'Wilhelm Furtwängler', 'Wiener Philharmoniker']",
#   '0.127',
#   '197813',
#   '0.218',
#   '0',
#   '1kqWugFghxSx3rjDtf2XQl',
#   '0.921',
#   '10',
#   '0.335',
#   '-15.989',
#   '1',
#   'Brahms: Variations on a Theme by Haydn, Op. 56a "St. Antoni Chorale": Variation VII. Grazioso',
#   '0',
#   '1949',
#   '0.036000000000000004',
#   '147.935',
#   '0.116',
#   '1949'],
#  ['0.946',
#   "['Nikolai Rimsky-Korsakov', 'Mario Lanza', 'Constantine Callinicos']",
#   '0.238',
#   '239253',
#   '0.301',
#   '0',
#   '1ktOaQeEQRMv9B5XOoa88t',
#   '0.000918',
#   '1',
#   '0.109',
#   '-9.804',
#   '1',
#   'Sadko: Song of India',
#   '1',
#   '1949',
#   '0.0314',
#   '93.734',
#   '0.269',
#   '1949'],
#  ['0.959',
#   "['Ralph Vaughan Williams', 'Leopold Stokowski', 'New York Philharmonic']",
#   '0.113',
#   '517733',
#   '0.0173',
#   '0',
#   '1kwpuqFRYEeM01Ccg5P9kb',
#   '0.888',
#   '0',
#   '0.116',
#   '-34.677',
#   '1',
#   'Symphony No. 6 in E Minor: IV. Epilogue',
#   '0',
#   '1949',
#   '0.0444',
#   '93.826',
#   '0.0346',
#   '1949'],
#  ['0.984',
#   "['Aaron Copland', 'Martha Lipton']",
#   '0.3720000000000001',
#   '136133',
#   '0.152',
#   '0',
#   '1lN3jH5YqsNzHDRqjqKlZD',
#   '0.000174',
#   '1',
#   '0.0982',
#   '-13.61',
#   '1',
#   'Twelve Poems of Emily Dickinson: IX. I felt a funeral in my brain',
#   '0',
#   '1949',
#   '0.063',
#   '173.447',
#   '0.051',
#   '1949'],
#  ['0.669',
#   "['Anton Bruckner', 'Wiener Philharmoniker', 'Hans Knappertsbusch']",
#   '0.16699999999999998',
#   '1220467',
#   '0.123',
#   '0',
#   '1lSlNDHyjHq67U92wbwczi',
#   '0.217',
#   '11',
#   '0.289',
#   '-20.217',
#   '1',
#   'Symphony No. 7 in E Major, WAB 107 (Modified 1885 Version, Ed. A. Gutmann): I. Allegro moderato [Live]',
#   '0',
#   '1949-08-30',
#   '0.04',
#   '104.871',
#   '0.039',
#   '1949'],
#  ['0.8759999999999999',
#   "['George Gershwin', 'Mary Martin', 'Girl Crazy Ensemble (1952)', 'Lehman Engel']",
#   '0.426',
#   '173533',
#   '0.302',
#   '0',
#   '1lT06EeLeQEzOYD9X8tCby',
#   '0.0',
#   '7',
#   '0.522',
#   '-11.286',
#   '1',
#   'Girl Crazy: Boy! What Love Has Done to Me',
#   '1',
#   '1949',
#   '0.0437',
#   '85.654',
#   '0.408',
#   '1949'],
#  ['0.536',
#   "['Munawwar Sultana']",
#   '0.61',
#   '167027',
#   '0.455',
#   '0',
#   '1lTGhbAlGF8wvzUbWmutby',
#   '8.53e-05',
#   '5',
#   '0.419',
#   '-9.605',
#   '0',
#   'Dil ko rahat nahin qarar nahin',
#   '0',
#   '1949-01-01',
#   '0.0701',
#   '76.89',
#   '0.472',
#   '1949'],
#  ['0.838',
#   "['Lead Belly']",
#   '0.599',
#   '65698',
#   '0.321',
#   '0',
#   '1lgnLRxxnFqaXxMlZNyWKj',
#   '0.0',
#   '2',
#   '0.156',
#   '-9.407',
#   '0',
#   'Come And Sit Down Beside Me',
#   '0',
#   '1949',
#   '0.0354',
#   '87.006',
#   '0.919',
#   '1949'],
#  ['0.8490000000000001',
#   "['Hariram']",
#   '0.618',
#   '203314',
#   '0.202',
#   '0',
#   '1ljivYBdnsquYYJMmRXupX',
#   '1.05e-06',
#   '0',
#   '0.413',
#   '-18.214',
#   '1',
#   'Gagar Gai Bharne Sakhi',
#   '0',
#   '1949-12-31',
#   '0.0461',
#   '81.032',
#   '0.935',
#   '1949'],
#  ['0.988',
#   "['Giacomo Puccini', 'Richard Tucker', 'Dorothy Kirsten', 'Fausto Cleva']",
#   '0.179',
#   '221013',
#   '0.212',
#   '0',
#   '1lkfS36M4GobrT3QVhrA6S',
#   '0.0095',
#   '4',
#   '0.124',
#   '-12.348',
#   '1',
#   'La bohème, Act I:"O soave fanciulla"',
#   '0',
#   '1949',
#   '0.0402',
#   '83.141',
#   '0.0507',
#   '1949'],
#  ['0.979',
#   "['Charles Mingus']",
#   '0.248',
#   '245133',
#   '0.219',
#   '0',
#   '1lzMkGUlTgyMUbrp1j9A3N',
#   '0.905',
#   '5',
#   '0.123',
#   '-13.591',
#   '0',
#   'Inspiration',
#   '3',
#   '1949',
#   '0.0292',
#   '76.779',
#   '0.0946',
#   '1949'],
#  ['0.948',
#   "['Joaquín Rodrigo', 'Andrés Segovia']",
#   '0.479',
#   '225019',
#   '0.13699999999999998',
#   '0',
#   '1m02sEzI88HcByzEM8goMH',
#   '0.74',
#   '4',
#   '0.236',
#   '-24.695',
#   '1',
#   'Fandango',
#   '0',
#   '1949-01-01',
#   '0.0383',
#   '90.29',
#   '0.485',
#   '1949'],
#  ['0.937',
#   "['Giuseppe Verdi', 'Arturo Toscanini']",
#   '0.274',
#   '100573',
#   '0.123',
#   '0',
#   '1m7WbravGKJ9iilTKOywFz',
#   '7.06e-05',
#   '1',
#   '0.246',
#   '-19.687',
#   '1',
#   "Aida: Vedi? Di morte l'angelo",
#   '0',
#   '1949',
#   '0.0456',
#   '72.428',
#   '0.238',
#   '1949'],
#  ['0.978',
#   "['Giuseppe Verdi', 'Arturo Toscanini']",
#   '0.15',
#   '266787',
#   '0.116',
#   '0',
#   '1m8Hj7ER6ixH30KApRpVZj',
#   '0.00372',
#   '3',
#   '0.108',
#   '-19.381',
#   '1',
#   'Aida: Nume, custode e vindice',
#   '0',
#   '1949',
#   '0.036000000000000004',
#   '60.015',
#   '0.16899999999999998',
#   '1949'],
#  ['0.987',
#   "['Giacomo Puccini', 'Richard Tucker', 'Fausto Cleva [Conductor]']",
#   '0.274',
#   '275840',
#   '0.251',
#   '0',
#   '1m8epcwSD06TJu7kYyTv1m',
#   '9.48e-06',
#   '7',
#   '0.246',
#   '-12.113',
#   '1',
#   'La Bohême, Act I: "Che gelida manina"',
#   '0',
#   '1949',
#   '0.0401',
#   '126.229',
#   '0.11',
#   '1949'],
#  ['0.941',
#   "['Giuseppe Verdi', 'Arturo Toscanini']",
#   '0.203',
#   '98507',
#   '0.103',
#   '0',
#   '1m9BazgCOGMJxmyqE30grw',
#   '0.0218',
#   '2',
#   '0.364',
#   '-23.632',
#   '0',
#   'Aida: Qui Radamès verrà!',
#   '0',
#   '1949',
#   '0.0425',
#   '81.033',
#   '0.103',
#   '1949'],
#  ['0.952',
#   "['Ezio Pinza']",
#   '0.243',
#   '180693',
#   '0.234',
#   '0',
#   '1mANcjsYwOOSQJdf8dIL1Y',
#   '0.00182',
#   '0',
#   '0.0964',
#   '-13.954',
#   '1',
#   'Some Enchanted Evening - from "South Pacific, 1949"',
#   '0',
#   '1949',
#   '0.0394',
#   '90.851',
#   '0.222',
#   '1949'],
#  ['0.7979999999999999',
#   "['Franz von Suppé', 'London Philharmonic Orchestra', 'Sir Georg Solti']",
#   '0.241',
#   '494053',
#   '0.268',
#   '0',
#   '1mVlcXbhcRM0Ie9nydrC6d',
#   '0.000536',
#   '2',
#   '0.0708',
#   '-11.583',
#   '1',
#   'Poet and Peasant: Overture',
#   '0',
#   '1949',
#   '0.0512',
#   '87.945',
#   '0.244',
#   '1949'],
#  ['0.996',
#   "['Suraiya', 'Mukesh']",
#   '0.362',
#   '190880',
#   '0.232',
#   '0',
#   '1mdGSkdBhCvCBTDDcRkCgy',
#   '0.883',
#   '3',
#   '0.129',
#   '-14.586',
#   '1',
#   'Badra Ki Chhaon Tale',
#   '0',
#   '1949-01-01',
#   '0.14',
#   '66.59899999999999',
#   '0.498',
#   '1949'],
#  ['0.953',
#   "['N. S. Krishnan', 'T A Madhuram']",
#   '0.602',
#   '197240',
#   '0.408',
#   '0',
#   '1nItTy4DPU7LcrbGAfLkcp',
#   '0.0208',
#   '1',
#   '0.124',
#   '-8.579',
#   '1',
#   'Vignanathai',
#   '0',
#   '1949-12-01',
#   '0.48',
#   '67.748',
#   '0.816',
#   '1949'],
#  ['0.994',
#   "['Lalita Phadke', 'Balakram']",
#   '0.805',
#   '167787',
#   '0.269',
#   '0',
#   '1nMOUk1hLge8FdFEdZ98TB',
#   '0.546',
#   '8',
#   '0.122',
#   '-9.15',
#   '0',
#   'Bachpan Mera Bachpan Tera',
#   '0',
#   '1949-12-31',
#   '0.487',
#   '101.197',
#   '0.835',
#   '1949'],
#  ['0.945',
#   "['Lead Belly']",
#   '0.7020000000000001',
#   '202707',
#   '0.32',
#   '0',
#   '1nPu67v2i3iWqdiZYY48Uf',
#   '0.00118',
#   '5',
#   '0.68',
#   '-9.817',
#   '1',
#   'Whoa Buck',
#   '0',
#   '1949',
#   '0.353',
#   '75.967',
#   '0.465',
#   '1949'],
#  ['0.529',
#   "['Frank Wedekind']",
#   '0.6629999999999999',
#   '140400',
#   '0.153',
#   '0',
#   '1ncMthnYcUTBCSPEoelULc',
#   '0.0',
#   '5',
#   '0.194',
#   '-29.06',
#   '1',
#   'Kapitel 20 - Der Kammersänger',
#   '0',
#   '1949-03-12',
#   '0.925',
#   '145.585',
#   '0.27',
#   '1949'],
#  ...]

# %%
# read in the csv file
data = pd.read_csv('data.csv')

# %%
# Check the top five rows of the data to have a glimpse of how the table looks like
data.head()
# Out:
#    acousticness                                   artists  danceability  \
# 0         0.995                       ['Carl Woitschach']         0.708
# 1         0.994  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2         0.604                   ['Seweryn Goszczyński']         0.749
# 3         0.995                      ['Francisco Canaro']         0.781
# 4         0.990  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD             0.563
# 1       282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV             0.901
# 2       104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM             0.000
# 3       180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8             0.887
# 4       687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd             0.908
#
#    key  liveness  loudness  mode  \
# 0   10    0.1510   -12.428     1
# 1    8    0.0763   -28.454     1
# 2    5    0.1190   -19.924     0
# 3    1    0.1110   -14.734     0
# 4   11    0.0980   -16.829     1
#
#                                             name  popularity release_date  \
# 0                    Singende Bataillone 1. Teil           0         1928
# 1       Fantasiestücke, Op. 111: Più tosto lento           0         1928
# 2                 Chapter 1.18 - Zamek kaniowski           0         1928
# 3  Bebamos Juntos - Instrumental (Remasterizado)           0   1928-09-25
# 4    Polonaise-Fantaisie in A-Flat Major, Op. 61           1         1928
#
#    speechiness    tempo  valence  year
# 0       0.0506  118.469   0.7790  1928
# 1       0.0462   83.972   0.0767  1928
# 2       0.9290  107.177   0.8800  1928
# 3       0.0926  108.003   0.7200  1928
# 4       0.0424   62.149   0.0693  1928

# %%
# check for missing values in the data. It io sseen the data has no missing values
data.isnull().sum()
# Out:
# acousticness        0
# artists             0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# valence             0
# year                0
# dtype: int64

# %%
# check for the dimension of the data
data.shape
# Out:
# (169909, 19)

# %%
# print the names of all columns in the dataset
data.columns
# Out:
# Index(['acousticness', 'artists', 'danceability', 'duration_ms', 'energy',
#        'explicit', 'id', 'instrumentalness', 'key', 'liveness', 'loudness',
#        'mode', 'name', 'popularity', 'release_date', 'speechiness', 'tempo',
#        'valence', 'year'],
#       dtype='object')

# %%
# retrieve the required columns and check
specific_columns = data[['acousticness', 'artists', 'danceability', 'energy', 'id', 'liveness', 
                         'loudness', 'name', 'popularity', 'speechiness', 'tempo', 'valence']]

specific_columns.head()
# Out:
#    acousticness                                   artists  danceability  \
# 0         0.995                       ['Carl Woitschach']         0.708
# 1         0.994  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2         0.604                   ['Seweryn Goszczyński']         0.749
# 3         0.995                      ['Francisco Canaro']         0.781
# 4         0.990  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
#
#    energy                      id  liveness  loudness  \
# 0  0.1950  6KbQ3uYMLKb5jDxLF7wYDD    0.1510   -12.428
# 1  0.0135  6KuQTIu1KoTTkLXKrwlLPV    0.0763   -28.454
# 2  0.2200  6L63VW0PibdM1HDSBoqnoM    0.1190   -19.924
# 3  0.1300  6M94FkXd15sOAOQYRnWPN8    0.1110   -14.734
# 4  0.2040  6N6tiFZ9vLTSOIxkj8qKrd    0.0980   -16.829
#
#                                             name  popularity  speechiness  \
# 0                    Singende Bataillone 1. Teil           0       0.0506
# 1       Fantasiestücke, Op. 111: Più tosto lento           0       0.0462
# 2                 Chapter 1.18 - Zamek kaniowski           0       0.9290
# 3  Bebamos Juntos - Instrumental (Remasterizado)           0       0.0926
# 4    Polonaise-Fantaisie in A-Flat Major, Op. 61           1       0.0424
#
#      tempo  valence
# 0  118.469   0.7790
# 1   83.972   0.0767
# 2  107.177   0.8800
# 3  108.003   0.7200
# 4   62.149   0.0693

# %%
# create id for the artist. Each artist is is linked to a specific id. An artist having multiple rows (obsrvation) has same id
specific_columns['artist_id'] = specific_columns.groupby(['artists']).ngroup()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# check the new dimension of the data
specific_columns.head()
# Out:
#    acousticness                                   artists  danceability  \
# 0         0.995                       ['Carl Woitschach']         0.708
# 1         0.994  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2         0.604                   ['Seweryn Goszczyński']         0.749
# 3         0.995                      ['Francisco Canaro']         0.781
# 4         0.990  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
#
#    energy                      id  liveness  loudness  \
# 0  0.1950  6KbQ3uYMLKb5jDxLF7wYDD    0.1510   -12.428
# 1  0.0135  6KuQTIu1KoTTkLXKrwlLPV    0.0763   -28.454
# 2  0.2200  6L63VW0PibdM1HDSBoqnoM    0.1190   -19.924
# 3  0.1300  6M94FkXd15sOAOQYRnWPN8    0.1110   -14.734
# 4  0.2040  6N6tiFZ9vLTSOIxkj8qKrd    0.0980   -16.829
#
#                                             name  popularity  speechiness  \
# 0                    Singende Bataillone 1. Teil           0       0.0506
# 1       Fantasiestücke, Op. 111: Più tosto lento           0       0.0462
# 2                 Chapter 1.18 - Zamek kaniowski           0       0.9290
# 3  Bebamos Juntos - Instrumental (Remasterizado)           0       0.0926
# 4    Polonaise-Fantaisie in A-Flat Major, Op. 61           1       0.0424
#
#      tempo  valence  artist_id
# 0  118.469   0.7790       4880
# 1   83.972   0.0767      25163
# 2  107.177   0.8800      26351
# 3  108.003   0.7200       9738
# 4   62.149   0.0693      10245

# %%
specific_columns.set_index('artist_id').T.to_dict('list')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   """Entry point for launching an IPython kernel.
# {4880: [0.975,
#   "['Carl Woitschach']",
#   0.622,
#   0.589,
#   '5QgQImiqVwzrWrDfhJep30',
#   0.508,
#   -10.607000000000001,
#   'Kaiser Friedrich Marsch',
#   0,
#   0.0553,
#   122.655,
#   0.846],
#  25163: [0.995,
#   "['Robert Schumann', 'Vladimir Horowitz']",
#   0.335,
#   0.00513,
#   '267ABd8Tm1jV0yGrOMjnih',
#   0.132,
#   -37.321,
#   'Kinderszenen, Op. 15: No. 10, Fast zu ernst',
#   21,
#   0.0461,
#   90.361,
#   0.174],
#  26351: [0.614,
#   "['Seweryn Goszczyński']",
#   0.759,
#   0.136,
#   '6Bf9OsTGQOgWq6PxzRsN2y',
#   0.207,
#   -21.927,
#   'Chapter 3.10 - Zamek kaniowski',
#   0,
#   0.9440000000000001,
#   113.102,
#   0.659],
#  9738: [0.9570000000000001,
#   "['Francisco Canaro']",
#   0.5379999999999999,
#   0.23399999999999999,
#   '4eqwGB6lCj7UIDQaChbbLL',
#   0.081,
#   -12.404000000000002,
#   'Mariposa Nocturna - Remasterizado',
#   0,
#   0.0621,
#   129.197,
#   0.753],
#  10245: [0.9940000000000001,
#   "['Frédéric Chopin', 'Vladimir Horowitz']",
#   0.382,
#   0.205,
#   '6JFq3aShxlO5CyF2FrYXCr',
#   0.696,
#   -17.035,
#   'Scherzo No. 1 in B Minor, Op. 20',
#   0,
#   0.0407,
#   105.78200000000001,
#   0.11800000000000001],
#  9351: [0.995,
#   "['Felix Mendelssohn', 'Vladimir Horowitz']",
#   0.441,
#   0.109,
#   '4bI2cy6httfY5nXnL0aVJQ',
#   0.0917,
#   -20.183,
#   'Scherzo a capriccio: Presto',
#   4,
#   0.0523,
#   127.303,
#   0.314],
#  9943: [0.991,
#   "['Franz Liszt', 'Vladimir Horowitz']",
#   0.44299999999999995,
#   0.0531,
#   '5jfPVHZMhEN2CaRkkRtIGY',
#   0.131,
#   -25.11,
#   'Valse oubliée in F-Sharp Major, S. 215/1',
#   0,
#   0.0482,
#   52.471000000000004,
#   0.11],
#  9712: [0.988,
#   "['Francisco Canaro', 'Charlo']",
#   0.6990000000000001,
#   0.331,
#   '3wI58Cqoq0AmnQ2mYXLQZE',
#   0.128,
#   -10.798,
#   'El Perfume de las Rosas - Remasterizado',
#   0,
#   0.0919,
#   97.634,
#   0.838],
#  26319: [0.992,
#   "['Sergei Rachmaninoff', 'Vladimir Horowitz']",
#   0.266,
#   0.0295,
#   '5AdBHOAZNz4gTFUaCZloEF',
#   0.071,
#   -26.044,
#   'Prelude No. 12 in G Sharp Minor, Op. 32',
#   36,
#   0.04,
#   61.738,
#   0.066],
#  25971: [0.987,
#   "['Samuel Barber', 'Vladimir Horowitz']",
#   0.242,
#   0.258,
#   '3ybXfEwF7L5665Rl6ro5T3',
#   0.354,
#   -19.282,
#   'Piano Sonata in E-Flat Minor, Op. 26: I. Allegro energico',
#   0,
#   0.037000000000000005,
#   113.421,
#   0.0688],
#  18854: [0.985,
#   "['Ludwig van Beethoven', 'Staatskapelle Berlin', 'Richard Strauss']",
#   0.359,
#   0.35700000000000004,
#   '5kcaEVw6HbPT7BXrhf5Eju',
#   0.27899999999999997,
#   -13.51,
#   'Symphony No. 5 in C Minor, Op. 67: 1. Allegro con brio',
#   0,
#   0.0826,
#   105.641,
#   0.152],
#  10705: [0.9940000000000001,
#   "['George Butterworth', 'John Cameron']",
#   0.502,
#   0.19899999999999998,
#   '5WTP0iaaQoyDUpNRqRBzy0',
#   0.10400000000000001,
#   -12.435,
#   'A Shropshire Lad: Think No More, Lad',
#   0,
#   0.0373,
#   106.759,
#   0.588],
#  1267: [0.992,
#   "['Alexander Scriabin', 'Vladimir Horowitz']",
#   0.21600000000000005,
#   0.374,
#   '6DjkA3GwyDPn6QPck1qIyf',
#   0.7879999999999999,
#   -17.351,
#   'Etude In C-Sharp Minor, Op. 42 No. 5',
#   0,
#   0.040999999999999995,
#   78.017,
#   0.0755],
#  9729: [0.9940000000000001,
#   "['Francisco Canaro', 'Luis Scalon']",
#   0.743,
#   0.203,
#   '0C4XVOWXyYRNyipPK86xQJ',
#   0.134,
#   -13.203,
#   'Carro Viejo - Remasterizado',
#   0,
#   0.0917,
#   116.195,
#   0.8959999999999999],
#  30041: [0.9890000000000001,
#   "['Thomas Arne', 'John Heddle Nash']",
#   0.57,
#   0.109,
#   '673HCDZAkZY1cOt9pBmcUp',
#   0.11199999999999999,
#   -17.64,
#   'Under the Greenwood Tree',
#   0,
#   0.11599999999999999,
#   72.215,
#   0.41100000000000003],
#  21126: [0.988,
#   "['Moritz Moszkowski', 'Vladimir Horowitz']",
#   0.32299999999999995,
#   0.29,
#   '2gzbvyQjmR5qCvJBXQUEpn',
#   0.7190000000000001,
#   -21.648000000000003,
#   'Étude in A-flat Major, Op. 72, No. 11',
#   1,
#   0.0752,
#   72.184,
#   0.361],
#  25288: [0.99,
#   "['Roger Quilter', 'John Heddle Nash']",
#   0.35700000000000004,
#   0.109,
#   '5REXbj74KXCIh7Op3t6Uh9',
#   0.0817,
#   -20.655,
#   'Come Away Death',
#   0,
#   0.0405,
#   63.75899999999999,
#   0.207],
#  12277: [0.995,
#   "['Hafız Yaşar']",
#   0.442,
#   0.34,
#   '7ahv6TGZoqzaF5vaNSFAyF',
#   0.183,
#   -13.417,
#   'Zahimdari Hicri Yar',
#   0,
#   0.10400000000000001,
#   72.539,
#   0.12300000000000001],
#  21330: [0.9940000000000001,
#   "['Muzio Clementi', 'Vladimir Horowitz']",
#   0.369,
#   0.166,
#   '66YnSi3KSGDwPfb9JdWbPC',
#   0.09699999999999999,
#   -22.245,
#   'Sonata, Op. 34, No. 2 in G Minor: I. Largo; Allegro con fuoco',
#   0,
#   0.0534,
#   136.248,
#   0.135],
#  13079: [0.925,
#   "['Ignacio Corsini']",
#   0.485,
#   0.303,
#   '23mXGyQH4sWYI5PY0RefcE',
#   0.193,
#   -15.696,
#   'Pampa Luna - Remasterizado',
#   0,
#   0.125,
#   93.90700000000001,
#   0.363],
#  26669: [0.4920000000000001,
#   "['Shungi Music Crew']",
#   0.7709999999999999,
#   0.818,
#   '6Jg1cMlHS3xaexvhjXcWGT',
#   0.348,
#   -6.2139999999999995,
#   'Cant Be There',
#   0,
#   0.0663,
#   122.20200000000001,
#   0.455],
#  23127: [0.993,
#   "['Perchicot']",
#   0.569,
#   0.312,
#   '1ssmmcu30tT05PKbBgxh3S',
#   0.156,
#   -10.911,
#   'La Chanson Française',
#   0,
#   0.0919,
#   135.851,
#   0.792],
#  7604: [0.993,
#   "['Dmitry Kabalevsky', 'Vladimir Horowitz']",
#   0.3720000000000001,
#   0.0945,
#   '4IbcCM5llepYSpmhHJ7saD',
#   0.18899999999999997,
#   -22.709,
#   'Sonata No. 3, Op. 46: II. Andante cantabile',
#   0,
#   0.0317,
#   59.217,
#   0.0791],
#  23020: [0.988,
#   "['Paul Whiteman']",
#   0.718,
#   0.147,
#   '6Bad1QMVqCMutswNuBRcaK',
#   0.28300000000000003,
#   -17.014,
#   "'Tain't So, Honey, 'Tain't So",
#   0,
#   0.0429,
#   108.37200000000001,
#   0.722],
#  28308: [0.9570000000000001,
#   "['Ted Weems & His Orchestra']",
#   0.838,
#   0.479,
#   '6HmSRTXwzOjF0mNbh4tSom',
#   0.133,
#   -9.698,
#   'Marvelous',
#   0,
#   0.0331,
#   107.616,
#   0.8440000000000001],
#  28132: [0.905,
#   "['Taj Mahal']",
#   0.591,
#   0.47100000000000003,
#   '3hKwsWbBTbG6GnoabrN8mG',
#   0.105,
#   -12.583,
#   "Ain't Nobody's Business",
#   30,
#   0.302,
#   173.968,
#   0.731],
#  15206: [0.986,
#   "['John Raitt']",
#   0.26,
#   0.171,
#   '48ZIEFRrjq6CeFBcG5wQra',
#   0.19,
#   -13.573,
#   'Hey There (from "The Pajama Game") - from "The Pajama Game"',
#   2,
#   0.0343,
#   83.39,
#   0.132],
#  17643: [0.884,
#   "['Leroy Carr']",
#   0.514,
#   0.165,
#   '5yUUNMnhh3eYCMIkN06LJU',
#   0.141,
#   -14.237,
#   'Tight Time Blues',
#   0,
#   0.0422,
#   88.38799999999998,
#   0.727],
#  12736: [0.995,
#   "['Hikmet Rıza Hanım']",
#   0.33899999999999997,
#   0.267,
#   '2CYS38UCmg4QnY6durw4H4',
#   0.12,
#   -9.97,
#   'Ruhumda Ah',
#   0,
#   0.0481,
#   82.036,
#   0.415],
#  8604: [0.98,
#   "['Elsie Houston']",
#   0.736,
#   0.231,
#   '2dUrX0PNlWncN63zDL22Br',
#   0.126,
#   -7.13,
#   'Aribu',
#   0,
#   0.0701,
#   79.283,
#   0.637],
#  33092: [0.948,
#   "['Αντώνης Νταλγκάς']",
#   0.551,
#   0.397,
#   '0k3oKpHhujpT60wAOYiJdy',
#   0.0851,
#   -8.257,
#   'Μπαγλαμάδες',
#   0,
#   0.0536,
#   127.915,
#   0.6859999999999999],
#  27439: [0.992,
#   "['Stellakis Perpiniadis']",
#   0.541,
#   0.42100000000000004,
#   '2J2OFzt2KZp14xgp5xOzzU',
#   0.22899999999999998,
#   -10.277000000000001,
#   'Stri Vre Koutsavaki',
#   1,
#   0.0523,
#   143.959,
#   0.9209999999999999],
#  33089: [0.976,
#   "['Αντώνης Διαμαντίδης']",
#   0.47200000000000003,
#   0.43799999999999994,
#   '3tIWS1Bp8USD777mG05tPN',
#   0.337,
#   -7.581,
#   'Αλή Πασάς I',
#   0,
#   0.0531,
#   96.404,
#   0.5760000000000001],
#  25692: [0.992,
#   "['S. Loukopoulos', 'Klarino G. Anestopoulos', 'Klarino KOstas Giaouzos', 'Klarinos Nikos Karakostas']",
#   0.368,
#   0.263,
#   '3zK60VaQyLm9Tbrji7v4eX',
#   0.28800000000000003,
#   -16.262999999999998,
#   'Xipna Pouli Mou To Proi',
#   0,
#   0.0476,
#   101.447,
#   0.312],
#  22780: [0.9229999999999999,
#   "['Paradosiako I. KIriakatis']",
#   0.295,
#   0.557,
#   '3CtmIunn3WtwisKdSUBAE8',
#   0.243,
#   -10.155,
#   'Mia Papadia',
#   0,
#   0.0688,
#   177.04,
#   0.909],
#  21185: [0.973,
#   "['Moune De Rivel']",
#   0.5770000000000001,
#   0.17800000000000002,
#   '3BSqWmo9XI5ZTKbG2GBPAd',
#   0.184,
#   -19.35,
#   'Feuilles',
#   0,
#   0.0461,
#   137.49,
#   0.578],
#  7428: [0.993,
#   "['Dimitris Gkogkos']",
#   0.71,
#   0.318,
#   '3XgZ4JIlJQLo7GLtumUaG9',
#   0.177,
#   -12.411,
#   'To alani',
#   0,
#   0.0415,
#   94.265,
#   0.777],
#  11417: [0.9840000000000001,
#   "['Giorgos Papasideris']",
#   0.365,
#   0.273,
#   '0hVOC24TPXrlB1niwAN2al',
#   0.594,
#   -15.38,
#   'Xitzazkiar Manes Gkazeli Sirf',
#   0,
#   0.0787,
#   134.094,
#   0.295],
#  23246: [0.993,
#   "['Petros Epitropakis', 'Antonis Kalampousis']",
#   0.562,
#   0.389,
#   '2kMiZo7KJvydCxTue9uFsf',
#   0.254,
#   -10.242,
#   'Koumparoula',
#   0,
#   0.04,
#   96.04,
#   0.7120000000000001],
#  5112: [0.361,
#   "['Cellular Project']",
#   0.611,
#   0.8290000000000001,
#   '2ma7knM1nPQSfAahlRzrXv',
#   0.375,
#   -6.4270000000000005,
#   'For the Love of It',
#   0,
#   0.0307,
#   120.541,
#   0.9490000000000001],
#  9727: [0.973,
#   "['Francisco Canaro', 'Luis Diaz']",
#   0.406,
#   0.45399999999999996,
#   '3OKdplss1WsO85vLmHtGls',
#   0.38299999999999995,
#   -6.712999999999999,
#   '¿Puede Ser? - Remasterizado',
#   0,
#   0.0959,
#   147.15,
#   0.514],
#  27166: [0.996,
#   "['Sotiris Stasinopoulos']",
#   0.4270000000000001,
#   0.33799999999999997,
#   '3T1w24fL8b4NVZY0sQ0P0G',
#   0.166,
#   -15.392999999999999,
#   'Stin Patra Mes Ton Kafene',
#   0,
#   0.113,
#   72.918,
#   0.583],
#  22136: [0.985,
#   "['Nota Kaleli']",
#   0.735,
#   0.406,
#   '3WvKy6LXTSzZNeIBQSF6Wj',
#   0.155,
#   -12.815999999999999,
#   'Pagkratiotissa mou',
#   0,
#   0.0566,
#   77.025,
#   0.847],
#  25088: [0.943,
#   "['Robert Francis']",
#   0.501,
#   0.214,
#   '2wsMChGh9edi3V2sgjv5wn',
#   0.141,
#   -11.222999999999999,
#   'I Fall in Love Too Easily',
#   1,
#   0.0331,
#   106.764,
#   0.34700000000000003],
#  9735: [0.988,
#   "['Francisco Canaro', 'Roberto Maida']",
#   0.639,
#   0.25,
#   '7xLAwuepFeJn4Ca1JEHYsk',
#   0.10800000000000001,
#   -11.417,
#   '¿Donde? - Remasterizado',
#   0,
#   0.0471,
#   123.49700000000001,
#   0.787],
#  28662: [0.99,
#   "['The Caresser']",
#   0.62,
#   0.244,
#   '4FEMPPbzkzswZCT5XdIwUV',
#   0.12,
#   -16.169,
#   'Theodor',
#   0,
#   0.174,
#   96.34700000000001,
#   0.8140000000000001],
#  27181: [0.995,
#   "['Soula Karagiorgi']",
#   0.4,
#   0.433,
#   '3ZjkJVSvASnoADaUm75OeP',
#   0.428,
#   -9.74,
#   'Giati Na Fugeis',
#   0,
#   0.0941,
#   106.411,
#   0.452],
#  29350: [0.15,
#   "['The Merlons']",
#   0.563,
#   0.574,
#   '2wVeRaZMBQWiTAn7l5p24O',
#   0.255,
#   -12.379000000000001,
#   'Romanior',
#   0,
#   0.027999999999999997,
#   137.971,
#   0.617],
#  9711: [0.992,
#   "['Francisco Canaro', 'Charlo', 'Angel Ramos']",
#   0.469,
#   0.48700000000000004,
#   '5GIsPBfq12xmAuvJjdOnSZ',
#   0.767,
#   -6.763,
#   'Lupe - Remasterizado',
#   0,
#   0.191,
#   155.999,
#   0.743],
#  33174: [0.9690000000000001,
#   "['Κώστας Δούσιας']",
#   0.589,
#   0.392,
#   '2N2AspBNmayY1jGk9RGRUy',
#   0.0877,
#   -11.329,
#   'Μανωλάκης ο χασικλης',
#   0,
#   0.0533,
#   159.85,
#   0.655],
#  20790: [0.995,
#   "['Miltiadis Kazis']",
#   0.508,
#   0.525,
#   '1Op4qlbSfphZs3Xv4qhWnh',
#   0.22,
#   -8.352,
#   'Tsatsa Nikolakaina',
#   0,
#   0.0564,
#   130.47299999999998,
#   0.821],
#  4903: [0.995,
#   "['Carlos Gardel']",
#   0.521,
#   0.29,
#   '3sO8kzKFRu8e4EEbNJRym2',
#   0.47600000000000003,
#   -15.484000000000002,
#   'Pobre paica el motivo',
#   1,
#   0.124,
#   78.16199999999998,
#   0.522],
#  24192: [0.9940000000000001,
#   "['Raquel Meller']",
#   0.591,
#   0.1,
#   '3jw2E8xkqP0BRQrblQKl7o',
#   0.182,
#   -10.708,
#   'La Violetera',
#   0,
#   0.248,
#   112.712,
#   0.569],
#  264: [0.995,
#   '["Sam Manning\'s and His Cole Jazz Orchestra"]',
#   0.664,
#   0.28300000000000003,
#   '42WDMm9hX0xCFkkKpt6NOY',
#   0.109,
#   -18.301,
#   'Bungo',
#   0,
#   0.0807,
#   99.506,
#   0.688],
#  28997: [0.821,
#   "['The Four Deuces']",
#   0.627,
#   0.795,
#   '42r18phTFwegQjdbeDnFyN',
#   0.105,
#   -0.395,
#   'Fore Day in the Morning',
#   0,
#   0.136,
#   100.715,
#   0.975],
#  2870: [0.958,
#   "['Banda del Regimiento Pérez 3 de Infantería', 'Adrián Patiño']",
#   0.7240000000000001,
#   0.387,
#   '2LcbLg2f7XPOeb05afiuGR',
#   0.10300000000000001,
#   -11.28,
#   'Despedida De Tarija (Boleros de Caballería)',
#   0,
#   0.0563,
#   100.96600000000001,
#   0.7979999999999999],
#  26608: [4.85e-05,
#   "['Shiny Gnomes']",
#   0.456,
#   0.8170000000000001,
#   '7HDZRSZtYADCTSG4My54f3',
#   0.188,
#   -5.997000000000001,
#   'Spirit of the Band',
#   0,
#   0.0334,
#   124.119,
#   0.48700000000000004],
#  23247: [0.9440000000000001,
#   "['Petros Epitropakis', 'Elvira Nte Ntalgko']",
#   0.433,
#   0.45799999999999996,
#   '432t2QZQYpOJdEHmb60JAp',
#   0.0641,
#   -10.689,
#   'Mparmpa Giannis Kanatas',
#   0,
#   0.0585,
#   65.672,
#   0.716],
#  22785: [0.9840000000000001,
#   "['Paradosiako']",
#   0.48100000000000004,
#   0.369,
#   '2nkkEaaBwbVhYXblHZEODA',
#   0.353,
#   -12.135,
#   'LIaskoviki',
#   0,
#   0.0588,
#   78.317,
#   0.8420000000000001],
#  13262: [0.992,
#   "['Ioannis Panagiotopoulos']",
#   0.499,
#   0.515,
#   '3hs6LnvVpkdUn0nwUXx4dW',
#   0.109,
#   -10.193,
#   'To Pino Mana To Krasi',
#   0,
#   0.0495,
#   121.07799999999999,
#   0.92],
#  18414: [0.973,
#   "['Los Peregrinos']",
#   0.621,
#   0.688,
#   '1U4NlYFKORNtgQfCPpZdR2',
#   0.314,
#   -10.385,
#   'Cholita Kihui',
#   0,
#   0.0512,
#   99.663,
#   0.7609999999999999],
#  6412: [0.9890000000000001,
#   "['D.roitman']",
#   0.23800000000000002,
#   0.08,
#   '1oVcFrwK4pGFh9UKLP8Jsy',
#   0.0956,
#   -19.131,
#   "V'haarev no",
#   0,
#   0.0578,
#   65.794,
#   0.077],
#  4902: [0.991,
#   "['Carlos Galhardo']",
#   0.7120000000000001,
#   0.623,
#   '44NkmEmGvCudWCfqWklKIq',
#   0.303,
#   -9.828,
#   'O Palhaço o Que É?',
#   7,
#   0.04,
#   134.58,
#   0.9259999999999999],
#  26977: [0.995,
#   "['Smt. Angurbala Devi']",
#   0.258,
#   0.142,
#   '2zJ1KG7qjCu5rwbvR62fEX',
#   0.138,
#   -18.102,
#   'Ogo Priyotama Ogo Premomoy',
#   0,
#   0.0597,
#   74.84100000000002,
#   0.18100000000000002],
#  25504: [0.991,
#   "['Roza Eskenazi']",
#   0.545,
#   0.373,
#   '3wljMDemL3QKII2q8k3Lft',
#   0.297,
#   -12.727,
#   'As ta logia',
#   0,
#   0.0526,
#   142.951,
#   0.934],
#  19756: [0.963,
#   "['Marika Papaggika']",
#   0.332,
#   0.73,
#   '1pNYexTOb0ZDgWYsFPeyJd',
#   0.474,
#   -6.614,
#   'Ta kommena ta mallia soy',
#   0,
#   0.0651,
#   152.97,
#   0.738],
#  23413: [0.993,
#   "['Pirros Xronidis']",
#   0.423,
#   0.409,
#   '45i0kvbyPfVaST8OX5VyXb',
#   0.342,
#   -11.573,
#   'Ki An Metaniosoume',
#   0,
#   0.0364,
#   100.719,
#   0.617],
#  7424: [0.99,
#   "['Dimitris Arapakis']",
#   0.39299999999999996,
#   0.382,
#   '2IlokC1WAvLhFvq0AZFQlF',
#   0.272,
#   -9.555,
#   'O Menousis',
#   0,
#   0.0521,
#   83.431,
#   0.551],
#  10667: [0.983,
#   "['Gene Sedric', 'Al Casey']",
#   0.564,
#   0.191,
#   '47Yn2O8dgxSzyWDrq4n7Nx',
#   0.168,
#   -11.107999999999999,
#   'Wail Of The Scromph',
#   2,
#   0.0319,
#   86.405,
#   0.38799999999999996],
#  16839: [0.993,
#   "['Kostas Tsanakos']",
#   0.348,
#   0.215,
#   '23qyLwj4z0CJCqILIYvYBN',
#   0.11,
#   -15.613,
#   'Krifa Tha Pantreftoume',
#   0,
#   0.0407,
#   143.996,
#   0.823],
#  27967: [0.905,
#   "['Sy Oliver', 'Attila the Hun', 'Jimmie Lunceford & His Orchestra']",
#   0.8,
#   0.166,
#   '493O6Uf84IQH4SH4Scumay',
#   0.0883,
#   -14.921,
#   "Hittin' the Bottle",
#   1,
#   0.0779,
#   104.06,
#   0.617],
#  22892: [0.991,
#   "['Patrício Teixeira']",
#   0.534,
#   0.19899999999999998,
#   '49OPPHZzx3svtdYt4ffCQV',
#   0.11,
#   -15.419,
#   'Gavião Calçudo',
#   0,
#   0.0685,
#   100.38600000000001,
#   0.578],
#  11386: [0.904,
#   "['Giorgos Papasideris', 'Klarino Har. Margels']",
#   0.502,
#   0.494,
#   '49gHX66DkP4yrMT6hng6UO',
#   0.0844,
#   -7.685,
#   'Gia Sou Kaimeni Leventia',
#   0,
#   0.0388,
#   112.03299999999999,
#   0.9309999999999999],
#  733: [0.987,
#   "['ANTONIS NTALGKAS']",
#   0.489,
#   0.602,
#   '0h34UFsWvpnr8hUJegposj',
#   0.264,
#   -8.657,
#   'Katinaki',
#   0,
#   0.0718,
#   161.467,
#   0.966],
#  16835: [0.995,
#   "['Kostas Roukounas']",
#   0.528,
#   0.313,
#   '23p5XjS2cccqNvO0rL4qnJ',
#   0.12,
#   -17.385,
#   'Ithela Na Moun Tseligkas',
#   0,
#   0.055,
#   116.163,
#   0.946],
#  9719: [0.927,
#   "['Francisco Canaro', 'Ernesto Fama']",
#   0.63,
#   0.488,
#   '27LkKPxyvPQJmtlTEVJJZj',
#   0.0583,
#   -7.358,
#   'La Cuarentona - Remasterizado',
#   0,
#   0.19699999999999998,
#   160.187,
#   0.8029999999999999],
#  13623: [0.97,
#   "['Jack Payne']",
#   0.314,
#   0.0506,
#   '3qg5iSELuv5WqeqxWX3Krp',
#   0.114,
#   -22.294,
#   "You're Always in My Arms",
#   1,
#   0.0369,
#   83.93700000000003,
#   0.335],
#  12882: [0.982,
#   "['Hrisoula Stini']",
#   0.7390000000000001,
#   0.426,
#   '2TUhVomiMjXJvCwvydFeLe',
#   0.109,
#   -9.887,
#   'Eimai Erotevmenos Me Ta Matia Sou',
#   0,
#   0.0323,
#   108.56,
#   0.8320000000000001],
#  18246: [0.835,
#   "['Lord Kitchener']",
#   0.6990000000000001,
#   0.9620000000000001,
#   '6ESkjj0HJZqUNgqhRCgVoW',
#   0.0996,
#   0.523,
#   'Trouble in Arima',
#   1,
#   0.0412,
#   105.395,
#   0.965],
#  26653: [0.368,
#   "['Shorty Bralik', 'ParkPlace Swagg']",
#   0.7609999999999999,
#   0.629,
#   '1Lvc7UtFcsxt94ozIeY3Rr',
#   0.107,
#   -8.651,
#   'Gang Gang',
#   0,
#   0.494,
#   139.99,
#   0.45],
#  19553: [0.9940000000000001,
#   "['Manuel Ponce', 'Andrés Segovia']",
#   0.38,
#   0.0213,
#   '0ZJxdJb9oS2GVXxWrAdmsO',
#   0.115,
#   -35.042,
#   'Sonatina Meridional p.1',
#   0,
#   0.0381,
#   138.43,
#   0.38],
#  9638: [0.993,
#   "['Fragiskos Dimitriou']",
#   0.293,
#   0.21100000000000002,
#   '4DSIEavoLru6Dn5OKrP1Uw',
#   0.11199999999999999,
#   -11.083,
#   'Ntoulas',
#   0,
#   0.0391,
#   89.13,
#   0.56],
#  11359: [0.986,
#   "['Giorgos Mpekas', 'Polixeni LItou']",
#   0.5479999999999999,
#   0.289,
#   '4DlATZ1MIXLxb1WbA6utuO',
#   0.102,
#   -8.432,
#   'Vasilikos Tha Gino',
#   0,
#   0.0411,
#   122.28399999999999,
#   0.757],
#  7426: [0.995,
#   "['Dimitris Filipopoulos']",
#   0.342,
#   0.36200000000000004,
#   '0bXBEpYU3fxTTO6REnTCmj',
#   0.609,
#   -10.732999999999999,
#   'Giati giati giati',
#   0,
#   0.0371,
#   127.428,
#   0.613],
#  9728: [0.992,
#   "['Francisco Canaro', 'Luis Díaz']",
#   0.7,
#   0.389,
#   '3KHp0BikWu4UzjIEqhfVHd',
#   0.6759999999999999,
#   -8.506,
#   'Ay, Josefina - Remasterizado',
#   0,
#   0.0863,
#   108.31,
#   0.9109999999999999],
#  22779: [0.8759999999999999,
#   "['Paradosiako Har. Margelis']",
#   0.45899999999999996,
#   0.479,
#   '3rFViAWWvlG85BtLSdGVyt',
#   0.131,
#   -11.013,
#   'Apano Pai To Nero',
#   0,
#   0.0459,
#   127.015,
#   0.8170000000000001],
#  24447: [0.995,
#   "['Renos Talmas', 'Panos Visvardis']",
#   0.345,
#   0.395,
#   '4GcaZeQH8XpwlXTVdf8T3y',
#   0.342,
#   -11.025,
#   "Tosoi Sou Eipan S'agapo",
#   0,
#   0.0353,
#   126.39,
#   0.653],
#  266: [0.986,
#   '["Scarlet D\'Carpio"]',
#   0.313,
#   0.126,
#   '7J39equrLyLGQK1aO5e0rD',
#   0.129,
#   -11.713,
#   "H'acuchu",
#   0,
#   0.0446,
#   72.012,
#   0.418],
#  7427: [0.983,
#   "['Dimitris Gkogkos', 'Manolis Xiotis']",
#   0.5670000000000001,
#   0.547,
#   '4HlNijxuoeNkexYmTPOIhh',
#   0.113,
#   -12.907,
#   'To perasma',
#   0,
#   0.0433,
#   107.78200000000001,
#   0.929],
#  22603: [0.68,
#   "['Oρχήστρα Β.Reibold', 'Τέτος Δημητριάδης']",
#   0.5710000000000001,
#   0.5429999999999999,
#   '4IR8qww21dJImL5VmpBMPJ',
#   0.47700000000000004,
#   -9.035,
#   'Σόνια',
#   0,
#   0.0868,
#   101.90299999999999,
#   0.7340000000000001],
#  16829: [0.995,
#   "['Kostas Nouros']",
#   0.391,
#   0.21600000000000005,
#   '31B7dlhuhid4pex9QtxQ2n',
#   0.12,
#   -13.593,
#   'Xasapaki',
#   0,
#   0.0595,
#   141.649,
#   0.596],
#  25014: [0.889,
#   "['Rita Ampatzi']",
#   0.5670000000000001,
#   0.685,
#   '2J0ZtdYTLm5fBakQYxtBXS',
#   0.33299999999999996,
#   -7.267,
#   'Mpallos (paradosiako)',
#   0,
#   0.0622,
#   92.62,
#   0.655],
#  6687: [0.9520000000000001,
#   "['Danai Stratigopoulou', 'Panos Visvardis']",
#   0.546,
#   0.525,
#   '2yLXg19GX0b7fmyb8WkgRi',
#   0.13,
#   -13.372,
#   'Exeis Matakia',
#   0,
#   0.0528,
#   80.655,
#   0.861],
#  33121: [0.759,
#   "['Γιώργος Κατσαρός']",
#   0.687,
#   0.297,
#   '2lVyepgRH8OsyImbNelIAB',
#   0.0848,
#   -13.425,
#   'Εχτές το βράδυ στου Καρίπη',
#   0,
#   0.0571,
#   115.963,
#   0.5379999999999999],
#  11421: [0.993,
#   "['Giota Lidia', 'Prodromos Tsaousakis']",
#   0.613,
#   0.311,
#   '4KTaMgC3vIdYo4K4CU85Cm',
#   0.134,
#   -11.212,
#   'Ο μετανάστης',
#   0,
#   0.0451,
#   119.633,
#   0.961],
#  27051: [0.965,
#   "['Sofia Iatridou']",
#   0.38799999999999996,
#   0.27,
#   '3vycmR8znRtYfsM4KDKmWx',
#   0.0752,
#   -11.949000000000002,
#   'Ziliara Mou',
#   1,
#   0.0395,
#   170.479,
#   0.8220000000000001],
#  9292: [0.978,
#   "['Federico Moreno Torroba', 'Vicente Gomez', 'Guillermo Gomez']",
#   0.4970000000000001,
#   0.13,
#   '2G33ABZPZDkCjGYOfYnAfO',
#   0.10400000000000001,
#   -23.978,
#   'Suite Castellana: Fandanguillo',
#   0,
#   0.0593,
#   110.459,
#   0.701],
#  26783: [0.602,
#   "['Sinclair Lewis', 'Frank Arnold']",
#   0.71,
#   0.196,
#   '4gMn6tEvpuXIj6qq5WZSTA',
#   0.325,
#   -17.71,
#   'Das ist bei uns nicht möglich, Kapitel 182',
#   0,
#   0.96,
#   75.723,
#   0.49],
#  9891: [0.9690000000000001,
#   "['Franz Joseph Haydn', 'Pro Arte Quartet']",
#   0.586,
#   0.168,
#   '4Oa4DWAke3AGDv9pRYVThm',
#   0.0843,
#   -14.345999999999998,
#   'Haydn: String Quartet No. 47 in B-Flat Major, Op. 55 No. 3, Hob. III, 62: III. Menuetto',
#   0,
#   0.0642,
#   76.485,
#   0.644],
#  33296: [0.867,
#   "['Эрнест Хемингуэй']",
#   0.499,
#   0.39299999999999996,
#   '15O4Sv0Vghsnyx3Kd2J4Rx',
#   0.6779999999999999,
#   -16.936,
#   'Часть 14.3 & Часть 15.1 - Старик и море',
#   0,
#   0.0724,
#   108.723,
#   0.381],
#  21939: [0.9890000000000001,
#   "['Nikos Karakostas']",
#   0.585,
#   0.5,
#   '2AjlRGde4XJlOWgKZt6fWS',
#   0.0931,
#   -7.4170000000000025,
#   'La patroy tzintzi marmari, solo klarino',
#   0,
#   0.0554,
#   85.88600000000002,
#   0.922],
#  19671: [0.991,
#   "['Margarita Cueto', 'Jorge Añez']",
#   0.7509999999999999,
#   0.134,
#   '4iCz3Nr7IryTuxf2PNhcXd',
#   0.13,
#   -13.177,
#   'Los Promeseritos',
#   0,
#   0.446,
#   81.293,
#   0.45899999999999996],
#  6254: [0.948,
#   "['Cristian Vasile']",
#   0.569,
#   0.242,
#   '4BfeKnKYqagOKKpfE6veGK',
#   0.384,
#   -13.995,
#   'Dă-mi o zi din viața ta',
#   0,
#   0.0442,
#   105.75200000000001,
#   0.584],
#  31361: [0.9329999999999999,
#   "['Viorel Demetriad']",
#   0.514,
#   0.20199999999999999,
#   '4L7NE9YbwFKjSkem40fqQi',
#   0.25,
#   -13.994000000000002,
#   'Vino la noapte în barul meu',
#   0,
#   0.0504,
#   120.583,
#   0.534],
#  25569: [0.909,
#   "['Ruggero Leoncavallo', 'Karl Böhm', 'Staatskapelle Dresden']",
#   0.21100000000000002,
#   0.17800000000000002,
#   '4k8gfZc9CfCiUQ7OQ9Q4bZ',
#   0.0861,
#   -16.840999999999998,
#   'Leoncavallo: Pagliacci, Act 1: Intermezzo',
#   0,
#   0.0415,
#   74.311,
#   0.0359],
#  23244: [0.993,
#   "['Petre Alexandru']",
#   0.419,
#   0.299,
#   '4MN4MVzOkaauiPJj6fnyyv',
#   0.0961,
#   -13.623,
#   'Parcă ieri ne-am iubit',
#   0,
#   0.0491,
#   118.67399999999999,
#   0.635],
#  15008: [0.98,
#   "['Johannes Brahms', 'Karl Böhm', 'Staatskapelle Dresden']",
#   0.4320000000000001,
#   0.193,
#   '4XTfmG3UMLLfh5w4VWlUuN',
#   0.267,
#   -16.743,
#   'Brahms: Piano Concerto No. 2 in B-Flat Major, Op. 83: II. Allegro appassionato',
#   0,
#   0.0333,
#   113.685,
#   0.23600000000000002],
#  25965: [0.986,
#   "['Samuel Barber', 'Marilyn Horne']",
#   0.3720000000000001,
#   0.318,
#   '2CxOLpJrQVPrOGnq1H9vQU',
#   0.311,
#   -13.002,
#   '3 Songs, Op. 10: 3. I Hear an Army',
#   0,
#   0.0469,
#   116.492,
#   0.11900000000000001],
#  1975: [0.86,
#   "['Anton Bruckner', 'Karl Böhm', 'Staatskapelle Dresden']",
#   0.341,
#   0.141,
#   '3TpzrQWTIxDzTH7wB4ouZE',
#   0.0698,
#   -15.879000000000001,
#   'Bruckner: Symphony No. 5 in B-Flat Major: III. Scherzo - Molto vivace',
#   0,
#   0.0432,
#   129.464,
#   0.172],
#  27670: [0.991,
#   "['Stratos Pagioumtzis']",
#   0.845,
#   0.33299999999999996,
#   '23TV8AevoJLOAhMhoxfwoZ',
#   0.0906,
#   -12.305,
#   'Pistepse me paixnidiara',
#   0,
#   0.0503,
#   128.6,
#   0.6990000000000001],
#  19633: [0.982,
#   "['Marcelle Bordas']",
#   0.637,
#   0.21100000000000002,
#   '4mNmdGAJBVXnyRQoSAHldN',
#   0.0927,
#   -14.645999999999999,
#   'La Femme À Barbe',
#   0,
#   0.134,
#   115.78,
#   0.644],
#  16061: [0.995,
#   "['Kakkia Mendri', 'Lidia Likiardopoulou', '2014 ATHINAIKI DISCOGRAFIKI']",
#   0.501,
#   0.341,
#   '4pRTgwUEHWSHSpsirCkl1s',
#   0.418,
#   -11.514000000000001,
#   'An xanagirizes',
#   0,
#   0.0814,
#   109.956,
#   0.621],
#  25963: [0.9690000000000001,
#   "['Samuel Barber', 'Leontyne Price', 'Thomas Schippers', 'New Philharmonia Orchestra']",
#   0.201,
#   0.11599999999999999,
#   '29cS4CtsVZqTrL0PyYewTT',
#   0.0621,
#   -17.93,
#   'Antony and Cleopatra, Op. 40: Give Me Some Music',
#   0,
#   0.0475,
#   83.87700000000002,
#   0.0357],
#  25962: [0.878,
#   "['Samuel Barber', 'Leonard Slatkin', 'St. Louis Symphony']",
#   0.0839,
#   0.0304,
#   '1n0qRbwRPRxB7MShO6u9fx',
#   0.0978,
#   -21.898000000000003,
#   'Symphony No. 1, Op. 9: III. Andante tranquillo',
#   0,
#   0.045,
#   171.09599999999998,
#   0.0309],
#  20191: [0.917,
#   "['Max Reger', 'Karl Böhm', 'Staatskapelle Dresden']",
#   0.313,
#   0.214,
#   '4a3sZBCJPBN3loV6WwwuRr',
#   0.126,
#   -16.892,
#   'Reger: Variations and Fugue on a Theme of Mozart, Op. 132: VI. Var. V (Quasi presto)',
#   0,
#   0.0468,
#   85.179,
#   0.266],
#  14093: [0.966,
#   "['Jean Moscopol']",
#   0.578,
#   0.36,
#   '4e1YMQGlSSqSs5DIKQCsp4',
#   0.8540000000000001,
#   -13.607000000000001,
#   'Ași voi să te iert',
#   0,
#   0.0863,
#   121.595,
#   0.5],
#  14197: [0.875,
#   "['Jeff Stetson']",
#   0.332,
#   0.379,
#   '4bCbVc0JFwYemjqSBHBs94',
#   0.134,
#   -9.904,
#   'Motherland',
#   0,
#   0.0288,
#   125.32600000000001,
#   0.35],
#  14110: [0.8590000000000001,
#   "['Jean Sibelius', 'Jascha Heifetz', 'Sir Thomas Beecham', 'London Philharmonic Orchestra']",
#   0.485,
#   0.209,
#   '2LABSUwtKIL8u417gCSAux',
#   0.45299999999999996,
#   -18.94,
#   'Violin Concerto in D minor Op. 47: III. Allegro ma non tanto',
#   1,
#   0.0471,
#   119.368,
#   0.23],
#  2540: [0.5920000000000001,
#   "['Avelino Muñoz']",
#   0.9209999999999999,
#   0.7490000000000001,
#   '4Y7yZIB7SsMbkCjXsG7Ucq',
#   0.32299999999999995,
#   -11.18,
#   'Cuchareta',
#   0,
#   0.183,
#   118.057,
#   0.963],
#  9017: [0.9840000000000001,
#   "['Eugen Mirea', 'V. Citov', 'Manole Stroici']",
#   0.5579999999999999,
#   0.228,
#   '4u8gssQxavBHHfAQF2OW4l',
#   0.105,
#   -12.720999999999998,
#   'De închiriat',
#   0,
#   0.0341,
#   95.884,
#   0.47],
#  15983: [0.971,
#   "['K.C.Dey']",
#   0.588,
#   0.265,
#   '4OYV3QInz4NwBD3msSwqTm',
#   0.287,
#   -14.384,
#   'O Dike Nimai Chale',
#   0,
#   0.115,
#   72.342,
#   0.603],
#  33000: [0.903,
#   "['n/a', 'Nitsch, Johanens', 'In Motion']",
#   0.349,
#   0.41600000000000004,
#   '4PABQMdRoYEerJW1rmjTZn',
#   0.17800000000000002,
#   -9.379,
#   'Last day in summer',
#   0,
#   0.0352,
#   78.115,
#   0.138],
#  4950: [0.956,
#   "['Carmen Miranda']",
#   0.5589999999999999,
#   0.184,
#   '79JzM5x7kn3IphV661FcJm',
#   0.301,
#   -13.186,
#   'Pelo Amor Daquela Ingrata',
#   0,
#   0.0431,
#   107.694,
#   0.66],
#  27663: [0.992,
#   "['Stratos Pagioumtzis', 'Stellakis Perpiniadis']",
#   0.46,
#   0.295,
#   '2FXw3Ds97sDj4poFjPo2b2',
#   0.153,
#   -16.985,
#   'H fisarmonika',
#   0,
#   0.0446,
#   162.24200000000005,
#   0.364],
#  21393: [0.7859999999999999,
#   "['N. Vlădoianu', 'N. Constantinescu', 'Ion Vasilescu', 'Mia Braia', 'Petre Alexandru']",
#   0.537,
#   0.264,
#   '6IR4plkU48lAtbSKeNF94u',
#   0.113,
#   -15.368,
#   'La fereastra unde doarme o pisică',
#   0,
#   0.0487,
#   60.15600000000001,
#   0.7390000000000001],
#  24816: [0.8190000000000001,
#   "['Richard Wagner', 'Karl Böhm', 'Arno Schellenberg', 'Eugen Füchs', 'Hanns Lange', 'Hans Hermann Nissen', 'Helene Jung', 'Hermann Greiner', 'Klaus Hermanns', 'Ludwig Eybisch', 'Margarete Teschemacher', 'Martin Kremer', 'Robert Büssel', 'Rudolf Dittrich', 'Rudolf Schmalnauer', 'Serge Smirnoff', 'Sven Nilsson', 'Torsten Ralf', 'Staatskapelle Dresden']",
#   0.261,
#   0.34299999999999997,
#   '2YDo913Hx5YHsB3nJp0PbA',
#   0.109,
#   -12.526,
#   'Wagner: Die Meistersinger von Nürnberg, WWV 96, Act 3: "Verachtet mir die Meister nicht" (Sachs, All)',
#   0,
#   0.0293,
#   99.361,
#   0.5760000000000001],
#  33243: [0.946,
#   "['Πέτρος Κυριακός']",
#   0.736,
#   0.0667,
#   '3nlCqSAB6wVVNRWW4UhOqM',
#   0.136,
#   -11.31,
#   'Ο Μπεκροκανάτας του Κυριακού',
#   0,
#   0.349,
#   84.24700000000001,
#   0.387],
#  4879: [0.825,
#   "['Carl Verheyen']",
#   0.336,
#   0.358,
#   '4DbSC9d7QISeBFkvKFspp2',
#   0.0971,
#   -10.612,
#   'Dixie Walk',
#   2,
#   0.036000000000000004,
#   84.92200000000003,
#   0.29],
#  21512: [0.987,
#   "['Nandalal Puri']",
#   0.46399999999999997,
#   0.14800000000000002,
#   '57rfqRYpKi8AoVixLBsOG3',
#   0.0981,
#   -16.274,
#   'Gabir Rate Jagi Khungi Tomare',
#   0,
#   0.0406,
#   70.495,
#   0.324],
#  4922: [0.996,
#   "['Carlota Jaramillo']",
#   0.535,
#   0.21600000000000005,
#   '4F9LO00F4BrguaYB8yKW43',
#   0.151,
#   -15.069,
#   'Espinas',
#   3,
#   0.0807,
#   96.56299999999999,
#   0.595],
#  8632: [0.922,
#   "['Elyane Célis']",
#   0.426,
#   0.223,
#   '59PnS1LZdaq9nd2I7SjZNy',
#   0.259,
#   -15.16,
#   'Piroulirouli',
#   0,
#   0.0485,
#   121.28399999999999,
#   0.353],
#  30015: [0.511,
#   "['Theodor Berger', 'Karl Böhm', 'Staatskapelle Dresden']",
#   0.402,
#   0.44,
#   '5AkWbIxJiOL0oAZ54lHKCk',
#   0.5379999999999999,
#   -12.312999999999999,
#   'Berger: Rondino giocoso, Op. 4',
#   0,
#   0.0357,
#   115.98299999999999,
#   0.657],
#  32101: [0.975,
#   "['Wolfgang Amadeus Mozart', 'Karl Böhm', 'Staatskapelle Dresden']",
#   0.34,
#   0.157,
#   '4NmG4f7s2HOCAeIgdMvoXT',
#   0.331,
#   -17.465,
#   'Mozart: Horn Concerto No. 3 in E-Flat Major, K. 447: I. Allegro',
#   0,
#   0.0426,
#   129.21,
#   0.23199999999999998],
#  17411: [0.846,
#   "['Lead Belly']",
#   0.6409999999999999,
#   0.273,
#   '1eRVoTxsnsWiiJMsDlI6HY',
#   0.20800000000000002,
#   -12.92,
#   'Ha, Ha This A Way',
#   0,
#   0.0863,
#   102.23200000000001,
#   0.9],
#  25964: [0.985,
#   "['Samuel Barber', 'Leontyne Price']",
#   0.45399999999999996,
#   0.308,
#   '4OXwLmIZE4CNUH6MzhtfvI',
#   0.696,
#   -15.946,
#   'Hermit Songs, Op. 29: The Praises of God',
#   0,
#   0.124,
#   118.166,
#   0.428],
#  19738: [0.988,
#   "['Marianne Oswald']",
#   0.626,
#   0.052000000000000005,
#   '5EnN9J6MwBszuNOWMiBRgS',
#   0.107,
#   -19.774,
#   'Jeu De Massacre',
#   0,
#   0.087,
#   85.68299999999998,
#   0.354],
#  19673: [0.8959999999999999,
#   "['Margarita Cueto', 'Juan Arvizu']",
#   0.38,
#   0.428,
#   '4PQluuW1ep3r3t3Wrh13tZ',
#   0.2,
#   -11.262,
#   'Bajo el Palma',
#   0,
#   0.0412,
#   83.25399999999998,
#   0.742],
#  18818: [0.8029999999999999,
#   "['Ludwig van Beethoven', 'New York Philharmonic', 'Arturo Toscanini']",
#   0.35200000000000004,
#   0.426,
#   '2GCbnMiw0WcdlUwxmEqXEy',
#   0.213,
#   -9.719,
#   'Symphony No. 7 in A Major, Op. 92: IV. Allegro con brio',
#   0,
#   0.0373,
#   74.441,
#   0.555],
#  18820: [0.6970000000000001,
#   "['Ludwig van Beethoven', 'New York Philharmonic', 'Leonard Bernstein']",
#   0.386,
#   0.32899999999999996,
#   '3pMefyvJYJ1YXOSqlfumHn',
#   0.12,
#   -16.602,
#   'Symphony No. 8 in F Major, Op. 93: IV. Allegro vivace',
#   0,
#   0.0425,
#   134.363,
#   0.265],
#  18733: [0.9470000000000001,
#   "['Ludwig van Beethoven', 'Columbia Symphony Orchestra', 'Bruno Walter']",
#   0.20800000000000002,
#   0.0703,
#   '3FaJiBx3X50WfGImhsxutK',
#   0.0771,
#   -20.34,
#   'Symphony No. 1 in C Major, Op. 21: II. Andante cantabile con moto',
#   0,
#   0.039,
#   88.48200000000001,
#   0.0615],
#  18867: [0.98,
#   "['Ludwig van Beethoven', 'Wiener Philharmoniker', 'Herbert von Karajan']",
#   0.184,
#   0.0838,
#   '3Tb4LcPNkfDAjKZahiPEf8',
#   0.0931,
#   -16.573,
#   'Symphony No. 5 in C Minor, Op. 67: II. Andante con moto',
#   0,
#   0.0403,
#   143.681,
#   0.0509],
#  18734: [0.9179999999999999,
#   "['Ludwig van Beethoven', 'Concertgebouworkest', 'Erich Kleiber']",
#   0.168,
#   0.136,
#   '3Z3egFjxQzXJy3APaDRtcO',
#   0.191,
#   -15.448,
#   'Symphony No. 6 in F Major, Op. 68 "Pastoral": V. Hirtengesang - Frohe und dankbare Gefühle nach dem Sturm (Allegretto)',
#   0,
#   0.0357,
#   94.195,
#   0.107],
#  18823: [0.977,
#   "['Ludwig van Beethoven', 'Orchestre De La Société Des Concerts Du Conservatoire', 'Carl Schuricht']",
#   0.209,
#   0.133,
#   '6Z5lc5Oh20uAXbMWv1gVHI',
#   0.127,
#   -15.993,
#   'Symphony No. 4 in B-Flat Major, Op. 60: II. Adagio',
#   0,
#   0.0378,
#   68.465,
#   0.0712],
#  14139: [0.992,
#   "['Jeanette Mcdonald', 'Allan Jones']",
#   0.28800000000000003,
#   0.363,
#   '4XdccXdbwuRNwULdZfDIVn',
#   0.223,
#   -11.148,
#   'Tosca',
#   0,
#   0.0376,
#   67.846,
#   0.24100000000000002],
#  18735: [0.958,
#   "['Ludwig van Beethoven', 'Concertgebouworkest', 'Josef Krips']",
#   0.298,
#   0.131,
#   '66MeNd20vTzSaEs2FGIujV',
#   0.12,
#   -13.947000000000001,
#   'Symphony No. 4 in B-Flat Major, Op. 60: III. Allegro vivace',
#   0,
#   0.0424,
#   148.113,
#   0.218],
#  18861: [0.9640000000000001,
#   "['Ludwig van Beethoven', 'Tilla Briem', 'Elisabeth Höngen', 'Peter Anders', 'Rudolf Watzke', 'Choeur Bruno Kittel', 'Berliner Philharmoniker', 'Wilhelm Furtwängler']",
#   0.163,
#   0.366,
#   '3CKzfjY5MsZ1DDoTnakIJo',
#   0.11800000000000001,
#   -13.786,
#   'Symphony No. 9 in D Minor, Op. 125 "Ode to Joy": IV. Presto - Allegro assai - Allegro assai vivace - Andante maestoso - Adagio ma non troppo, ma divoto',
#   0,
#   0.0477,
#   74.807,
#   0.102],
#  18835: [0.973,
#   "['Ludwig van Beethoven', 'Philharmonia Orchestra', 'Herbert von Karajan']",
#   0.204,
#   0.17,
#   '2INv6nhoYCzAH7S10WOy0q',
#   0.10300000000000001,
#   -20.733,
#   'Symphony No. 3 in E-Flat Major, Op. 55 "Eroica": III. Scherzo (Allegro vivace)',
#   0,
#   0.055,
#   89.84899999999998,
#   0.251],
#  18731: [0.873,
#   "['Ludwig van Beethoven', 'Chicago Symphony Orchestra', 'Fritz Reiner']",
#   0.307,
#   0.145,
#   '3r0cS0KGdZAJ38vgZNm0xf',
#   0.122,
#   -16.589000000000002,
#   'Symphony No. 7 in A Major, Op. 92: I. Poco sostenuto - Vivace',
#   0,
#   0.0433,
#   100.584,
#   0.111],
#  18743: [0.976,
#   "['Ludwig van Beethoven', 'Elisabeth Schwarzkopf', 'Elisabeth Höngen', 'Hans Hopf', 'Otto Edelmann', 'Bayreuth Festival Orchestra', 'Wilhelm Furtwängler']",
#   0.17,
#   0.302,
#   '2wXaoUk1Ve0emOT1ywMZHH',
#   0.5479999999999999,
#   -14.206,
#   'Symphony No. 9 in D Minor, Op. 125 "Ode to Joy": IV. Presto - Allegro assai - Allegro assai vivace - Andante maestoso - Adagio ma non troppo, ma divoto',
#   0,
#   0.0466,
#   77.318,
#   0.0786],
#  18816: [0.9590000000000001,
#   "['Ludwig van Beethoven', 'NBC Symphony Orchestra', 'Arturo Toscanini']",
#   0.254,
#   0.0456,
#   '2tseBPkigHt6ThJx2NbW8c',
#   0.26899999999999996,
#   -21.776999999999997,
#   'Symphony No. 2 in D Major, Op. 36: II. Larghetto',
#   0,
#   0.0312,
#   84.285,
#   0.11900000000000001],
#  14137: [0.992,
#   "['Jeanette MacDonald', 'Nelson Eddy']",
#   0.256,
#   0.39799999999999996,
#   '1VDvTA4PTzPosSoF2reh7r',
#   0.488,
#   -9.363999999999999,
#   'Indian Love Call (Version)',
#   0,
#   0.0594,
#   62.695,
#   0.19899999999999998],
#  18736: [0.9229999999999999,
#   "['Ludwig van Beethoven', 'Concertgebouworkest', 'Willem Mengelberg']",
#   0.29600000000000004,
#   0.11,
#   '3q6pkvKnvgJKwjI4EqyDDf',
#   0.10400000000000001,
#   -18.464000000000002,
#   'Symphony No. 6 in F Major, Op. 68 "Pastoral": V. Hirtengesang - Frohe und dankbare Gefühle nach dem Sturm (Allegretto)',
#   0,
#   0.0362,
#   110.889,
#   0.27699999999999997],
#  21716: [0.9940000000000001,
#   "['Nelson Eddy']",
#   0.42,
#   0.5579999999999999,
#   '3OaOruQzHWE5qAq8OwwI1c',
#   0.18899999999999997,
#   -9.861,
#   'Rose Marie',
#   0,
#   0.16899999999999998,
#   98.959,
#   0.268],
#  14138: [0.992,
#   "['Jeanette MacDonald']",
#   0.217,
#   0.35,
#   '6RCbTtaOhlFlBubpNtkyqK',
#   0.237,
#   -10.092,
#   'Indian Love Call',
#   0,
#   0.0429,
#   90.883,
#   0.23399999999999999],
#  18803: [0.727,
#   "['Ludwig van Beethoven', 'London Symphony Orchestra', 'Felix Weingartner']",
#   0.325,
#   0.17300000000000001,
#   '2lJWi0Sh2Cka2t1MHCwQO6',
#   0.264,
#   -17.97,
#   'Symphony No. 2 in D Major, Op. 36: IV. Allegro molto',
#   0,
#   0.0372,
#   142.75,
#   0.376],
#  14140: [0.993,
#   "['Jeanette Mcdonald']",
#   0.555,
#   0.524,
#   '6Bm4OT48ZPmyGTMieJIJ6q',
#   0.557,
#   -9.133,
#   'Pardon Me, Madame',
#   0,
#   0.11900000000000001,
#   79.207,
#   0.537],
#  25072: [0.9740000000000001,
#   "['Robe', 'Chorus']",
#   0.368,
#   0.882,
#   '6RrQcjCdW8gaMst4H1VTfg',
#   0.244,
#   -8.177999999999999,
#   'Totem Tom-Tom',
#   0,
#   0.0745,
#   127.93299999999999,
#   0.254],
#  18843: [0.7809999999999999,
#   "['Ludwig van Beethoven', 'Royal Philharmonic Orchestra', 'Hermann Scherchen']",
#   0.28600000000000003,
#   0.22899999999999998,
#   '1ykJqxWsYGtJoQMQsN7KQ0',
#   0.133,
#   -14.585,
#   'Symphony No. 8 in F Major, Op. 93: I. Allegro vivace e con brio',
#   0,
#   0.0373,
#   177.74099999999999,
#   0.318],
#  18844: [0.888,
#   "['Ludwig van Beethoven', 'Royal Philharmonic Orchestra', 'René Leibowitz']",
#   0.23399999999999999,
#   0.307,
#   '3jyDAD13ORdrItXffJ8nQr',
#   0.0994,
#   -16.893,
#   'Symphony No. 5 in C Minor, Op. 67: IV. Allegro',
#   0,
#   0.033,
#   90.329,
#   0.364],
#  18880: [0.977,
#   "['Ludwig van Beethoven', 'Wilma Lipp', 'Marga Höffgen', 'Murray Dickie', 'Gottlob Frick', 'Chorale Elisabeth Brasseur', 'Orchestre De La Société Des Concerts Du Conservatoire', 'Carl Schuricht']",
#   0.10300000000000001,
#   0.0643,
#   '2IlyhOq7oBmkeCSG9XusKQ',
#   0.107,
#   -24.898000000000003,
#   'Symphony No. 9 in D Minor, Op. 125 "Ode to Joy": III. Adagio molto e cantabile - Andante moderato',
#   0,
#   0.0373,
#   90.139,
#   0.0521],
#  14136: [0.9940000000000001,
#   "['Jeanette MacDonald', 'Gilda Gray']",
#   0.40700000000000003,
#   0.789,
#   '7vrkLLH4fFGN1rdKkAD1I0',
#   0.917,
#   -8.844,
#   'Dinah, Some of These Days',
#   0,
#   0.498,
#   113.977,
#   0.774],
#  1391: [0.9890000000000001,
#   "['Allan Jones', 'Jeanette Mcdonald']",
#   0.35200000000000004,
#   0.465,
#   '7wiUKiHMiiq8ewBOi0T0Gr',
#   0.825,
#   -9.459,
#   "Capulet's Ball",
#   0,
#   0.0597,
#   118.94,
#   0.33899999999999997],
#  25499: [0.9470000000000001,
#   "['Roza Eskenazi', 'Nikos Karakostas']",
#   0.59,
#   0.441,
#   '2KRTqKtjAetLgzZi4YJWfo',
#   0.214,
#   -8.765,
#   'Stazoun ta keramidia sou',
#   0,
#   0.0445,
#   77.988,
#   0.41100000000000003],
#  16065: [0.965,
#   "['Kalanidhi Rathin Ghosh']",
#   0.295,
#   0.34600000000000003,
#   '2L2W1PS5nc3fftA4UCyTev',
#   0.141,
#   -12.177,
#   'Radhar Ki Holo Antare Byatha',
#   0,
#   0.0585,
#   82.39200000000002,
#   0.47600000000000003],
#  19753: [0.893,
#   "['Marika Kanaropoulou']",
#   0.639,
#   0.316,
#   '3vlEyBi2MtpxAF3s24SXc8',
#   0.11,
#   -8.588,
#   'Vele me stin agkalia sou',
#   0,
#   0.0677,
#   122.13,
#   0.693],
#  11410: [0.9940000000000001,
#   "['Giorgos Papasideris', 'Vaios', 'Malliaras', 'Klarino']",
#   0.48,
#   0.325,
#   '2H7UPjnoWerhUfaA61I0Gm',
#   0.19699999999999998,
#   -14.448,
#   'Rina Katerina moy',
#   0,
#   0.0757,
#   111.94200000000001,
#   0.799],
#  16833: [0.995,
#   "['Kostas Roukounas', 'I. Ogdontakis', 'Violi']",
#   0.5579999999999999,
#   0.273,
#   '3VMjbMy6gPG9DWgmPjKsCG',
#   0.306,
#   -16.84,
#   'O geros',
#   0,
#   0.0821,
#   125.546,
#   0.7090000000000001],
#  25883: [0.9359999999999999,
#   "['Saltoy Maria']",
#   0.47200000000000003,
#   0.368,
#   '28a0fySbgc4vuci0hyuM7G',
#   0.154,
#   -12.511,
#   'Filoi kalosorisate',
#   0,
#   0.0402,
#   82.535,
#   0.841],
#  20925: [0.9940000000000001,
#   "['Mixalis Xatzis']",
#   0.47600000000000003,
#   0.204,
#   '00Xa5ouRfqsApqBlq9eLYr',
#   0.177,
#   -18.733,
#   'Panagioula',
#   0,
#   0.076,
#   70.673,
#   0.805],
#  7431: [0.996,
#   "['Dimitris Mpenetos']",
#   0.48100000000000004,
#   0.419,
#   '1nIHdRI4NzsM9am2nnSd7k',
#   0.342,
#   -10.022,
#   'As Pan Na Doun Ta Matia Mou',
#   0,
#   0.0503,
#   125.581,
#   0.846],
#  28781: [0.0309,
#   "['The Cotton Candy Blues Band']",
#   0.593,
#   0.45,
#   '1mTxphc9naXMLE9qfMkEVh',
#   0.33399999999999996,
#   -10.679,
#   'Early in the morning',
#   0,
#   0.0307,
#   112.054,
#   0.45399999999999996],
#  1921: [0.991,
#   "['Anonymous', 'Thomanerchor Leipzig', 'Günther Ramin']",
#   0.43,
#   0.12300000000000001,
#   '0qOevIWRr8i2PM9eLfv3xQ',
#   0.312,
#   -15.055,
#   'Freu dich, Erd und Sternenzelt',
#   0,
#   0.0551,
#   72.98899999999998,
#   0.355],
#  33311: [0.993,
#   "['周璇']",
#   0.301,
#   0.158,
#   '2HCs8VTLo6Vkzu06gVt1C1',
#   0.131,
#   -17.066,
#   '瘋狂世界',
#   4,
#   0.037000000000000005,
#   179.136,
#   0.7759999999999999],
#  10939: [0.992,
#   "['Georgia Mitaki', 'Giorgos Anestopoulos']",
#   0.569,
#   0.602,
#   '1sAJJWwzCAWUSqzOnr2SiU',
#   0.184,
#   -8.27,
#   'To giasemi',
#   0,
#   0.131,
#   77.862,
#   0.778],
#  10946: [0.987,
#   "['Georgia Mitaki']",
#   0.512,
#   0.58,
#   '2H2SgB7VdW8XfV5ZozmvhP',
#   0.24600000000000002,
#   -7.5779999999999985,
#   "Edo sta ksena pou'rtha",
#   0,
#   0.0351,
#   110.40299999999999,
#   0.9640000000000001],
#  18646: [0.981,
#   "['Luciano Tajoli']",
#   0.426,
#   0.145,
#   '4WONv0mae8AqJ2gboQBtlp',
#   0.2,
#   -17.427,
#   'Luna rossa',
#   0,
#   0.0403,
#   119.87100000000001,
#   0.484],
#  25003: [0.9590000000000001,
#   "['Rita Ampatzi', 'Kostas', 'Giaoyzos', 'Klarino']",
#   0.629,
#   0.45399999999999996,
#   '09aNbU79EaZNRX8xqC7hBa',
#   0.134,
#   -7.08,
#   'Stiliani',
#   0,
#   0.0573,
#   121.03299999999999,
#   0.665],
#  2106: [0.9590000000000001,
#   "['Anuradha Paudwal']",
#   0.568,
#   0.146,
#   '1sUlLSIhe1VmEGKPsiiA68',
#   0.618,
#   -11.328,
#   'Ana Ana Khel Khilone',
#   0,
#   0.0892,
#   93.044,
#   0.8190000000000001],
#  21950: [0.993,
#   "['Nilla Pizzi', 'Duo Fasano']",
#   0.8220000000000001,
#   0.16,
#   '0otiBQ1at6TCG4VeomJmA3',
#   0.425,
#   -19.337,
#   'Manana por la manana',
#   0,
#   0.12300000000000001,
#   116.184,
#   0.917],
#  21949: [0.995,
#   "['Nilla Pizzi', 'Achille Togliani']",
#   0.37,
#   0.0376,
#   '29r1taSfLJn01OUfE30PNe',
#   0.273,
#   -22.545,
#   'Nel regno dei sogni',
#   0,
#   0.0641,
#   90.38,
#   0.27899999999999997],
#  13726: [0.9940000000000001,
#   "['Jaganmoy Mitra']",
#   0.444,
#   0.10800000000000001,
#   '4Qv5gAgLXmsvuqH9YhPxhA',
#   0.182,
#   -23.294,
#   'Keno Ager Mato',
#   0,
#   0.0334,
#   91.135,
#   0.565],
#  21952: [0.992,
#   "['Nilla Pizzi', 'Gino Latilla']",
#   0.32799999999999996,
#   0.0489,
#   '0pRao8SaZ7sPJkcoloWxeb',
#   0.21100000000000002,
#   -26.195999999999998,
#   'Buonanotte Irene',
#   0,
#   0.0496,
#   62.361000000000004,
#   0.27899999999999997],
#  16084: [0.988,
#   "['Kalyani']",
#   0.486,
#   0.0906,
#   '46mOqgADSkWC93GVODFJWd',
#   0.54,
#   -15.523,
#   'Aise Bedard Ho Tum',
#   0,
#   0.094,
#   119.86,
#   0.41200000000000003],
#  11408: [0.966,
#   "['Giorgos Papasideris', 'Tasos Xalkias-Klarino']",
#   0.414,
#   0.40700000000000003,
#   '0XtcjTZW9y2NBJiQYUAeMw',
#   0.102,
#   -6.705,
#   'To feggari kanei kyklo',
#   0,
#   0.0358,
#   140.582,
#   0.285],
#  25001: [0.94,
#   "['Rita Ampatzi', 'Giorgos Anestopoulos']",
#   0.555,
#   0.555,
#   '2RUC3GcehdiEUuj7UmQ8JP',
#   0.177,
#   -6.4460000000000015,
#   'Xoriatopoula',
#   0,
#   0.0482,
#   115.49799999999999,
#   0.905],
#  18925: [0.721,
#   "['Luis Rovira y su Orquesta']",
#   0.462,
#   0.772,
#   '30C7J7pi51niDzFGiuMPvE',
#   0.857,
#   -7.63,
#   'Adiós al Boggie',
#   0,
#   0.0668,
#   92.986,
#   0.579],
#  13936: [0.991,
#   "['Jararaca E Ratinho']",
#   0.624,
#   0.349,
#   '2BhHwwSPjoj9ib5lPBGJqJ',
#   0.175,
#   -10.049,
#   'A Lalá Tá Cá',
#   0,
#   0.474,
#   90.39200000000001,
#   0.917],
#  25500: [0.987,
#   "['Roza Eskenazi', 'Nikos Rellias', 'Klarino']",
#   0.504,
#   0.46299999999999997,
#   '1uCgB9SCxrSEZ24DUfyh19',
#   0.0974,
#   -8.586,
#   'Zevgolatiotissa',
#   0,
#   0.0303,
#   97.729,
#   0.79],
#  3071: [0.953,
#   "['Bedřich Smetana', 'Marie Podvalová', 'Stanislav Muž', 'Vilém Zítek', 'Josef Vojta', 'Ota Horáková', 'Marta Krásová', 'Jaroslav Veverka', 'Prague National Theatre Chorus', 'Prague National Theatre Orchestra', 'Jan Maria Ouředník', 'Václav Talich', 'Josef Křikava']",
#   0.341,
#   0.327,
#   '0yvAexKigIDisv6XLblKQu',
#   0.664,
#   -16.592,
#   'Libuše, Act II, Scene 2: "On jde!" (Libuše, Přemysl ze Stadic, Chrudoš od Otavy, Šťáhlav na Radbuze, Krasava, Radmila, Lutobor, Radovan) - Live',
#   0,
#   0.25,
#   135.632,
#   0.293],
#  24599: [0.165,
#   "['Richard Levitt', 'Charles Byrd', 'Carl Tucker']",
#   0.513,
#   0.9059999999999999,
#   '1MBhdHBtzL1pax4aNFBNnK',
#   0.664,
#   -7.2079999999999975,
#   'Get out of My Life',
#   0,
#   0.0932,
#   116.193,
#   0.6659999999999999],
#  31819: [0.679,
#   "['Wilmoth Houdini']",
#   0.605,
#   0.4370000000000001,
#   '2HXaYdEm3jpKc5OZQQw8G0',
#   0.17300000000000001,
#   -9.642999999999999,
#   'Gravel Gertie',
#   0,
#   0.13,
#   167.565,
#   0.9620000000000001],
#  32469: [0.9109999999999999,
#   "['Ying Yin Wu']",
#   0.4,
#   0.289,
#   '2CAjwUrascHi89CTTv3Cf7',
#   0.259,
#   -6.728,
#   '當初見到你',
#   1,
#   0.0345,
#   117.469,
#   0.43],
#  19755: [0.97,
#   "['Marika Ninou']",
#   0.297,
#   0.292,
#   '2Guu3V5IGI1g3x6XJTSLxf',
#   0.28800000000000003,
#   -12.985,
#   'Agapi pou egines dikopo maxairi',
#   3,
#   0.0366,
#   124.821,
#   0.552],
#  20922: [0.9740000000000001,
#   "['Mixalis Kalergis']",
#   0.5589999999999999,
#   0.713,
#   '2G4ctgDEVmVAfM2AxPHMvr',
#   0.0932,
#   -8.685,
#   'Poios eide prasino dendri',
#   0,
#   0.0605,
#   115.146,
#   0.536],
#  9010: [0.996,
#   "['Euaggelos Sofroniou']",
#   0.311,
#   0.2,
#   '2UrKxrgUa35APXtIdHMXiv',
#   0.11199999999999999,
#   -14.072000000000001,
#   'Mikropantremeni',
#   0,
#   0.0543,
#   82.805,
#   0.5479999999999999],
#  1878: [0.995,
#   "['Anna Likiardopoulou']",
#   0.36,
#   0.262,
#   '2X1xOy1oHFnO7d5FKtNc2x',
#   0.111,
#   -15.812000000000001,
#   'Kapote klapsame kai oi dio',
#   0,
#   0.0459,
#   114.73200000000001,
#   0.635],
#  1932: [0.613,
#   "['Ansambl Biljana']",
#   0.115,
#   0.39799999999999996,
#   '2Jpl9jjMRgdL8rboM1o6rA',
#   0.11599999999999999,
#   -8.939,
#   'Bolen Mi Leži Mile Pop Ordanov',
#   0,
#   0.0393,
#   78.015,
#   0.159],
#  29064: [0.637,
#   "['The Gns Band']",
#   0.46799999999999997,
#   0.544,
#   '1ddrtXrepsvPENfuu37Zmt',
#   0.495,
#   -9.939,
#   'Into the Night',
#   0,
#   0.0432,
#   116.137,
#   0.727],
#  25498: [0.976,
#   "['Roza Eskenazi', 'Nikos Karakostas', 'Klarino']",
#   0.38299999999999995,
#   0.37799999999999995,
#   '0cWFfrWGftqt1tkNy9eqhI',
#   0.185,
#   -10.474,
#   'Trigona',
#   0,
#   0.0509,
#   101.104,
#   0.514],
#  16100: [0.995,
#   "['Kanak Das Biswas']",
#   0.483,
#   0.0994,
#   '20kcZfb9UeRraiEuCWGS0m',
#   0.109,
#   -16.430999999999994,
#   'Aasa Jaoyar Pather Dhare',
#   0,
#   0.0329,
#   80.874,
#   0.303],
#  27658: [0.988,
#   "['Stratos Pagioumtzis', 'Ioanna Georgokopoulou']",
#   0.6890000000000001,
#   0.377,
#   '2ZGCMzTDtatCkqskpSfEWx',
#   0.13699999999999998,
#   -13.936,
#   'Se ksana eida pali',
#   0,
#   0.0392,
#   129.22899999999998,
#   0.905],
#  11366: [0.991,
#   "['Giorgos Panagiotopoylos-Koyros)']",
#   0.20600000000000002,
#   0.434,
#   '2ZQo4qi5RdvUxMVQlun2op',
#   0.777,
#   -11.405999999999999,
#   'Striftopoylos',
#   0,
#   0.0528,
#   72.74,
#   0.297],
#  21225: [0.976,
#   "['Mr. Padgaonkar']",
#   0.532,
#   0.163,
#   '3bzsbC6HwBNn7mTlqPJZ9p',
#   0.39299999999999996,
#   -11.578,
#   'Kya Pachtata Murakh Man',
#   0,
#   0.0606,
#   130.563,
#   0.5760000000000001],
#  27435: [0.987,
#   "['Stellakis Perpiniadis', 'Manolis Xiotis']",
#   0.446,
#   0.467,
#   '0IVeNdTMenQLn4aRsJtGlc',
#   0.29100000000000004,
#   -12.642999999999999,
#   'Gia koita mia ginaika',
#   0,
#   0.0405,
#   91.72200000000001,
#   0.757],
#  31234: [0.9940000000000001,
#   "['Victor Arden', 'Adam Caroll']",
#   0.713,
#   0.126,
#   '2aLLqFbnXWcAvYgadfrVqU',
#   0.0946,
#   -20.506,
#   'Wake up and Dream: What is this thing called love?',
#   0,
#   0.0538,
#   103.274,
#   0.6],
#  808: [0.96,
#   "['Abbasuddin Ahmed']",
#   0.596,
#   0.31,
#   '1XSQxlkn0uU4HJYhcwehvJ',
#   0.18899999999999997,
#   -11.790999999999999,
#   'Ore O Paraner Majhi',
#   0,
#   0.0422,
#   128.126,
#   0.503],
#  14029: [0.953,
#   "['Jay McShann & His Orchestra']",
#   0.42100000000000004,
#   0.669,
#   '23sZlNqAtJuJAXiBRvvHpA',
#   0.11900000000000001,
#   -6.526,
#   'Body and Soul',
#   0,
#   0.0503,
#   100.40299999999999,
#   0.629],
#  19835: [0.995,
#   "['Markos Vamvakaris']",
#   0.579,
#   0.27399999999999997,
#   '0ougCtBoDQv8z8g3MFOfRV',
#   0.34299999999999997,
#   -9.812000000000001,
#   'Koula Fragkosiriani',
#   0,
#   0.0432,
#   138.342,
#   0.643],
#  27870: [0.983,
#   "['Surendra', 'Jyoti']",
#   0.491,
#   0.316,
#   '0kefOCjNLTvc4QWWWPBbLv',
#   0.593,
#   -7.886,
#   'Pila De Pila De',
#   0,
#   0.19,
#   80.749,
#   0.7490000000000001],
#  5307: [0.978,
#   "['Charlie Chaplin']",
#   0.38799999999999996,
#   0.131,
#   '4al7lN71jOj80pWD5LFifR',
#   0.575,
#   -11.228,
#   'Thanksgiving Day / Impending Doom',
#   1,
#   0.0516,
#   90.916,
#   0.214],
#  7434: [0.9940000000000001,
#   "['Dimitris Perdikopoulos']",
#   0.312,
#   0.294,
#   '2Cxhu70uYGQpBJfBJzhZDw',
#   0.175,
#   -12.499,
#   'Mia kori Aleksandriani',
#   0,
#   0.0357,
#   81.868,
#   0.838],
#  22397: [0.7140000000000001,
#   "['Orchestra Studio 7']",
#   0.46,
#   0.597,
#   '4huyqlnpURLX49SJUxzv4R',
#   0.159,
#   -16.177,
#   "'A rossa - Musical base Version",
#   0,
#   0.0573,
#   155.52100000000004,
#   0.593],
#  4890: [0.985,
#   "['Carlo Buti']",
#   0.475,
#   0.293,
#   '4a3QRE4IIxMqQeB5o2meOb',
#   0.141,
#   -13.567,
#   'Ho sognato Firenze',
#   0,
#   0.0433,
#   119.277,
#   0.563],
#  18846: [0.981,
#   "['Ludwig van Beethoven', 'Rudolf Serkin', 'Bruno Walter']",
#   0.32,
#   0.0809,
#   '2f0F5lirp6VIdl2uPLYbR4',
#   0.0875,
#   -23.041,
#   'Concerto No. 5 in E-Flat Major for Piano and Orchestra, Op. 73 "Emperor": II. Adagio un poco moto',
#   7,
#   0.0377,
#   136.327,
#   0.0905],
#  15188: [0.992,
#   "['John Philip Sousa', 'Vladimir Horowitz']",
#   0.523,
#   0.2,
#   '4GVePC4pv2cyiATDT9iHZl',
#   0.23800000000000002,
#   -19.334,
#   'The Stars and Stripes Forever',
#   0,
#   0.0379,
#   110.25399999999999,
#   0.501],
#  5891: [0.951,
#   "['Claudio Villa']",
#   0.387,
#   0.28600000000000003,
#   '4hzQ9zTwFQq4uj5D5xVjZw',
#   0.36,
#   -12.17,
#   'Marechiaro',
#   0,
#   0.0378,
#   131.245,
#   0.429],
#  33358: [0.773,
#   "['葛蘭']",
#   0.884,
#   0.418,
#   '4fY6F81QOduK7yZVXjEWxf',
#   0.22899999999999998,
#   -9.478,
#   '打噴嚏',
#   2,
#   0.247,
#   128.315,
#   0.601],
#  17336: [0.99,
#   "['Lata Mangeshkar']",
#   0.326,
#   0.18600000000000005,
#   '2pznhPGNH7NRqMAXk5RZnM',
#   0.10300000000000001,
#   -13.071,
#   'Marna Teri Gali Mein',
#   4,
#   0.0335,
#   172.11,
#   0.3670000000000001],
#  28202: [0.995,
#   "['Tapi Dharma Rao']",
#   0.47700000000000004,
#   0.193,
#   '4qHfraZj0DRJukTpSGPc72',
#   0.19399999999999998,
#   -10.811,
#   'Karma Data Vasama (From "Patni")',
#   0,
#   0.127,
#   73.08800000000002,
#   0.696],
#  2395: [0.99,
#   "['Asha Bhosle', 'Mohammed Rafi']",
#   0.39399999999999996,
#   0.027999999999999997,
#   '0a6MqU965thvRSxVDO8JzO',
#   0.11199999999999999,
#   -25.046999999999997,
#   'Ae Saba Unse Kah Zara',
#   0,
#   0.0696,
#   71.098,
#   0.52],
#  32001: [0.99,
#   "['Wolfgang Amadeus Mozart', 'Ezio Pinza', 'Margit Bokor', 'Wiener Philharmoniker', 'Bruno Walter']",
#   0.38299999999999995,
#   0.132,
# ...
#   0.20800000000000002,
#   '274ERr7MTmAwkdWS4dBZ3Y',
#   0.374,
#   -19.736,
#   'The Alchemist',
#   5,
#   0.956,
#   92.448,
#   0.39],
#  18102: [0.35200000000000004,
#   "['Little Jimmy Scott']",
#   0.449,
#   0.4970000000000001,
#   '16KH4kriyc6SyePXS48xwe',
#   0.298,
#   -7.98,
#   'All Or Nothing At All',
#   7,
#   0.0418,
#   132.71,
#   0.488],
#  30399: [0.92,
#   "['Tony Fruscella']",
#   0.6659999999999999,
#   0.348,
#   '35vsbF3HChT1kUujhwShsJ',
#   0.081,
#   -10.243,
#   "Let's Play the Blues",
#   17,
#   0.05,
#   93.333,
#   0.5710000000000001],
#  11162: [0.991,
#   "['Giacomo Puccini', 'Maria Callas', 'Herbert von Karajan', 'Lucie Danieli', 'Orchestra Del Teatro Alla Scala, Milano']",
#   0.207,
#   0.062,
#   '0VvgLZAgONZT5eWGune9iZ',
#   0.11599999999999999,
#   -20.422,
#   'Puccini: Madama Butterfly, Act 2: "Or vienmi ad adornar" (Suzuki, Butterfly)',
#   12,
#   0.0472,
#   90.14399999999999,
#   0.0383],
#  4414: [0.955,
#   "['Bud Powell']",
#   0.552,
#   0.171,
#   '7pKWTcPfT9mg2iAhobFHpS',
#   0.122,
#   -13.66,
#   'Polka Dots And Moonbeams - Rudy Van Gelder/24 Bit Mastering/1998 Digital Remaster',
#   46,
#   0.0544,
#   102.40799999999999,
#   0.152],
#  30017: [0.662,
#   "['Theodore Bikel']",
#   0.638,
#   0.214,
#   '7i6C3oYDVUbNUdJf04a1Zd',
#   0.11599999999999999,
#   -14.548,
#   'Chupchik (Curly Forelock)',
#   8,
#   0.113,
#   114.676,
#   0.8190000000000001],
#  27342: [0.856,
#   "['Stan Getz']",
#   0.551,
#   0.44799999999999995,
#   '2ExI2HJwAPqXs2eWfHb1uX',
#   0.307,
#   -11.286,
#   'Falsa Baiana',
#   36,
#   0.0311,
#   87.165,
#   0.662],
#  12599: [0.9209999999999999,
#   "['Helen Merrill']",
#   0.392,
#   0.0306,
#   '3bwBtoqCAHKbGDEtNU98ne',
#   0.11800000000000001,
#   -26.384,
#   "Vous M'Eblouissez (You Go To My Head)",
#   12,
#   0.0386,
#   103.154,
#   0.13],
#  10853: [0.96,
#   "['George Shearing Quintet']",
#   0.546,
#   0.17600000000000002,
#   '0vtXD4PfsCvaEqpgqabRBs',
#   0.0792,
#   -16.730999999999998,
#   'Midnight In The Air',
#   10,
#   0.0462,
#   124.40799999999999,
#   0.266],
#  25090: [0.9640000000000001,
#   "['Robert Frost']",
#   0.748,
#   0.179,
#   '3xxd1UwCCUnxRHIgsFDxXe',
#   0.11599999999999999,
#   -15.485,
#   "An Old Man's Winter Night",
#   5,
#   0.6,
#   92.089,
#   0.4920000000000001],
#  19035: [0.96,
#   "['Léo Delibes', 'Maria Callas', 'Tullio Serafin', 'Philharmonia Orchestra']",
#   0.297,
#   0.0814,
#   '55gUuIn96J9SwYeVpRdp9F',
#   0.10800000000000001,
#   -18.054000000000002,
#   'Delibes: Lakmé, Act 2: "Où va la jeune indoue" (Lakmé)',
#   15,
#   0.0576,
#   172.952,
#   0.155],
#  2045: [0.973,
#   "['Antonín Dvořák', 'Fritz Reiner', 'Chicago Symphony Orchestra']",
#   0.297,
#   0.14,
#   '1XESIwVu8Ccbpj7oWbajQY',
#   0.0768,
#   -16.406,
#   'Symphony No. 9 in E Minor, Op. 95, B. 178 "From the New World": I. Adagio - Allegro molto',
#   5,
#   0.0363,
#   124.844,
#   0.11199999999999999],
#  20789: [0.777,
#   "['Milt Jackson']",
#   0.556,
#   0.335,
#   '6linBr32WmoP56Y2N26isX',
#   0.2,
#   -18.281,
#   'Plenty, Plenty Soul',
#   35,
#   0.0565,
#   115.92299999999999,
#   0.369],
#  21720: [0.9620000000000001,
#   "['Nelson Riddle']",
#   0.141,
#   0.166,
#   '6mXFM2sinE5jIyjMIymAbo',
#   0.11900000000000001,
#   -15.145,
#   'Love Theme from Lolita',
#   18,
#   0.0338,
#   97.164,
#   0.0385],
#  28954: [0.9470000000000001,
#   "['The Famous Davis Sisters']",
#   0.419,
#   0.255,
#   '5Jwz65pTx6TGngmWCEgr4C',
#   0.17300000000000001,
#   -12.48,
#   "Lord Don't Leave Me",
#   9,
#   0.0349,
#   98.084,
#   0.21],
#  17665: [0.648,
#   "['Les Paul']",
#   0.617,
#   0.632,
#   '3zc5n5NIehzubwOZqskGCj',
#   0.29,
#   -10.302999999999999,
#   'Nola',
#   6,
#   0.0508,
#   112.803,
#   0.938],
#  25943: [0.7140000000000001,
#   "['Sammy Davis Jr.']",
#   0.501,
#   0.5479999999999999,
#   '5bAQy2e2gMXnx21FbaQKqX',
#   0.322,
#   -9.086,
#   'Love Me Or Leave Me',
#   32,
#   0.0927,
#   147.562,
#   0.573],
#  27866: [0.981,
#   "['Suraiya', 'Talat Mahmood']",
#   0.502,
#   0.326,
#   '5PjLGKf6XCzArnYIJwG9i4',
#   0.302,
#   -11.479000000000001,
#   'Dil-E-Nadan Tujhe Hua Kya',
#   5,
#   0.0321,
#   105.399,
#   0.706],
#  4792: [0.26,
#   "['Cannonball Adderley']",
#   0.539,
#   0.601,
#   '3fRo5HGjCGa8vZN07ozJ2X',
#   0.0563,
#   -9.676,
#   'Fiddler On The Roof - Remastered',
#   21,
#   0.038,
#   67.881,
#   0.452],
#  9151: [0.99,
#   "['Fairuz']",
#   0.419,
#   0.129,
#   '2nov8Gl2kJAyaMSIORSs6S',
#   0.313,
#   -15.224,
#   'Abhathou an Aynain',
#   9,
#   0.043,
#   109.26799999999999,
#   0.52],
#  20769: [0.545,
#   "['Miles Davis']",
#   0.365,
#   0.231,
#   '7DpXEh9OAJ90AxIiBMr6Gt',
#   0.304,
#   -14.015,
#   'Feio',
#   31,
#   0.0375,
#   112.98299999999999,
#   0.0769],
#  11163: [0.9740000000000001,
#   "['Giacomo Puccini', 'Maria Callas', 'Herbert von Karajan', 'Mario Borriello', 'Mario Carlin', 'Orchestra Del Teatro Alla Scala, Milano', 'Renato Ercolani']",
#   0.255,
#   0.247,
#   '48WndKdt4VmcPx1jsVyCoB',
#   0.473,
#   -14.425999999999998,
#   'Puccini: Madama Butterfly, Act 2: "Non lo sapete insomma" (Butterfly, Sharpless, Goro, Yamadori)',
#   13,
#   0.0431,
#   88.51299999999998,
#   0.25],
#  29371: [0.62,
#   "['The Modern Jazz Quartet']",
#   0.5479999999999999,
#   0.152,
#   '1NFgTMJ6R0ucnwew3t2Aa9',
#   0.109,
#   -15.617,
#   'Pyramid',
#   21,
#   0.0428,
#   128.423,
#   0.191],
#  30211: [0.794,
#   "['Tito Puente & His Orchestra']",
#   0.413,
#   0.7559999999999999,
#   '3h8L0mIYdtllLW8wWd9Wsv',
#   0.0755,
#   -7.297999999999999,
#   'Bambaram Bam Bam',
#   6,
#   0.0644,
#   128.154,
#   0.623],
#  23089: [0.805,
#   "['Peggy Lee']",
#   0.7140000000000001,
#   0.483,
#   '4RFRVqXndX8PBCpPw4ETpi',
#   0.26,
#   -13.142999999999999,
#   'I Could Have Danced All Night - Remastered',
#   16,
#   0.10400000000000001,
#   146.515,
#   0.897],
#  23305: [0.9590000000000001,
#   "['Philippe Clay']",
#   0.6920000000000001,
#   0.196,
#   '0OKLgBecUL3YlMMIS3ukcf',
#   0.147,
#   -16.135,
#   'Ah !',
#   0,
#   0.34600000000000003,
#   110.09700000000001,
#   0.703],
#  30676: [0.884,
#   "['Trio Lissabet']",
#   0.507,
#   0.516,
#   '5tLl0gZ2G6tAImK2E3BROp',
#   0.121,
#   -18.977999999999998,
#   'Black Tears',
#   6,
#   0.0346,
#   95.485,
#   0.9670000000000001],
#  32320: [0.9109999999999999,
#   "['Xavier Cugat & His Orchestra']",
#   0.6459999999999999,
#   0.6709999999999999,
#   '1uddWLJ12TTyn137a4i2DI',
#   0.141,
#   -11.774000000000001,
#   'Yo Quiero un Mambo',
#   5,
#   0.0363,
#   87.728,
#   0.7759999999999999],
#  6846: [0.7340000000000001,
#   "['Dave Brubeck Trio', 'Gerry Mulligan']",
#   0.6,
#   0.429,
#   '63bFjNeaOxRuaMKD9eaHXd',
#   0.24600000000000002,
#   -12.013,
#   "Things Ain't What They Used To Be",
#   4,
#   0.0295,
#   131.547,
#   0.63],
#  4939: [0.894,
#   "['Carmen McRae']",
#   0.467,
#   0.35100000000000003,
#   '4OPMopeVYxV7kyCvFu2woR',
#   0.23800000000000002,
#   -10.704,
#   'Speak Low',
#   4,
#   0.0497,
#   124.391,
#   0.433],
#  5218: [0.381,
#   "['Charles Aznavour']",
#   0.149,
#   0.491,
#   '0UQOiRsZEJom6E35xajJzu',
#   0.0889,
#   -6.901,
#   "Mourir d'aimer",
#   48,
#   0.034,
#   77.171,
#   0.386],
#  6851: [0.8390000000000001,
#   "['Dave Brubeck']",
#   0.451,
#   0.365,
#   '62OASyCuBCdYAsviFcYz3W',
#   0.586,
#   -18.894000000000002,
#   "It's a Raggy Waltz - Live at Carnegie Hall",
#   17,
#   0.0521,
#   175.965,
#   0.732],
#  7717: [0.9940000000000001,
#   "['Don Shirley']",
#   0.337,
#   0.0609,
#   '3BvQ1HwOh97KbkhMtYZM0H',
#   0.0921,
#   -20.636999999999997,
#   'My Funny Valentine',
#   5,
#   0.0382,
#   68.15899999999999,
#   0.0869],
#  20174: [0.872,
#   "['Max Bruch', 'Jascha Heifetz', 'Sir Malcolm Sargent', 'The New Symphony Orchestra Of London']",
#   0.0853,
#   0.18,
#   '0oVkdN98E1m6frPKjMGGYS',
#   0.127,
#   -21.924,
#   'Violin Concerto No. 1 in G Minor, Op. 26: II. Adagio - Redbook Stereo',
#   8,
#   0.0505,
#   49.869,
#   0.0667],
#  9644: [0.963,
#   "['Frances Archer', 'Beverly Gile']",
#   0.799,
#   0.154,
#   '2id1gFfNJlOcBEdiRKmAfg',
#   0.0777,
#   -12.773,
#   'Frog Went A-Courtin',
#   3,
#   0.0655,
#   97.15299999999999,
#   0.642],
#  4434: [0.17,
#   '[\'Buddy Rich\', \'Harry "Sweets" Edison\']',
#   0.506,
#   0.8759999999999999,
#   '7wV5F8I7rXGFSVrIR5nQhp',
#   0.087,
#   -11.349,
#   "Barney's Bugle",
#   8,
#   0.0826,
#   118.431,
#   0.302],
#  26613: [0.867,
#   '[\'Shirl Conway\', "Original Broadway Cast \'Plain And Fancy\'"]',
#   0.529,
#   0.226,
#   '6oBGLSOCvxyMsb3KCGZDzQ',
#   0.32,
#   -12.832,
#   "It's A Helluva Way To Run A Love Affair",
#   5,
#   0.0733,
#   93.47200000000001,
#   0.5],
#  14819: [0.992,
#   "['Johann Sebastian Bach', 'Glenn Gould', 'Toronto Symphony Orchestra', 'Ernest Macmillan']",
#   0.3720000000000001,
#   0.22,
#   '4Hnx7xEKY4aLrCXcN9egq8',
#   0.105,
#   -16.528,
#   'Keyboard Concerto in D Minor, BWV 1052: I. Allegro',
#   9,
#   0.0306,
#   95.964,
#   0.39799999999999996],
#  24232: [0.787,
#   "['Ravi', 'Kalyanji Virji Shah', 'Lata Mangeshkar']",
#   0.498,
#   0.493,
#   '6umpwR6rQvkfIGlWFxzi3X',
#   0.376,
#   -13.645999999999999,
#   'Man Dole Mera Tan Dole',
#   8,
#   0.0298,
#   107.376,
#   0.695],
#  26063: [0.772,
#   "['Sarah Vaughan']",
#   0.713,
#   0.507,
#   '7DTQayqJ4Q19TcxpwmhQUd',
#   0.213,
#   -9.829,
#   'The Banana Boat Song',
#   17,
#   0.0353,
#   125.895,
#   0.8690000000000001],
#  23092: [0.978,
#   "['Peggy Seeger']",
#   0.584,
#   0.10099999999999999,
#   '0T7LT2ywyVZXvQmC5qLbVM',
#   0.109,
#   -21.682,
#   "The Old Maid's Song",
#   5,
#   0.0862,
#   74.601,
#   0.892],
#  30391: [0.907,
#   "['Tony Bennett']",
#   0.409,
#   0.435,
#   '4BH8EuPAxeFAh1rSWtnGdD',
#   0.0559,
#   -9.399,
#   'Rags to Riches - Remastered',
#   53,
#   0.0453,
#   78.13600000000002,
#   0.5670000000000001],
#  18547: [0.708,
#   "['Louis Armstrong', 'Sonny Burke & His Orchestra']",
#   0.429,
#   0.263,
#   '3StcXy0MMm3XNogT3HLcUT',
#   0.0648,
#   -11.065,
#   'Sincerely',
#   12,
#   0.0423,
#   73.223,
#   0.35600000000000004],
#  12320: [0.963,
#   "['Hampton Hawes Trio']",
#   0.545,
#   0.21,
#   '2MEbRBMLawSUVstTskWnzG',
#   0.11199999999999999,
#   -19.108,
#   'Blues The Most',
#   7,
#   0.0453,
#   144.178,
#   0.4970000000000001],
#  11167: [0.9840000000000001,
#   "['Giacomo Puccini', 'Maria Callas', 'Herbert von Karajan', 'Nicolai Gedda', 'Orchestra Del Teatro Alla Scala, Milano']",
#   0.157,
#   0.254,
#   '3fqKSWfuE4vNl1HoYb3t9e',
#   0.353,
#   -12.427999999999999,
#   'Puccini: Madama Butterfly, Act 1: "Vogliatemi bene, un bene piccolino" (Pinkerton, Butterfly)',
#   15,
#   0.0349,
#   89.426,
#   0.0582],
#  3571: [0.701,
#   '[\'Billy "The Kid" Emerson\']',
#   0.551,
#   0.731,
#   '1tLIzSDBkJqc2LsKui8jxy',
#   0.0951,
#   -5.612,
#   'Red Hot',
#   7,
#   0.147,
#   200.968,
#   0.92],
#  21576: [0.851,
#   "['Nat King Cole']",
#   0.55,
#   0.18100000000000002,
#   '2d5rklRuLWhBIcq2XpyyE7',
#   0.136,
#   -13.696,
#   "Walkin' My Baby Back Home - Remastered",
#   43,
#   0.0403,
#   110.035,
#   0.47100000000000003],
#  10662: [0.804,
#   '[\'Gene Krupa Big Band\', "Anita O\'Day", \'Roy Eldridge\']',
#   0.519,
#   0.345,
#   '7ykN6z8LAxWieSfiiXVrAK',
#   0.0739,
#   -9.508,
#   'Let Me Off Uptown',
#   14,
#   0.0386,
#   133.33100000000002,
#   0.535],
#  28758: [0.8140000000000001,
#   "['The Clovers']",
#   0.595,
#   0.24100000000000002,
#   '2S9avNgOA00cN7LsbLnhKq',
#   0.0959,
#   -15.97,
#   "Don't You Know I Love You",
#   13,
#   0.0381,
#   116.98299999999999,
#   0.7090000000000001],
#  20755: [0.615,
#   "['Miles Davis Sextet']",
#   0.46299999999999997,
#   0.601,
#   '1ywAsfpgyrq6iUYI3ApCMj',
#   0.325,
#   -11.302,
#   'Tempus Fugit - Alternate Take',
#   12,
#   0.0421,
#   133.153,
#   0.741],
#  29533: [0.851,
#   "['The Platters']",
#   0.652,
#   0.303,
#   '6Q2pkSKuM08SDOuAS5amQD',
#   0.324,
#   -8.573,
#   'The Great Pretender',
#   46,
#   0.0297,
#   114.665,
#   0.706],
#  8052: [0.109,
#   "['Duke Ellington']",
#   0.435,
#   0.157,
#   '6CY7GdDuAXXEIqNGzfQAt0',
#   0.092,
#   -17.651,
#   'Anatomy of a Murder - Stereo Single Version',
#   17,
#   0.0475,
#   202.513,
#   0.647],
#  15799: [0.715,
#   "['Julie London']",
#   0.324,
#   0.21100000000000002,
#   '0VYFn9RQ93CeH3g4FBSbwe',
#   0.0918,
#   -16.177,
#   'Love Letters - Remastered',
#   20,
#   0.033,
#   119.186,
#   0.35100000000000003],
#  32836: [0.9840000000000001,
#   "['Zoot Sims']",
#   0.564,
#   0.162,
#   '36NzG0ptwi4k798mpIS3Oz',
#   0.125,
#   -12.06,
#   'Evening In Paris',
#   40,
#   0.0331,
#   62.56,
#   0.57],
#  7733: [0.0888,
#   "['Donald Byrd']",
#   0.727,
#   0.7240000000000001,
#   '1iPbcdvxT4WVG0Irt98uL3',
#   0.292,
#   -8.982000000000003,
#   'Love Has Come Around',
#   36,
#   0.0398,
#   111.741,
#   0.519],
#  2294: [0.778,
#   "['Art Pepper']",
#   0.568,
#   0.39,
#   '3wqWq1ZOBIO0NQo98kmIFC',
#   0.0764,
#   -9.78,
#   "Walkin' Shoes",
#   18,
#   0.0823,
#   162.548,
#   0.5760000000000001],
#  26949: [0.897,
#   "['Small Island Pride']",
#   0.644,
#   0.39299999999999996,
#   '4LzmAVMOcE16RczU8U2mgK',
#   0.157,
#   -19.839000000000002,
#   'Mama Loves Mambo',
#   18,
#   0.0857,
#   98.824,
#   0.879],
#  29592: [0.773,
#   "['The Ray Conniff Singers']",
#   0.67,
#   0.381,
#   '5VNYJDz5rdqruOvqOUkXUM',
#   0.32899999999999996,
#   -14.792,
#   'Downtown',
#   28,
#   0.0316,
#   123.33,
#   0.9079999999999999],
#  21101: [0.00172,
#   "['Moondog']",
#   0.39399999999999996,
#   0.9440000000000001,
#   '2kIRRCAPFhPIKCSK2z9JUy',
#   0.0396,
#   -14.026,
#   'Oo Debut',
#   13,
#   0.0595,
#   135.25,
#   0.785],
#  22941: [0.938,
#   "['Paul Clayton']",
#   0.44799999999999995,
#   0.175,
#   '3q1Bx4GURmhkVafAtU5tOQ',
#   0.191,
#   -13.638,
#   "Who's Gonna Buy You Ribbons",
#   16,
#   0.0448,
#   61.328,
#   0.324],
#  17131: [0.447,
#   "['La Sonora Matancera', 'Celia Cruz']",
#   0.753,
#   0.507,
#   '4J65phbGLmyWvfhNYZQdli',
#   0.0445,
#   -10.2,
#   'El Marinero',
#   13,
#   0.0656,
#   133.692,
#   0.976],
#  28747: [0.9209999999999999,
#   "['The Clancy Brothers', 'Tommy Makem']",
#   0.29,
#   0.149,
#   '6K2bILxGCd4MsafXeUuBw3',
#   0.6990000000000001,
#   -20.415,
#   'Patriot Game (with Tommy Makem) - Live at Carnegie Hall, New York, NY - March 17, 1963',
#   23,
#   0.102,
#   145.704,
#   0.568],
#  10669: [0.728,
#   "['Gene Vincent & His Blue Caps']",
#   0.516,
#   0.863,
#   '4hurKoJaOsZHfHiI4feGyy',
#   0.287,
#   -7.027,
#   "Double Talkin' Baby",
#   19,
#   0.0635,
#   103.32799999999999,
#   0.7240000000000001],
#  20433: [0.618,
#   "['Merle Travis']",
#   0.7979999999999999,
#   0.312,
#   '6Jvw3KvzhMnp67v3wLbc6m',
#   0.14400000000000002,
#   -16.142,
#   'Sixteen Tons',
#   38,
#   0.075,
#   135.395,
#   0.38799999999999996],
#  3680: [0.992,
#   "['Bing Crosby']",
#   0.52,
#   0.0712,
#   '1FP4HX6uBcSS5cmWOVx0Rj',
#   0.376,
#   -18.305999999999997,
#   'Sunday, Monday Or Always - Single Version',
#   11,
#   0.0512,
#   72.90899999999998,
#   0.341],
#  24275: [0.76,
#   "['Ray Price']",
#   0.35200000000000004,
#   0.204,
#   '4cIGNFaKpoVuJfVvixS0mU',
#   0.327,
#   -15.414000000000001,
#   'For the Good Times',
#   49,
#   0.0311,
#   83.34200000000001,
#   0.524],
#  12344: [0.667,
#   "['Hank Thompson', 'Hank Thompson And His Brazos Valley Boys']",
#   0.701,
#   0.546,
#   '7rVrMFtJ3VrNZtNnMHCp7f',
#   0.0748,
#   -10.790999999999999,
#   'Hangover Tavern',
#   22,
#   0.0395,
#   83.499,
#   0.738],
#  3990: [0.867,
#   "['Bobby Capo']",
#   0.664,
#   0.3670000000000001,
#   '2RaXEKmOuAwQ1NAXbsdbwU',
#   0.382,
#   -10.599,
#   'Locamente Enamorado',
#   16,
#   0.0501,
#   113.68,
#   0.867],
#  22248: [0.772,
#   "['Odetta']",
#   0.34600000000000003,
#   0.45399999999999996,
#   '27Be6a8BHTjUS736RAnGgP',
#   0.426,
#   -5.181,
#   'Muleskinner Blues',
#   10,
#   0.0323,
#   115.302,
#   0.584],
#  10085: [0.9640000000000001,
#   "['Frederick Loewe', 'My Fair Lady Ensemble (1959)', 'Franz Allers', 'Cyril Ornadel']",
#   0.645,
#   0.14800000000000002,
#   '6e29SyfN6Hq0FoI1PPqkKx',
#   0.46799999999999997,
#   -16.722,
#   'My Fair Lady: Ascot Gavotte',
#   11,
#   0.0446,
#   120.821,
#   0.39],
#  27694: [0.795,
#   '[\'Stubby Kaye\', "Li\'l Abner Ensemble"]',
#   0.603,
#   0.569,
#   '0XULYas8JNdbnXLenGdmuV',
#   0.7609999999999999,
#   -9.049,
#   'The Matrimonial Stomp',
#   4,
#   0.366,
#   107.999,
#   0.8390000000000001],
#  4625: [0.966,
#   "['Cal Tjader']",
#   0.634,
#   0.386,
#   '1UvN9KX92pOABJmzmtTcoS',
#   0.099,
#   -15.152999999999999,
#   'Descarga Cubana',
#   25,
#   0.0517,
#   109.95,
#   0.8320000000000001],
#  22938: [0.602,
#   "['Paul Chambers', 'John Coltrane']",
#   0.5720000000000001,
#   0.451,
#   '0UwWtYObvuf2mq7axxaQGy',
#   0.342,
#   -9.758,
#   'John Paul Jones',
#   23,
#   0.0359,
#   112.228,
#   0.4],
#  12683: [0.47700000000000004,
#   "['Herb Ellis']",
#   0.565,
#   0.449,
#   '1pj5aeoZlIQQJYNgRMkMRs',
#   0.125,
#   -12.265999999999998,
#   'Pogo',
#   12,
#   0.0442,
#   127.67,
#   0.787],
#  19365: [0.8759999999999999,
#   "['Mahalia Jackson']",
#   0.664,
#   0.29100000000000004,
#   '2ShHbk7uxpRTlANACj3ya5',
#   0.971,
#   -16.914,
#   "He's Right On Time - Live",
#   14,
#   0.455,
#   123.406,
#   0.669],
#  3918: [0.36200000000000004,
#   "['Bob Dorough']",
#   0.616,
#   0.34700000000000003,
#   '7MFYyeIFUMaY40uFoibJwa',
#   0.0971,
#   -13.520999999999999,
#   'Three Is A Magic Number',
#   39,
#   0.128,
#   108.18,
#   0.276],
#  17698: [0.92,
#   "['Lester Young']",
#   0.586,
#   0.215,
#   '3oevvCDxct8oQvfejYPDmE',
#   0.196,
#   -13.432,
#   'You Can Depend On Me',
#   18,
#   0.0527,
#   114.288,
#   0.524],
#  ...}

# %%
# functions to get the required columns fo the different dictionaries to be created

def artist_music(data):
    '''
    Takes in a dataset, extracts specific columns and transforms the columns into a dictionary.
    The funtion stores the columns as a dictionary in memory.
    
    Parameter:
    data - A single dataset having rows and columns.
    '''
    
    artist = data[['acousticness', 'artists', 'danceability', 'energy', 'artist_id', 'liveness', 
                   'loudness', 'name', 'popularity', 'speechiness', 'tempo', 'valence']]
    
    return artist.set_index('artist_id').T.to_dict('list')


def music_features(data):
    '''
    Takes in a dataset, extracts specific columns and transforms the columns into a dictionary.
    The funtion stores the columns as a dictionary in memory.
    
    Parameter:
    data - A single dataset having rows and columns.
    '''
    
    artist = data[['acousticness', 'danceability', 'energy', 'id', 'liveness', 
                   'loudness', 'popularity', 'speechiness', 'tempo', 'valence']]
    
    return artist.set_index('id').T.to_dict('list')

# create the containers (variables) holding the dictionaries
music = music_features(specific_columns)
artist = artist_music(specific_columns)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   from ipykernel import kernelapp as app

# %%
artist[4880]
# Out:
# [0.975,
#  "['Carl Woitschach']",
#  0.622,
#  0.589,
#  0.508,
#  -10.607000000000001,
#  'Kaiser Friedrich Marsch',
#  0,
#  0.0553,
#  122.655,
#  0.846]

# %%
artist[9738]
# Out:
# [0.9570000000000001,
#  "['Francisco Canaro']",
#  0.5379999999999999,
#  0.23399999999999999,
#  0.081,
#  -12.404000000000002,
#  'Mariposa Nocturna - Remasterizado',
#  0,
#  0.0621,
#  129.197,
#  0.753]

# %% [markdown]
# # Module 2

# %%
from scipy.stats import pearsonr
from math import sqrt


def squared(x):
    '''
    A function that takes in a list of integers and squares them one by one.
    
    Parameter:
    x - List of integers.
    '''
    
#     return the square of the values passed into the function 
    return sqrt(sum([a*a for a in x]))


def euclidean_similarity(dictionary, id1, id2):
    '''
    A function to calculate the euclidean distance between two variables.
    
    Parameters:
    dictionary - a dictionary object that stores the parameters (either a single data or list of data) to be used
    in calculating the euclidean similarity between 2 data points.
    id1 -  A key to a specific data in the dictionary (either a single data or list of data) whose values are to be compared against id2.
    id2 -  A key to a specific data in the dictionary (either a single data or list of data) whose values are to be compared against id1.
    '''
    
    #     get the features associated with the id to be used for calculating the similarity
    first = dictionary[id1]
    second = dictionary[id2]
    
    #     remove string values found in the features
    x = [x for x in first if not isinstance(x, str)]
    y = [x for x in second if not isinstance(x, str)]
    
    #     calculate and return the euclidean similarity as shown in the mathematical notation
    return sqrt(sum(pow(a-b,2) for a, b in zip(x, y)))
  
    
def cosine_similarity(dictionary, id1, id2):
    '''
    A function to calculate the cosine distance between two variables.
    
    Parameters:
    dictionary - a dictionary object that stores the parameters (either a single data or list of data) to be used
    in calculating the cosine similarity between 2 data points.
    id1 -  A key to a specific data in the dictionary (either a single data or list of data) whose values are to be compared against id2.
    id2 -  A key to a specific data in the dictionary (either a single data or list of data) whose values are to be compared against id1.
    '''
    
    #     get the features associated with the id to be used for calculating the similarity
    first = dictionary[id1]
    second = dictionary[id2]
    
    #     remove string values found in the features
    x = [x for x in first if not isinstance(x, str)]
    y = [x for x in second if not isinstance(x, str)]
    
    #     calculate and return the cosine similarity as shown in the mathematical notation
    numerator = sum(a*b for a,b in zip(x,y))
    denominator = squared(x)*squared(y)
    return (numerator/float(denominator))


def pearson_similarity(dictionary, id1, id2):
    '''
    A function to calculate the pearson correlation between two variables.
    
    Parameters:
    dictionary - a dictionary object that stores the parameters (either a single data or list of data) to be used
    in calculating the pearson similarity between 2 data points.
    id1 -  A key to a specific data in the dictionary (either a single data or list of data) whose values are to be compared against id2.
    id2 -  A key to a specific data in the dictionary (either a single data or list of data) whose values are to be compared against id1.
    '''
    
    #     get the features associated with the id to be used for calculating the similarity
    first = dictionary[id1]
    second = dictionary[id2]
    
    #     remove string values found in the features
    x = [x for x in first if not isinstance(x, str)]
    y = [x for x in second if not isinstance(x, str)]
    
    #   return the pearson similarity as shown in the mathematical notation using a predefined class
    return pearsonr(x,y)[0]
  
    
def jaccard_similarity(dictionary, id1, id2):
    '''
    A function to calculate the jaccard distance between two variables.
    
    Parameters:
    dictionary - a dictionary object that stores the parameters (either a single data or list of data) to be used
    in calculating the jaccard similarity between 2 data points.
    id1 -  A key to a specific data in the dictionary (either a single data or list of data) whose values are to be compared against id2.
    id2 -  A key to a specific data in the dictionary (either a single data or list of data) whose values are to be compared against id1.
    '''
    
    #     get the features associated with the id to be used for calculating the similarity
    first = dictionary[id1]
    second = dictionary[id2]
    
    #     remove string values found in the features
    x = [x for x in first if not isinstance(x, str)]
    y = [x for x in second if not isinstance(x, str)]
    
    #     calculate and return the jaccard similarity as shown in the mathematical notation
    numerator = len(set.intersection(*[set(x), set(y)]))
    denominator = len(set.union(*[set(x), set(y)]))
    return numerator/float(denominator)


def manhattan_similarity(dictionary, id1, id2):
    '''
    A function to calculate the manhattan distance between two variables.
    
    Parameters:
    dictionary - a dictionary object that stores the parameters (either a single data or list of data) to be used
    in calculating the manhattan similarity between 2 data points.
    id1 -  A key to a specific data in the dictionary (either a single data or list of data) whose values are to be compared against id2.
    id2 -  A key to a specific data in the dictionary (either a single data or list of data) whose values are to be compared against id1.
    '''
    
    #     get the features associated with the id to be used for calculating the similarity
    first = dictionary[id1]
    second = dictionary[id2]
    
    #     remove string values found in the features
    x = [x for x in first if not isinstance(x, str)]
    y = [x for x in second if not isinstance(x, str)]
    
    #     calculate and return the manhattan similarity as shown in the mathematical notation
    return sum(abs(a-b) for a,b in zip(x,y))

# %%
data1 = music_features(specific_columns)
data2 = artist_music(specific_columns)

pearson_similarity(data1, '6KbQ3uYMLKb5jDxLF7wYDD', '6N6tiFZ9vLTSOIxkj8qKrd')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   from ipykernel import kernelapp as app
# 0.9878809899628151

# %%
pearson_similarity(data2, 400, 23104)
# Out:
# 0.7959227550115404

# %%
cosine_similarity(data2, 400, 23104)
# Out:
# 0.8187285677122752

# %% [markdown]
# # Module 3
# ## User interface module

# %%
import module1
import module2

# NB: All try and except codes are used to catch errors that could occur during the running of the program so it does'nt affect the program flow 

print("User interface (main module)")

# define instructions to be printed on screen
alert_message = "Enter "
dict_message = "Enter 1 to check similatites between Artist \nEnter 2 to check similarities between Music tracks.\nEnter any other number to quit.\n"
metric_message = "Enter 1 to use Euclidean Similarity \nEnter 2 to use Cosine Similarity \nEnter 3 to use Pearson Correlation \nEnter 4 to use Jaccard Similarity \nEnter 5 to use Manhattan Similarity\n"
id1_message = "Enter first id to compare.\n"
id2_message = "Enter second id to compare.\n"


# while the program is running, until user terminates program
while True:
    
    try:
    
        # take in the dictionary object to be used
        dict_to_use = int(input(f'{dict_message}> '))


        # conditional statements to get desired result
        if dict_to_use == 1:
            #     call in the desired dictionary stated
            data = data2

            
            try:
                #     take in desired metric to be used
                metric_to_use = int(input(f'{metric_message}> '))

                if metric_to_use == 1:
                    try:
                        #         Take in the ids of music to be compared
                        first_id = int(input(f'{id1_message}> '))
                        second_id = int(input(f'{id2_message}> '))

                        if first_id in data.keys() and second_id in data.keys():
                            #         call in the required function to be used
                            print(f'The similarity value is: {module2.euclidean_similarity(data, first_id, second_id)}')
                        else:
                            print('Key does not exist!!!')
                        
                    except ValueError:
                        print("Enter a Number!!!")
                        continue

                elif metric_to_use == 2:
                    try:
                        #         Take in the ids of music to be compared
                        first_id = int(input(f'{id1_message}> '))
                        second_id = int(input(f'{id2_message}> '))

                        if first_id in data.keys() and second_id in data.keys():
                            #         call in the required function to be used
                            print(f'The similarity value is: {module2.cosine_similarity(data, first_id, second_id)}')
                        else:
                            print('Key does not exist!!!')
                            
                    except ValueError:
                        print("Enter a Number!!!")
                        continue

                elif metric_to_use == 3:
                    try:
                        #         Take in the ids of music to be compared
                        first_id = int(input(f'{id1_message}> '))
                        second_id = int(input(f'{id2_message}> '))

                        if first_id in data.keys() and second_id in data.keys():
                            #         call in the required function to be used
                            print(f'The similarity value is: {module2.pearson_similarity(data, first_id, second_id)}')
                        else:
                            print('Key does not exist!!!')
                        
                    except ValueError:
                        print("Enter a Number!!!")
                        continue

                elif metric_to_use == 4:
                    try:
                        #         Take in the ids of music to be compared
                        first_id = int(input(f'{id1_message}> '))
                        second_id = int(input(f'{id2_message}> '))

                        if first_id in data.keys() and second_id in data.keys():
                            #         call in the required function to be used
                            print(f'The similarity value is: {module2.jaccard_similarity(data, first_id, second_id)}')
                        else:
                            print('Key does not exist!!!')
                            
                    except ValueError:
                        print("Enter a Number!!!")
                        continue

                elif metric_to_use == 5:
                    try:
                        #         Take in the ids of music to be compared
                        first_id = int(input(f'{id1_message}> '))
                        second_id = int(input(f'{id2_message}> '))

                        if first_id in data.keys() and second_id in data.keys():
                            #         call in the required function to be used
                            print(f'The similarity value is: {module2.manhattan_similarity(data, first_id, second_id)}')
                        else:
                            print('Key does not exist!!!')
                        
                    except ValueError:
                        print("Enter a Number!!!")
                        continue
        
                else:
                    print('Enter a valid number!!!')
                    
            except ValueError:
                print("Enter a Number!!!")
                continue


        elif dict_to_use == 2:
            #     call in the desired dictionary stated
            data = data1
            
            try:
                #     take in desired metric to be used
                metric_to_use = int(input(f'{metric_message}> '))

                if metric_to_use == 1:
                    try:
                        #         Take in the ids of artist to be compared
                        first_id = input(f'{id1_message}> ')
                        second_id = input(f'{id2_message}> ')

                        if first_id in data.keys() and second_id in data.keys():
                            #         call in the required function to be used
                            print(f'The similarity value is: {module2.euclidean_similarity(data, first_id, second_id)}')
                        else:
                            print('Key does not exist!!!')
                            
                    except ValueError:
                        print("Invalid key press!!!")
                        continue

                elif metric_to_use == 2:
                    try:
                        #         Take in the ids of artist to be compared
                        first_id = input(f'{id1_message}> ')
                        second_id = input(f'{id2_message}> ')

                        if first_id in data.keys() and second_id in data.keys():
                            #         call in the required function to be used
                            print(f'The similarity value is: {module2.cosine_similarity(data, first_id, second_id)}')
                        else:
                            print('Key does not exist!!!')
                        
                    except ValueError:
                        print("Enter a Number!!!")
                        continue

                elif metric_to_use == 3:
                    try:
                        #         Take in the ids of artist to be compared
                        first_id = input(f'{id1_message}> ')
                        second_id = input(f'{id2_message}> ')

                        if first_id in data.keys() and second_id in data.keys():
                            #         call in the required function to be used
                            print(f'The similarity value is: {module2.pearson_similarity(data, first_id, second_id)}')
                        else:
                            print('Key does not exist!!!')
                            
                    except ValueError:
                        print("Enter a Number!!!")
                        continue

                elif metric_to_use == 4:
                    try:
                        #         Take in the ids of artist to be compared
                        first_id = input(f'{id1_message}> ')
                        second_id = input(f'{id2_message}> ')

                        if first_id in data.keys() and second_id in data.keys():
                            #         call in the required function to be used
                            print(f'The similarity value is: {module2.jaccard_similarity(data, first_id, second_id)}')
                        else:
                            print('Key does not exist!!!')
                        
                    except ValueError:
                        print("Enter a Number!!!")
                        continue


                elif metric_to_use == 5:
                    try:
                        #         Take in the ids of artist to be compared
                        first_id = input(f'{id1_message}> ')
                        second_id = input(f'{id2_message}> ')

                        if first_id in data.keys() and second_id in data.keys():
                            #         call in the required function to be used
                            print(f'The similarity value is: {module2.manhattan_similarity(data, first_id, second_id)}')
                        else:
                            print('Key does not exist!!!')
                        
                    except ValueError:
                        print("Enter a Number!!!")
                        continue
                    
                else:
                    print('Enter a valid number!!!')
            
            except ValueError:
                print("Enter a Number!!!")
                continue
                
        else:
            print('Thank you for using this service. Bye')
            break
                
                
                
    except ValueError:
        print("Enter a Number!!!")
        continue
# Out:
# C:\Users\AWEDA\Downloads\Assignment\module1.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   specific_columns['artist_id'] = specific_columns.groupby(['artists']).ngroup()
# C:\Users\AWEDA\Downloads\Assignment\module1.py:42: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   return artist.set_index('artist_id').T.to_dict('list')
# User interface (main module)
# Enter 1 to check similatites between Artist
# Enter 2 to check similarities between Music tracks.
# Enter any other number to quit.
# > 1
# Enter 1 to use Euclidean Similarity
# Enter 2 to use Cosine Similarity
# Enter 3 to use Pearson Correlation
# Enter 4 to use Jaccard Similarity
# Enter 5 to use Manhattan Similarity
# > 2
# Enter first id to compare.
# > 4880
# Enter second id to compare.
# > 9738
# The similarity value is: 0.9999436344973376
# Enter 1 to check similatites between Artist
# Enter 2 to check similarities between Music tracks.
# Enter any other number to quit.
# > 1
# Enter 1 to use Euclidean Similarity
# Enter 2 to use Cosine Similarity
# Enter 3 to use Pearson Correlation
# Enter 4 to use Jaccard Similarity
# Enter 5 to use Manhattan Similarity
# > 3
# Enter first id to compare.
# > 4880
# Enter second id to compare.
# > 9738
# The similarity value is: 0.999962751553325
# Enter 1 to check similatites between Artist
# Enter 2 to check similarities between Music tracks.
# Enter any other number to quit.
# > 13
# Thank you for using this service. Bye
